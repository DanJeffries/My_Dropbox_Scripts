# %%
from Bio import SeqIO

# %%
block_54 = SeqIO.parse(open("/home/djeffrie/Data/PacBio/DAZZELR/Block_54_seq.fa", 'r'), "fasta")

# %%
lengths = []
for i in block_54:
    lengths.append(len(i.seq))

# %%
sorted(lengths)
# Out:
# [9,
#  27,
#  53,
#  65,
#  69,
#  72,
#  102,
#  112,
#  118,
#  123,
#  124,
#  125,
#  131,
#  139,
#  140,
#  141,
#  145,
#  150,
#  162,
#  164,
#  165,
#  166,
#  168,
#  169,
#  178,
#  180,
#  180,
#  181,
#  182,
#  183,
#  189,
#  194,
#  197,
#  201,
#  203,
#  212,
#  212,
#  215,
#  216,
#  217,
#  220,
#  222,
#  223,
#  227,
#  229,
#  233,
#  236,
#  244,
#  244,
#  252,
#  252,
#  255,
#  256,
#  263,
#  269,
#  272,
#  273,
#  274,
#  274,
#  275,
#  282,
#  283,
#  284,
#  288,
#  292,
#  298,
#  299,
#  301,
#  307,
#  311,
#  311,
#  325,
#  327,
#  330,
#  331,
#  332,
#  334,
#  336,
#  337,
#  338,
#  340,
#  340,
#  341,
#  344,
#  347,
#  354,
#  361,
#  377,
#  379,
#  380,
#  381,
#  390,
#  392,
#  393,
#  395,
#  396,
#  396,
#  397,
#  397,
#  399,
#  400,
#  401,
#  403,
#  410,
#  410,
#  412,
#  413,
#  423,
#  425,
#  425,
#  426,
#  429,
#  436,
#  441,
#  442,
#  444,
#  446,
#  454,
#  462,
#  463,
#  465,
#  465,
#  465,
#  468,
#  470,
# ...
