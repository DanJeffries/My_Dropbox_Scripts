# %% [markdown]
# ## Define helper functions
# ### Biopython style `UstacksCommandLine` class

# %%
import numpy as np 
import collections
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as py
import os
import csv
from collections import Counter
import re
import subprocess

# %%
from Bio.Application import _Option, AbstractCommandline, _Switch 

class UstacksCommandLine(AbstractCommandline):
    def __init__(self, cmd="ustacks", **kwargs):
        """
        # Any ustacks option and switch
        >>> cline_args = {'t': 'fastq',
        ...               'f': '../../dan_data/OBY01_1.fil.fq_1',
        ...               'o': '../../dan_data/OBY01_1.fi/M_tests/M_1',
        ...               'i': 1,
        ...               'm': 6,
        ...               'M': 1,
        ...               'p': 3,
        ...               'r': True,
        ...               'd': True}
        
        # This creates a command line object
        >>> ustacks_cline = UstacksCommandLine(**cline_args)
        
        # This prints a string representation
        >>> print ustacks_cline
        ustacks -t fastq -f ../../dan_data/OBY01_1.fil.fq_1 -o ../../dan_data/OBY01_1.fi/M_tests/M_1 -i 1 -m 6 -M 1 -p 3 -r -d
        
        # This runs ustacks
        >>> stdout, stderr = ustacks_cline()
        
        # This prints the first line in the allele files of the example reuslts
        >>> with open('../../dan_data/OBY01_1.fi/M_tests/M_1/OBY01_1.fil.alleles.tsv') as alleles:
        ...     print alleles.readlines()[1].rstrip().split()
        ['0', '1', '1', 'C', '78.04', '167']
        """
        
        self.parameters = [
            _Option(["-t", "t"],
                    "input file Type. Supported types: fasta, fastq, gzfasta, or gzfastq",
                    is_required=True,
                    checker_function=lambda value : value in ["fasta", 
                                                              "fastq",
                                                              "gzfasta",
                                                              "gzfastq"],
                    equate=False),
            _Option(["-f", "f"],
                    "input file path",
                    is_required=True,
                    filename=True,
                    equate=False),
            _Option(["-o", "o"],
                    "output path to write results",
                    is_required=False,
                    filename=True,
                    equate=False),
            _Option(["-i", "i"],
                    "SQL ID to insert into the output to identify this sample",
                    is_required=False,
                    equate=False),
            _Option(["-m", "m"],
                    "Minimum depth of coverage required to create a stack (default 3)",
                    is_required=False,
                    checker_function=lambda value : isinstance(value,int),
                    equate=False),
            _Option(["-M", "M"],
                    "Maximum distance (in nucleotides) allowed between stacks (default 2)",
                    is_required=False,
                    checker_function=lambda value : isinstance(value,int),
                    equate=False),
            _Option(["-N", "N"],
                    "Maximum distance allowed to align secondary reads to primary stacks (default: M + 2)",
                    is_required=False,
                    checker_function=lambda value : isinstance(value,int),
                    equate=False),
            _Switch(["-R", "R"],
                    "retain unused reads"), 
            _Switch(["-H", "H"],
                    "disable calling haplotypes from secondary reads"),
            _Option(["-p", "p"],
                    "enable parallel execution with num_threads threads",
                    is_required=False,
                    checker_function=lambda value : isinstance(value,int),
                    equate=False),  
            _Switch(["-h", "h"],
                    "display this help messsage"),
            
            # Stack assembly options:
            _Switch(["-r", "r"],
                    "enable the Removal algorithm, to drop highly-repetitive stacks (and nearby errors) from the algorithm"), 
            _Switch(["-d", "d"],
                    "enable the Deleveraging algorithm, used for resolving over merged tags"),
            _Option(["--max_locus_stacks", "-max_locus_stacks","max_locus_stacks"],
                    "maximum number of stacks at a single de novo locus (default 3)",
                    is_required=False,
                    checker_function=lambda value : isinstance(value,int),
                    equate=False),
            
            # Model options:
            _Option(["--model_type", "-model_type","model_type"],
                    "either 'snp' (default), 'bounded', or 'fixed'",
                    is_required=False,
                    checker_function=lambda value : value in ["snp", 
                                                              "bounded",
                                                              "fixed"],
                    equate=False),
            
            # For the SNP or Bounded SNP model: 
            _Option(["--alpha", "-alpha","alpha"],
                    "chi square significance level required to call a heterozygote or homozygote, either 0.1, 0.05 (default), 0.01, or 0.001",
                    is_required=False,
                    checker_function=lambda value : value in [0.1, 
                                                              0.05,
                                                              0.01,
                                                              0.001],
                    equate=False),
            
            
            # For the Bounded SNP model:
            _Option(["--bound_low", "-bound_low","bound_low"],
                    "lower bound for epsilon, the error rate, between 0 and 1.0 (default 0)",
                    is_required=False,
                    checker_function=lambda value : 0 <= value <= 1,
                    equate=False),
            _Option(["--bound_high", "-bound_high","bound_high"],
                    "upper bound for epsilon, the error rate, between 0 and 1.0 (default 1)",
                    is_required=False,
                    checker_function=lambda value : 0 <= value <= 1,
                    equate=False),
            
            # For the Fixed model:
            _Option(["--bc_err_freq", "-bc_err_freq","bc_err_freq"],
                    "specify the barcode error frequency, between 0 and 1.0",
                    is_required=False,
                    checker_function=lambda value : 0 <= value <= 1,
                    equate=False)
                           ]
        AbstractCommandline.__init__(self, cmd, **kwargs) 

## With this uncommented, the examples in the 
## docstring will be run and the outputs compared
#if __name__ == "__main__":
#    import doctest
#    doctest.testmod()

# %% [markdown]
# ## Define the incrementation and helper functions

# %%
stop_value = 2

stop_value = stop_value+1
    

print range(1, stop_value, 1)
print stop_value
# Out:
# [1, 2]
# 3

# %%
def replace_all(text,dic): ## this function takes the string to be searched and a dictionary of replacements
    for i, j in dic.iteritems(): #iteritems needed when using dic entries - remember this
        text = text.replace(i,j) ## for each dictionary entry, replace the "key" with the "value" in the text
    return text

## Define a cool little helper function for "natural sorting". (no idea how it works though!)
def natural_key(string_): 
    return [int(s) if s.isdigit() else s for s in re.split(r'(\d+)', string_)]


def make_and_run_command_lines(param, param_values, parent_dir_path, sample, file_format, threads, ID):
    
    # fixed values
    default = {'M': 3, 
               'm': 6}
              # MS as stacks default
    
    batch_params = {}
    
    for val in param_values:
        
        # make a directory
        #parent_dir_path + str(sample[:-6])+ '/M_tests/M_x/
        dirname = '%s%s/%s_tests/%s_%i'%(parent_dir_path,str(sample[:-6]),param,param,val)
        if not os.path.exists(dirname):
            try:
                os.makedirs(dirname)
            except:
                os.mkdir(dirname)
            
        # make command line
        args = {}
        args['t'] = file_format
        args['p'] = threads
        args['d'] = True
        args['r'] = True
        args['i'] = str(ID)
        args['f'] = "%s%s"%(parent_dir_path,str(sample))
        args['o'] = dirname
        if param == 'MS':
            args['max_locus_stacks'] = val
            args.update(default)
        else:
            args[param] = val
            for key in default:
                if not key == param:
                    args[key] = default[key]
                    
        cline = UstacksCommandLine(**args)
        print str(cline)
        stderr, stdout = cline()
        batch_params["%s_%i"%(args['i'], val)] = args
        
        
    return batch_params          
                            
        
             


def IncreMental_U(param, start_value, stop_value, increment, parent_dir_path, file_format, threads):
## parent_dir_path - the path to look for raw read .fastq files must have the trailing '/' in it.
    
    
    stop_value = stop_value+1
    
    ##lists and command templates 
    sample_names = [] 
    param_values = range(start_value, stop_value, increment)
    
    ## Define subfunctions ---------------------------------------------------------
            
    ## TAG COUNTER ##         
    def Tag_counter(directory, parameter):
        c = Counter()
        sample_names = []
        tag_data = []
        names = []
    
    
        ## Function to count the length of a file
    
        def file_len(data):
                for i, l in enumerate(data):
                    pass
                return i + 1
    

        ## get file names and paths
        if parameter == 'm':
            for root, dirs, files in os.walk(parent_dir_path):
                for fil in files:
                    if fil.endswith("tags.tsv") and 'catalog' not in fil and root.split('/')[11].startswith('m'):
                        print fil
                        data_file = open(str(root+'/'+fil), 'r')
                        tag_tally = 0
                        for line in data_file.readlines():
                            if 'consensus' in line:
                                tag_tally +=1
                        tag_data.append(str(root.split('/')[-1])+'/'+str(fil)+"\t"+str(tag_tally)) ## works nicely just put this into a list with sample name and its nearly done
                        print data_file
            tag_data = sorted(tag_data, key = natural_key)
            f = open(directory + "m_tests_Tag_numbers.txt", 'w')
            for i in tag_data:
                print i
                f.write(i+"\n")
            f.close()

    
            ## get the sample names
            for i in tag_data:
                names.append(i.split('\t')[0].split('/')[-1])
            names = set(names)
            print names    
            
            ##plot the figures
            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for i in names:
                tag_numbers = []
                for item in tag_data:
                    if i in item:
                        tag_numbers.append(int(item.split('\t')[1]))
                print "TAG COUNTER\n", i, tag_numbers, "stop_value = ", stop_value
                fig.add_subplot(np.round((len(names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),tag_numbers) ## Manually input the same parameter range used in incremental IncreMental here for the x axis labels.
                plt.plot(range(start_value, stop_value, increment),tag_numbers)
                plt.title(i+" Change in number of tags with m incrementation", fontsize = 5)
                plt.xlabel("Ustacks m Value", fontsize = 10)
                plt.ylabel("Number of tags", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
        
                tag_numbers = []
                plot_number+=1
            plt.savefig(directory + "m_tests_Tags_per_sample.pdf")
            plt.close('all')  
            
        elif parameter == 'M':
            for root, dirs, files in os.walk(parent_dir_path):
                for fil in files:
                    if fil.endswith("tags.tsv") and 'catalog' not in fil and root.split('/')[-1].startswith('M'):
                        print fil
                        data_file = open(str(root+'/'+fil), 'r')
                        tag_tally = 0
                        for line in data_file.readlines():
                            if 'consensus' in line:
                                tag_tally +=1
                        tag_data.append(str(root.split('/')[-1])+'/'+str(fil)+"\t"+str(tag_tally)) ## works nicely just put this into a list with sample name and its nearly done
                        print data_file
            tag_data = sorted(tag_data, key = natural_key)
            f = open(directory + "M_tests_Tag_numbers.txt", 'w')
            for i in tag_data:
                print i
                f.write(i+"\n")
            f.close()

    
            ## get the sample names
            for i in tag_data:
                names.append(i.split('\t')[0].split('/')[-1])
            names = set(names)
            print names    
            ##plot the figures
            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for i in names:
                tag_numbers = []
                for item in tag_data:
                    if i in item:
                        tag_numbers.append(int(item.split('\t')[1]))
                print "TAG COUNTER\n", i, tag_numbers
                fig.add_subplot(np.round((len(names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),tag_numbers) ## Manually input the same parameter range used in incremental IncreMental here for the x axis labels.
                plt.plot(range(start_value, stop_value, increment),tag_numbers)
                plt.title(i+" Change in number of tags with M incrementation", fontsize = 5)
                plt.xlabel("Ustacks m Value", fontsize = 10)
                plt.ylabel("Number of tags", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
        
                tag_numbers = []
                plot_number+=1
            plt.savefig(directory + "M_tests_Tags_per_sample.pdf")
            plt.close('all')
            
        ## Max-stacks-per-locus ###
        
        elif parameter == "MS":
            for root, dirs, files in os.walk(parent_dir_path):
                for fil in files:
                    if fil.endswith("tags.tsv") and 'catalog' not in fil and root.split('/')[-1].startswith('MS'):
                        print fil
                        data_file = open(str(root+'/'+fil), 'r')
                        tag_tally = 0
                        for line in data_file.readlines():
                            if 'consensus' in line:
                                tag_tally +=1
                        tag_data.append(str(root.split('/')[-1])+'/'+str(fil)+"\t"+str(tag_tally)) ## works nicely just put this into a list with sample name and its nearly done
                        print data_file
            tag_data = sorted(tag_data, key = natural_key)
            f = open(directory + "MS_tests_Tag_numbers.txt", 'w')
            for i in tag_data:
                print i
                f.write(i+"\n")
            f.close()
            
        ## get the sample names
            for i in tag_data:
                names.append(i.split('\t')[0].split('/')[-1])
            names = set(names)
            print names    
            
        ##plot the figures
            
            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for i in names:
                tag_numbers = []
                for item in tag_data:
                    if i in item:
                        tag_numbers.append(int(item.split('\t')[1]))
                print "TAG COUNTER\n", i, tag_numbers
                fig.add_subplot(np.round((len(names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),tag_numbers) ## Manually input the same parameter range used in incremental IncreMental here for the x axis labels.
                plt.plot(range(start_value, stop_value, increment),tag_numbers)
                plt.title(i+" Change in number of tags with Max_locus_stacks incrementation", fontsize = 5)
                plt.xlabel("Ustacks M_L_S Value", fontsize = 10)
                plt.ylabel("Number of tags", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
        
                tag_numbers = []
                plot_number+=1
            plt.savefig(directory + "MS_tests_Tags_per_sample.pdf")
            plt.close('all')
        
    
    
    ## COVERAGE COUNTER ##
    
    def coverage_counter(file_name):
        csvcol3 = []
        csvfile = open(file_name, 'rb')
        csvread = csv.reader(csvfile, delimiter ="\t") ## read csv in
    
        for line in csvread:
            # outputs in new version of stacks start with a comment 
            if not line[0].startswith('#'):
                csvcol3.append(int(line[2])) ## add the 3 column of each line to a list
        csvcol3 = [str(i) for i in csvcol3] ## convert this list of integers to strings
    
        coverage_count = collections.Counter()
        for tagID in csvcol3:
            coverage_count[tagID] += 1 ## count the number of times each tag ID occurs (i.e. the coverage)
    
        coverage_values = []
        f = open(str(file_name[:-9]+" Coverage data.txt"), 'a') ## make a new txt file for coverage data
    
        for i,j in coverage_count.iteritems():
            if len(str(j)) > 0:
                coverage_values.append(j) ## append the coverage to a list
                f.write(str(j) + '\n') ## write the coverage data to the txt file
    
        plt.hist(coverage_values, bins = max(coverage_values),range = [0, 100])
        plt.hist(coverage_values, bins = max(coverage_values),range = [0, 100])
        plt.title(file_name[2:8]+file_name[27:33])
        plt.xlabel("Coverage")
        plt.ylabel("Frequency")
        plt.text(60, 1200, "Mean tag coverage ="+ str(np.round(np.mean(coverage_values),2)))
        plt.savefig(file_name.rpartition('/')[0]+"/Coverage.pdf")
        plt.close()
    
        f.close()
        print coverage_values[:10]
        
        ## COVERAGE COUNTER LOOPER ## 
        
    def coverage_counter_looper(directory, parameter): ## make sure this is the right parent directory - i.e. contains the sample name folder created by increMental
        tsvs = []
        subdirs = []
        cov_files = []
        
        ### BIG if statement - if the parameter is M or m
    
        if parameter == 'M':
        
        ## Make a list of the files, including their paths from the current directory
        
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith(".tags.tsv") and 'catalog' not in fil and 'M_' in root:
                        tsvs.append(str(str(root)+'/'+str(fil)))
                        subdirs.append(str(str(root)+'/'+str(dirs)))
                        print root, fil
    
            ## Execute coverage counter for all these files
    
            for tsv in tsvs:
                coverage_counter(tsv)           
    
            ## make the multiplot
            ## first get the coverage counter output files
    
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith("data.txt") and 'catalog' not in fil and 'M_' in root:  ## have changed this so hopefully it doesn't pick up increMental_C outputs
                        cov_files.append(str(str(root)+'/'+str(fil)))
            cov_files = sorted(cov_files, key = natural_key)
            plot_number = 1

            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.8)
            data = []
            for cov_file in cov_files:    
                data_file = open(cov_file, 'r')
                for i in data_file.readlines():
                    if i > 0:
                        data.append(int(i))    
    
                fig.add_subplot(np.round((len(cov_files)/3)+1),3,plot_number)
                plt.hist(data, bins = 100,range = [0, 150])
                plt.title(cov_file.split('/')[-1].partition('_')[0]+" "+ cov_file.split('/')[-2], fontsize = 5)
                py.yticks(fontsize = 5)
                py.xticks(fontsize = 5)
                plt.xlabel("Coverage", fontsize = 5)
                plt.ylabel("Frequency", fontsize = 5)
                plt.text(60, 1200, "Mean tag coverage ="+ str(np.round(float(np.mean(data)),2)), fontsize = 5)
    
                plot_number += 1

            plt.savefig(directory + 'M_tests_coverage_multiplot.pdf')    
            plt.close('all')
    
    
            print('number of coverage plots = '+ str(plot_number -1))
    
            ### Make the change-in average coverage plot
    
            sample_coverage = []
            sample_names = []
            cov_data = []
            cov_values = []



            ## get file names and paths

            for root, dirs, files in os.walk(directory):
                for fil in files:
                    if fil.endswith("data.txt") and 'M_' in root:
                        data_file = open(str(root+'/'+fil), 'r')
                        data = [int(i.lstrip('0')) for i in data_file.readlines()]
                        sample_coverage.append(fil.partition('_')[0] + "__" + root.split('/')[3]+"\t"+ str(np.round(np.mean(data),2)))

            ## make a list of uniq sample names

            for i in sample_coverage:
                sample_names.append(i.split('\t')[0].partition('_')[0])
            sample_names = set(sample_names)
            print "sample names =" 
            print sample_names

            ## Use this list to separate the data according to the sample it comes from
            ## And then plot the graphs in one file and save in parent directory
    
            fig = plt.figure() ## make fig
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for name in sample_names: ## for each sample
                for line in sample_coverage:
                    if name in line:
                        cov_data.append(line)
                cov_data = sorted(cov_data, key = natural_key) ## sort "naturally"
                for i in cov_data:
                    cov_values.append(float(i.split()[1]))
                print name
                print cov_values
    
            ## And now plot the graphs as subplots in a main fig. Put in parent dir.   
    
                fig.add_subplot(np.round((len(sample_names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),cov_values) ## Manually input range from IncreMental here!
                plt.plot(range(start_value, stop_value, increment),cov_values)
                plt.title(name+" coverage per tag with M incrementation", fontsize = 10)
                plt.xlabel("Ustacks Parameter Value", fontsize = 10)
                plt.ylabel("Coverage per tag", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
    
                cov_data = []
                cov_values = []
                plot_number+=1
            plt.savefig(directory + "M_tests_mean_coverage_multiplot.pdf")
            plt.close('all')
        
        elif parameter == 'm':
        
        ## Make a list of the files, including their paths from the current directory
        
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith(".tags.tsv") and 'catalog' not in fil and 'm_' in root:
                        tsvs.append(str(str(root)+'/'+str(fil)))
                        print root, fil
    
            ## Execute coverage counter for all these files
    
            for tsv in tsvs:
                coverage_counter(tsv)           
    
            ## make the multiplot
            ## first get the coverage counter output files
    
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith("data.txt") and 'catalog' not in fil and 'm_' in root:  ## have changed this so hopefully it doesn't pick up increMental_C outputs
                        cov_files.append(str(str(root)+'/'+str(fil)))
            cov_files = sorted(cov_files, key = natural_key)          
            plot_number = 1
            
            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.8)

            for cov_file in cov_files:    
                print cov_file
                data_file = open(cov_file, 'r')
                data = [int(i) for i in data_file.readlines()]

                fig.add_subplot(np.round((len(cov_files)/3)+1),3,plot_number)
                plt.hist(data, bins = 100,range = [0, 150])
                plt.title(cov_file.split('/')[-1].partition('_')[0]+" "+ cov_file.split('/')[-3], fontsize = 5)
                py.yticks(fontsize = 5)
                py.xticks(fontsize = 5)
                plt.xlabel("Coverage", fontsize = 5)
                plt.ylabel("Frequency", fontsize = 5)
                plt.text(60, 1200, "Mean tag coverage ="+ str(np.round(float(np.mean(data)),2)), fontsize = 5)
    
                plot_number += 1

            plt.savefig(directory + 'm_tests_coverage_multiplot.pdf')    
            plt.close('all')
    
    
            print('number of coverage plots = '+ str(plot_number -1))
    
            ### Make the change-in average coverage plot
    
            sample_coverage = []
            sample_names = []
            cov_data = []
            cov_values = []


            ## get file names and paths

            for root, dirs, files in os.walk(directory):
                for fil in files:
                    if fil.endswith("data.txt") and 'm_' in root:
                        data_file = open(str(root+'/'+fil), 'r')
                        data = [int(i) for i in data_file.readlines()]
                        sample_coverage.append(fil.partition('_')[0] + "__" + root.split('/')[3]+"\t"+ str(np.round(np.mean(data),2)))

            ## make a list of uniq sample names

            for i in sample_coverage:
                sample_names.append(i.split('\t')[0].partition('_')[0])
            sample_names = set(sample_names)
            print "sample names =" 
            print sample_names

            ## Use this list to separate the data according to the sample it comes from
            ## And then plot the graphs in one file and save in parent directory
    
            fig = plt.figure() ## make fig
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for name in sample_names: ## for each sample
                for line in sample_coverage:
                    if name in line:
                        cov_data.append(line)
                cov_data = sorted(cov_data, key = natural_key) ## sort "naturally"
                for i in cov_data:
                    cov_values.append(float(i.split()[1]))
                print name
                print cov_values
    
            ## And now plot the graphs as subplots in a main fig. Put in parent dir.   
    
                fig.add_subplot(np.round((len(sample_names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),cov_values) ## remember to change back to start_value, stop_value, increment
                plt.plot(range(start_value, stop_value, increment),cov_values)
                plt.title(name+" coverage per tag with m incrementation", fontsize = 10)
                plt.xlabel("Ustacks Parameter Value", fontsize = 10)
                plt.ylabel("Coverage per tag", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
    
                cov_data = []
                cov_values = []
                plot_number+=1
            plt.savefig(directory + "m_tests_mean_coverage_multiplot.pdf")
            plt.close('all')
            
        elif parameter == "max_locus_stacks":
            ## Make a list of the files, including their paths from the current directory
        
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith(".tags.tsv") and 'catalog' not in fil and 'MS_' in root:
                        tsvs.append(str(str(root)+'/'+str(fil)))
                        print root, fil
    
            ## Execute coverage counter for all these files
    
            for tsv in tsvs:
                coverage_counter(tsv)           
    
            ## make the multiplot
            ## first get the coverage counter output files
    
            for root, dirs, files in os.walk(str(directory)):
                for fil in files:
                    if fil.endswith("data.txt") and 'catalog' not in fil and 'MS_' in root:  ## have changed this so hopefully it doesn't pick up increMental_C outputs
                        cov_files.append(str(str(root)+'/'+str(fil)))
            cov_files = sorted(cov_files, key = natural_key)          
            plot_number = 1
            
            fig = plt.figure()
            plt.subplots_adjust(hspace = 0.8)

            for cov_file in cov_files:    
                print cov_file
                data_file = open(cov_file, 'r')
                data = [int(i) for i in data_file.readlines()]

                fig.add_subplot(np.round((len(cov_files)/3)+1),3,plot_number)
                plt.hist(data, bins = 100,range = [0, 150])
                plt.title(cov_file.split('/')[-1].partition('_')[0]+" "+ cov_file.split('/')[-3], fontsize = 5)
                py.yticks(fontsize = 5)
                py.xticks(fontsize = 5)
                plt.xlabel("Coverage", fontsize = 5)
                plt.ylabel("Frequency", fontsize = 5)
                plt.text(60, 1200, "Mean tag coverage ="+ str(np.round(float(np.mean(data)),2)), fontsize = 5)
    
                plot_number += 1

            plt.savefig(directory + 'MS_tests_coverage_multiplot.pdf')    
            plt.close('all')
    
    
            print('number of coverage plots = '+ str(plot_number -1))
        
        ### Make the change-in average coverage plot
    
            sample_coverage = []
            sample_names = []
            cov_data = []
            cov_values = []


            ## get file names and paths

            for root, dirs, files in os.walk(directory):
                for fil in files:
                    if fil.endswith("data.txt") and 'MS_' in root:
                        data_file = open(str(root+'/'+fil), 'r')
                        data = [int(i) for i in data_file.readlines()]
                        sample_coverage.append(fil.partition('_')[0] + "__" + root.split('/')[3]+"\t"+ str(np.round(np.mean(data),2)))

            ## make a list of uniq sample names

            for i in sample_coverage:
                sample_names.append(i.split('\t')[0].partition('_')[0])
            sample_names = set(sample_names)
            print "sample names =" 
            print sample_names

            ## Use this list to separate the data according to the sample it comes from
            ## And then plot the graphs in one file and save in parent directory
    
            fig = plt.figure() ## make fig
            plt.subplots_adjust(hspace = 0.5) ## adjust subplots
            plot_number =1
            for name in sample_names: ## for each sample
                for line in sample_coverage:
                    if name in line:
                        cov_data.append(line)
                cov_data = sorted(cov_data, key = natural_key) ## sort "naturally"
                for i in cov_data:
                    cov_values.append(float(i.split()[1]))
                print name
                print cov_values
    
            ## And now plot the graphs as subplots in a main fig. Put in parent dir.   
    
                fig.add_subplot(np.round((len(sample_names)/2)+1),2,plot_number)
                plt.scatter(range(start_value, stop_value, increment),cov_values) ## remember to change back to start_value, stop_value, increment
                plt.plot(range(start_value, stop_value, increment),cov_values)
                plt.title(name+" coverage per tag with Max_Locus_stacks incrementation", fontsize = 10)
                plt.xlabel("Ustacks M_L_S Parameter Value", fontsize = 10)
                plt.ylabel("Coverage per tag", fontsize = 10)
                plt.xticks(fontsize = 7)
                plt.yticks(fontsize = 7)
    
                cov_data = []
                cov_values = []
                plot_number+=1
            plt.savefig(directory + "MS_tests_mean_coverage_multiplot.pdf")
            plt.close('all')
   
    
    ## RUNNING PIPELINE ---------------------------------------------------------------
    
        
    ID = 1 ## Assign a different ID to each individual with for a given param value
    
    
    ## Get samples
    for i in os.listdir(parent_dir_path):
        if i.endswith(".fq_1") or i.endswith(".fq") or i.endswith("1.fastq"): 
            sample_names.append(i)
    sample_names = sorted(sample_names) ## Important line - as Incremental_C sorts as well and assigns samples to lists on the basis of their IDs they must be sorted the same way here
    
    print "samples present", sample_names
    print ("Parameter values =" + str(param_values))    

    
    analysis_settings = {}
   
    for sample in sample_names: ## Run pipeline for each sample ...
        
        analysis_settings[str(ID)] = make_and_run_command_lines(param, param_values, parent_dir_path,
                                                                sample, file_format, threads, ID)
        ID += 1

    Tag_counter(parent_dir_path, param)
    coverage_counter_looper(parent_dir_path, param)
    
    
    
    return analysis_settings

# %% [markdown]
# ### Run the pipline here:

# %%
Tag_counter("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/", "M")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-db02610d0790> in <module>()
# ----> 1 Tag_counter("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/", "M")
#
# NameError: name 'Tag_counter' is not defined

# %%
## MS analyses

working_dir = "/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/"

analysis_settings = {}

for root, dirs, files in os.walk(working_dir):
    for dir in dirs:
        if "TESTDIR" in dir:  ## Loop over the test directories
            
            testdir = '%s%s/' %(root, dir)
            print testdir
            analysis_settings[dir] = IncreMental_U("max_locus_stacks", 1, 5, 1, testdir, 'fastq', 7)
# Out:
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/
# samples present ['HOLT9_RD-P1-180_1.fil.fq_1', 'RM31_RD-P1-171_1.fil.fq_1', 'RM8_RD-P1-175_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/
# samples present ['EP01_1.fil.fq_1', 'OU01_1.fil.fq_1', 'RM32_RD-P1-179_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/EP01_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/OU01_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/
# samples present ['DEND3_RD-P1-130_1.fil.fq_1', 'POLEN4_RD-P1-105_1.fil.fq_1', 'VIKKHY2_RD-P1-155_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/
# samples present ['TU3_RD-P1-108_1.fil.fq_1', 'VIKKHY4_RD-P1-181_1.fil.fq_1', 'VIKKHY6_RD-P1-109_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/
# samples present ['LAS01_1.fil.fq_1', 'SK2_RD-P1-167_1.fil.fq_1', 'SWED97_3_RD-P1-144_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/LAS01_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SK2_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GIB_TESTDIR_3/SWED97_3_RD-P1-144_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/
# samples present ['BF04_1.fil.fq_1', 'GBP19_RD-P1-167_1.fil.fq_1', 'HOLT14_RD-P1-157_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/BF04_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/
# samples present ['FM01_1.fil.fq_1', 'FM05_1.fil.fq_1', 'GF2_RD-P1-193_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM01_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/FM05_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/
# samples present ['COP06_1.fil.fq_1', 'GF1_RD-P1-169_1.fil.fq_1', 'HOLT6_RD-P1-168_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 1 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 2 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/max_locus_stacks_tests/max_locus_stacks_1 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 1
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/max_locus_stacks_tests/max_locus_stacks_2 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 2
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/max_locus_stacks_tests/max_locus_stacks_3 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 3
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/max_locus_stacks_tests/max_locus_stacks_4 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 4
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/max_locus_stacks_tests/max_locus_stacks_5 -i 3 -m 6 -M 3 -p 7 -r -d --max_locus_stacks 5
# number of coverage plots = 0
# sample names =
# set([])

# %%
## Batch analysis
working_dir = "/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/"

test_params = ["M", "m", "MS"]

analysis_settings = {}

for root, dirs, files in os.walk(working_dir):
    for dir in dirs:
        if "TESTDIR" in dir:  ## Loop over the test directories
            testdir = '%s%s/' %(root, dir)
            
            for parameter in test_params: ## loop over the paramters to test . . . 
                
                analysis_settings[dir] = IncreMental_U(parameter, 1, 8, 1, testdir, 'fastq', 7)
# Out:
# samples present ['HOLT9_RD-P1-180_1.fil.fq_1', 'RM31_RD-P1-171_1.fil.fq_1', 'RM8_RD-P1-175_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5, 6, 7, 8]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_1 -i 1 -m 6 -M 1 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_2 -i 1 -m 6 -M 2 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_3 -i 1 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_4 -i 1 -m 6 -M 4 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_5 -i 1 -m 6 -M 5 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_6 -i 1 -m 6 -M 6 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_7 -i 1 -m 6 -M 7 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_8 -i 1 -m 6 -M 8 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_1 -i 2 -m 6 -M 1 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_2 -i 2 -m 6 -M 2 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_3 -i 2 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_4 -i 2 -m 6 -M 4 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_5 -i 2 -m 6 -M 5 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_6 -i 2 -m 6 -M 6 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_7 -i 2 -m 6 -M 7 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_8 -i 2 -m 6 -M 8 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_1 -i 3 -m 6 -M 1 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_2 -i 3 -m 6 -M 2 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_3 -i 3 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_4 -i 3 -m 6 -M 4 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_5 -i 3 -m 6 -M 5 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_6 -i 3 -m 6 -M 6 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_7 -i 3 -m 6 -M 7 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_8 -i 3 -m 6 -M 8 -p 7 -r -d
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_1/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_2/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_3/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_4/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_5/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_6/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_7/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_8/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_1/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_2/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_3/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_4/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_5/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_6/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_7/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_8/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_1/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_2/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_3/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_4/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_5/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_6/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_7/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f0b04b0>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_8/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b446f0>
# M_1/HOLT9_RD-P1-180_1.fil.tags.tsv	63508
# M_1/RM8_RD-P1-175_1.fil.tags.tsv	46553
# M_1/RM31_RD-P1-171_1.fil.tags.tsv	52843
# M_2/HOLT9_RD-P1-180_1.fil.tags.tsv	61795
# M_2/RM8_RD-P1-175_1.fil.tags.tsv	45908
# M_2/RM31_RD-P1-171_1.fil.tags.tsv	50634
# M_3/HOLT9_RD-P1-180_1.fil.tags.tsv	60262
# M_3/RM8_RD-P1-175_1.fil.tags.tsv	45472
# M_3/RM31_RD-P1-171_1.fil.tags.tsv	49523
# M_4/HOLT9_RD-P1-180_1.fil.tags.tsv	58939
# M_4/RM8_RD-P1-175_1.fil.tags.tsv	45036
# M_4/RM31_RD-P1-171_1.fil.tags.tsv	48794
# M_5/HOLT9_RD-P1-180_1.fil.tags.tsv	57864
# M_5/RM8_RD-P1-175_1.fil.tags.tsv	44601
# M_5/RM31_RD-P1-171_1.fil.tags.tsv	48223
# M_6/HOLT9_RD-P1-180_1.fil.tags.tsv	56974
# M_6/RM8_RD-P1-175_1.fil.tags.tsv	44161
# M_6/RM31_RD-P1-171_1.fil.tags.tsv	47774
# M_7/HOLT9_RD-P1-180_1.fil.tags.tsv	56325
# M_7/RM8_RD-P1-175_1.fil.tags.tsv	43764
# M_7/RM31_RD-P1-171_1.fil.tags.tsv	47398
# M_8/HOLT9_RD-P1-180_1.fil.tags.tsv	55817
# M_8/RM8_RD-P1-175_1.fil.tags.tsv	43407
# M_8/RM31_RD-P1-171_1.fil.tags.tsv	47071
# set(['HOLT9_RD-P1-180_1.fil.tags.tsv', 'RM8_RD-P1-175_1.fil.tags.tsv', 'RM31_RD-P1-171_1.fil.tags.tsv'])
# TAG COUNTER
# HOLT9_RD-P1-180_1.fil.tags.tsv [63508, 61795, 60262, 58939, 57864, 56974, 56325, 55817]
# TAG COUNTER
# RM8_RD-P1-175_1.fil.tags.tsv [46553, 45908, 45472, 45036, 44601, 44161, 43764, 43407]
# TAG COUNTER
# RM31_RD-P1-171_1.fil.tags.tsv [52843, 50634, 49523, 48794, 48223, 47774, 47398, 47071]
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_1 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_2 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_3 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_4 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_5 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_6 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_7 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/M_tests/M_8 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_1 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_2 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_3 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_4 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_5 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_6 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_7 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/M_tests/M_8 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_1 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_2 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_3 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_4 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_5 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_6 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_7 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/M_tests/M_8 RM8_RD-P1-175_1.fil.tags.tsv
# [8, 11, 11, 17, 18, 10, 12, 15, 14, 12]
# [16, 9, 34, 21, 21, 11, 10, 12, 13, 24]
# [24, 12, 16, 8, 11, 9, 9, 13, 12, 9]
# [10, 13, 9, 15, 21, 14, 13, 20, 16, 10]
# [13, 10, 11, 10, 10, 11, 14, 11, 12, 9]
# [11, 17, 53, 13, 9, 14, 10, 43, 11, 12]
# [13, 10, 9, 9, 17, 17, 24, 13, 19, 12]
# [29, 17, 11, 12, 10, 13, 15, 11, 20, 16]
# [9, 38, 11, 33, 36, 19, 25, 11, 24, 17]
# [30, 19, 36, 26, 29, 23, 24, 26, 27, 22]
# [10, 13, 31, 26, 26, 25, 19, 23, 40, 67]
# [41, 27, 12, 42, 34, 67, 24, 33, 25, 21]
# [21, 23, 30, 41, 19, 32, 33, 27, 8, 12]
# [12, 42, 12, 41, 20, 25, 35, 29, 15, 31]
# [14, 28, 25, 58, 31, 63, 36, 20, 11, 34]
# [34, 24, 31, 20, 25, 21, 13, 38, 30, 12]
# [14, 8, 18, 17, 17, 20, 16, 18, 16, 13]
# [18, 20, 17, 16, 19, 14, 23, 19, 13, 9]
# [25, 14, 16, 17, 24, 19, 20, 23, 26, 21]
# [19, 66, 18, 9, 12, 23, 17, 18, 17, 15]
# [15, 20, 9, 11, 20, 13, 8, 15, 19, 18]
# [18, 20, 13, 10, 17, 26, 24, 11, 22, 16]
# [14, 18, 19, 22, 20, 12, 13, 18, 22, 14]
# [16, 14, 18, 25, 13, 13, 16, 16, 15, 13]
# number of coverage plots = 24
# sample names =
# set(['HOLT9', 'RM8', 'RM31'])
# HOLT9
# [13.08, 13.54, 13.94, 14.3, 14.61, 14.87, 15.07, 15.23]
# RM8
# [20.19, 20.54, 20.78, 21.01, 21.22, 21.44, 21.65, 21.83]
# RM31
# [25.33, 26.42, 27.01, 27.42, 27.75, 28.01, 28.24, 28.44]
# samples present ['HOLT9_RD-P1-180_1.fil.fq_1', 'RM31_RD-P1-171_1.fil.fq_1', 'RM8_RD-P1-175_1.fil.fq_1']
# Parameter values =[1, 2, 3, 4, 5, 6, 7, 8]
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_1 -i 1 -m 1 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_2 -i 1 -m 2 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_3 -i 1 -m 3 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_4 -i 1 -m 4 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_5 -i 1 -m 5 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_6 -i 1 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_7 -i 1 -m 7 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_8 -i 1 -m 8 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_1 -i 2 -m 1 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_2 -i 2 -m 2 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_3 -i 2 -m 3 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_4 -i 2 -m 4 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_5 -i 2 -m 5 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_6 -i 2 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_7 -i 2 -m 7 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_8 -i 2 -m 8 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_1 -i 3 -m 1 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_2 -i 3 -m 2 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_3 -i 3 -m 3 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_4 -i 3 -m 4 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_5 -i 3 -m 5 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_6 -i 3 -m 6 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_7 -i 3 -m 7 -M 3 -p 7 -r -d
# ustacks -t fastq -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_8 -i 3 -m 8 -M 3 -p 7 -r -d
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_1/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_2/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_3/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_4/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_5/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_6/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_7/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# HOLT9_RD-P1-180_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_8/HOLT9_RD-P1-180_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_1/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_2/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_3/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_4/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_5/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_6/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_7/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM31_RD-P1-171_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_8/RM31_RD-P1-171_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_1/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_2/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_3/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_4/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_5/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_6/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_7/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff10f066030>
# RM8_RD-P1-175_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_8/RM8_RD-P1-175_1.fil.tags.tsv', mode 'r' at 0x7ff122b44f60>
# m_1/HOLT9_RD-P1-180_1.fil.tags.tsv	148518
# m_1/RM8_RD-P1-175_1.fil.tags.tsv	111067
# m_1/RM31_RD-P1-171_1.fil.tags.tsv	139101
# m_2/HOLT9_RD-P1-180_1.fil.tags.tsv	88083
# m_2/RM8_RD-P1-175_1.fil.tags.tsv	50659
# m_2/RM31_RD-P1-171_1.fil.tags.tsv	55420
# m_3/HOLT9_RD-P1-180_1.fil.tags.tsv	82550
# m_3/RM8_RD-P1-175_1.fil.tags.tsv	48799
# m_3/RM31_RD-P1-171_1.fil.tags.tsv	52469
# m_4/HOLT9_RD-P1-180_1.fil.tags.tsv	76777
# m_4/RM8_RD-P1-175_1.fil.tags.tsv	47750
# m_4/RM31_RD-P1-171_1.fil.tags.tsv	51293
# m_5/HOLT9_RD-P1-180_1.fil.tags.tsv	69369
# m_5/RM8_RD-P1-175_1.fil.tags.tsv	46672
# m_5/RM31_RD-P1-171_1.fil.tags.tsv	50418
# m_6/HOLT9_RD-P1-180_1.fil.tags.tsv	60262
# m_6/RM8_RD-P1-175_1.fil.tags.tsv	45472
# m_6/RM31_RD-P1-171_1.fil.tags.tsv	49523
# m_7/HOLT9_RD-P1-180_1.fil.tags.tsv	50014
# m_7/RM8_RD-P1-175_1.fil.tags.tsv	44119
# m_7/RM31_RD-P1-171_1.fil.tags.tsv	48595
# m_8/HOLT9_RD-P1-180_1.fil.tags.tsv	39640
# m_8/RM8_RD-P1-175_1.fil.tags.tsv	42478
# m_8/RM31_RD-P1-171_1.fil.tags.tsv	47460
# set(['HOLT9_RD-P1-180_1.fil.tags.tsv', 'RM8_RD-P1-175_1.fil.tags.tsv', 'RM31_RD-P1-171_1.fil.tags.tsv'])
# TAG COUNTER
# HOLT9_RD-P1-180_1.fil.tags.tsv [148518, 88083, 82550, 76777, 69369, 60262, 50014, 39640] stop_value =  9
# TAG COUNTER
# RM8_RD-P1-175_1.fil.tags.tsv [111067, 50659, 48799, 47750, 46672, 45472, 44119, 42478] stop_value =  9
# TAG COUNTER
# RM31_RD-P1-171_1.fil.tags.tsv [139101, 55420, 52469, 51293, 50418, 49523, 48595, 47460] stop_value =  9
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_1 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_2 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_3 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_4 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_5 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_6 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_7 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_8 HOLT9_RD-P1-180_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_1 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_2 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_3 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_4 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_5 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_6 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_7 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_8 RM31_RD-P1-171_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_1 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_2 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_3 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_4 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_5 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_6 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_7 RM8_RD-P1-175_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_8 RM8_RD-P1-175_1.fil.tags.tsv
# [5, 13, 11, 3, 11, 8, 7, 9, 15, 8]
# [11, 10, 8, 8, 17, 9, 33, 8, 9, 10]
# [9, 8, 5, 16, 13, 8, 8, 9, 10, 5]
# [13, 9, 6, 9, 14, 11, 7, 10, 13, 14]
# [8, 13, 8, 11, 20, 9, 11, 11, 22, 9]
# [12, 16, 10, 8, 10, 9, 12, 13, 22, 13]
# [17, 9, 12, 12, 60, 13, 20, 14, 29, 27]
# [16, 15, 11, 24, 11, 12, 14, 17, 18, 17]
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# [22, 5, 15, 36, 11, 4, 33, 53, 36, 25]
# [36, 7, 23, 22, 38, 13, 21, 30, 8, 28]
# [17, 40, 14, 29, 28, 14, 33, 12, 15, 30]
# [23, 29, 25, 25, 41, 19, 19, 13, 42, 29]
# [8, 37, 12, 21, 43, 29, 27, 22, 38, 22]
# [16, 16, 26, 28, 12, 30, 19, 20, 27, 38]
# [15, 16, 13, 13, 38, 19, 36, 48, 48, 23]
# [3, 3, 3, 12, 3, 3, 18, 13, 4, 3]
# [20, 46, 21, 30, 27, 25, 30, 4, 24, 16]
# [18, 9, 22, 20, 31, 8, 24, 13, 17, 19]
# [27, 19, 22, 13, 15, 19, 18, 16, 14, 20]
# [19, 17, 12, 26, 15, 20, 8, 11, 19, 22]
# [15, 15, 17, 14, 16, 24, 18, 15, 9, 21]
# [19, 41, 14, 12, 11, 20, 34, 21, 18, 21]
# [15, 16, 24, 26, 20, 23, 13, 29, 27, 19]
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_1/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_2/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_3/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_4/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_5/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_6/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_7/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/HOLT9_RD-P1-180_1.fi/m_tests/m_8/HOLT9_RD-P1-180_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_1/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_2/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_3/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_4/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_5/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_6/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_7/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM8_RD-P1-175_1.fi/m_tests/m_8/RM8_RD-P1-175_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_1/RM31_RD-P1-171_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_2/RM31_RD-P1-171_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_3/RM31_RD-P1-171_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_4/RM31_RD-P1-171_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_5/RM31_RD-P1-171_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_CYP_TESTDIR_1/RM31_RD-P1-171_1.fi/m_tests/m_6/RM31_RD-P1-171_1.fil Coverage data.txt
# ...
# COP06_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_8/COP06_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_1/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_2/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_3/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_4/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_5/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_6/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_7/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# GF1_RD-P1-169_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_8/GF1_RD-P1-169_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_1/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_2/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_3/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_4/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_5/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_6/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_7/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff122b44930>
# HOLT6_RD-P1-168_1.fil.tags.tsv
# <open file '/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_8/HOLT6_RD-P1-168_1.fil.tags.tsv', mode 'r' at 0x7ff10f066150>
# MS_1/COP06_1.fil.tags.tsv	47815
# MS_1/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_1/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_2/COP06_1.fil.tags.tsv	47815
# MS_2/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_2/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_3/COP06_1.fil.tags.tsv	47815
# MS_3/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_3/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_4/COP06_1.fil.tags.tsv	47815
# MS_4/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_4/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_5/COP06_1.fil.tags.tsv	47815
# MS_5/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_5/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_6/COP06_1.fil.tags.tsv	47815
# MS_6/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_6/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_7/COP06_1.fil.tags.tsv	47815
# MS_7/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_7/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# MS_8/COP06_1.fil.tags.tsv	47815
# MS_8/GF1_RD-P1-169_1.fil.tags.tsv	51236
# MS_8/HOLT6_RD-P1-168_1.fil.tags.tsv	59617
# set(['HOLT6_RD-P1-168_1.fil.tags.tsv', 'COP06_1.fil.tags.tsv', 'GF1_RD-P1-169_1.fil.tags.tsv'])
# TAG COUNTER
# HOLT6_RD-P1-168_1.fil.tags.tsv [59617, 59617, 59617, 59617, 59617, 59617, 59617, 59617]
# TAG COUNTER
# COP06_1.fil.tags.tsv [47815, 47815, 47815, 47815, 47815, 47815, 47815, 47815]
# TAG COUNTER
# GF1_RD-P1-169_1.fil.tags.tsv [51236, 51236, 51236, 51236, 51236, 51236, 51236, 51236]
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_1 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_2 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_3 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_4 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_5 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_6 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_7 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_8 COP06_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_1 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_2 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_3 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_4 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_5 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_6 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_7 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_8 GF1_RD-P1-169_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_1 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_2 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_3 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_4 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_5 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_6 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_7 HOLT6_RD-P1-168_1.fil.tags.tsv
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_8 HOLT6_RD-P1-168_1.fil.tags.tsv
# [23, 29, 25, 36, 35, 27, 59, 13, 34, 33]
# [20, 19, 16, 39, 10, 23, 30, 19, 21, 44]
# [41, 19, 25, 36, 25, 18, 33, 27, 17, 25]
# [23, 26, 25, 21, 26, 23, 28, 20, 32, 30]
# [41, 30, 24, 23, 28, 20, 28, 29, 34, 38]
# [35, 35, 31, 25, 27, 35, 31, 33, 49, 22]
# [41, 19, 25, 36, 25, 18, 33, 27, 17, 25]
# [25, 24, 22, 25, 21, 33, 23, 15, 31, 17]
# [39, 12, 14, 23, 31, 41, 9, 15, 24, 12]
# [15, 25, 33, 21, 31, 28, 38, 9, 43, 23]
# [39, 12, 21, 17, 22, 14, 102, 24, 48, 11]
# [13, 29, 30, 19, 27, 23, 17, 54, 41, 61]
# [15, 40, 14, 23, 31, 41, 9, 15, 24, 12]
# [39, 12, 22, 21, 29, 39, 40, 27, 27, 23]
# [15, 25, 22, 21, 29, 39, 40, 27, 27, 23]
# [15, 12, 14, 47, 19, 35, 44, 53, 32, 26]
# [25, 23, 11, 11, 16, 12, 11, 11, 22, 18]
# [17, 16, 30, 11, 16, 12, 11, 9, 22, 18]
# [28, 23, 11, 10, 11, 17, 20, 22, 14, 10]
# [28, 23, 11, 14, 9, 14, 15, 10, 12, 8]
# [23, 23, 12, 14, 18, 18, 16, 18, 9, 14]
# [17, 12, 18, 11, 16, 12, 11, 9, 22, 18]
# [10, 17, 14, 19, 16, 13, 27, 59, 9, 10]
# [17, 15, 11, 22, 29, 18, 9, 20, 22, 15]
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_1/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_2/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_3/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_4/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_5/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_6/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_7/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/COP06_1.fi/MS_tests/MS_8/COP06_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_1/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_2/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_3/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_4/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_5/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_6/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_7/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fi/MS_tests/MS_8/GF1_RD-P1-169_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_1/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_2/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_3/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_4/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_5/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_6/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_7/HOLT6_RD-P1-168_1.fil Coverage data.txt
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fi/MS_tests/MS_8/HOLT6_RD-P1-168_1.fil Coverage data.txt
# number of coverage plots = 24
# sample names =
# set(['COP06', 'GF1', 'HOLT6'])
# COP06
# [29.9, 29.9, 29.9, 29.9, 29.9, 29.79, 29.88, 29.89]
# GF1
# [29.35, 29.82, 29.84, 29.85, 29.85, 29.85, 29.85, 29.86]
# HOLT6
# [17.95, 18.21, 18.23, 18.24, 18.24, 18.24, 18.24, 18.24]

# %% [markdown]
# ### On the basis of the above results, decide on the Ustacks parameters to use here, and then run cstacks using these for use in Incremental_C

# %%
def Final_Ustacks_command(M_value, m_value, parent_dir_path):
       
## Define execute function ##
        
    def execute(bash_file):
        f = open(str(bash_file), 'r')
        script = f.read()
        subprocess.call(script, shell=True)
        print script
    
## Get files ##
    
    sample_names = []
    
    for i in os.listdir(parent_dir_path):
        if i.endswith(".fq_1") or i.endswith("1.fastq"): 
            sample_names.append(i)
    
    print ("Parameter values: M ="+str(M_value)+" m ="+str(m_value)+"\n")
    
## Write file ##

    f = open(str(parent_dir_path +"Final_Ustacks_commands.sh"), 'w') ## .. make a bash script file in the current ipython directory...
    f.write("#!/bin/bash\n\nmkdir "+ parent_dir_path + "Final_Ustacks_outputs/ \n") 
    
    Sample_ID = 1
    for sample in sample_names: ## so for each sample ...
        final_command_list = []
        f.write('ustacks -t fastq -M '+str(M_value)+' -m '+str(m_value)+' -p 8 -d -r -i '+str(Sample_ID)+' -f '+ str(parent_dir_path) + str(sample)+' -o '+ str(parent_dir_path) + 'Final_Ustacks_outputs/ \n')    
        Sample_ID += 1
        print (sample.split("_")[0]+" ID = "+str(Sample_ID))
    f.close()
    
## Execute the scripts
    execute(str(parent_dir_path +"Final_Ustacks_commands.sh"))

# %%
Final_Ustacks_command(8,8,'/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_V3/Incremental_tests/Batch_2/all_cru/')

# %%
## batch final ustacks

for root, dirs, files in os.walk("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs/"):
    for dir in dirs:
        if "TESTDIR" in dir and not "CRU_GIB_TESTDIR_3" in dir and not "CRU_CYP_TESTDIR_1" in dir:
            parent_dir = root+"/"+dir
            Final_Ustacks_command(4, 2, str(parent_dir+"/"))
# Out:
# Parameter values: M =4 m =2
#
# EP01 ID = 2
# OU01 ID = 3
# RM32 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/EP01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/OU01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/RM32_RD-P1-179_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_CYP_TESTDIR_2/Final_Ustacks_outputs/
#
# Parameter values: M =4 m =2
#
# DEND3 ID = 2
# POLEN4 ID = 3
# VIKKHY2 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/DEND3_RD-P1-130_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/POLEN4_RD-P1-105_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/VIKKHY2_RD-P1-155_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_1/Final_Ustacks_outputs/
#
# Parameter values: M =4 m =2
#
# TU3 ID = 2
# VIKKHY4 ID = 3
# VIKKHY6 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/TU3_RD-P1-108_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/VIKKHY4_RD-P1-181_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/VIKKHY6_RD-P1-109_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GIB_TESTDIR_2/Final_Ustacks_outputs/
#
# Parameter values: M =4 m =2
#
# BF04 ID = 2
# GBP19 ID = 3
# HOLT14 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/BF04_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/GBP19_RD-P1-167_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/HOLT14_RD-P1-157_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_1/Final_Ustacks_outputs/
#
# Parameter values: M =4 m =2
#
# FM01 ID = 2
# FM05 ID = 3
# GF2 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/FM01_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/FM05_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/GF2_RD-P1-193_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_2/Final_Ustacks_outputs/
#
# Parameter values: M =4 m =2
#
# COP06 ID = 2
# GF1 ID = 3
# HOLT6 ID = 4
# #!/bin/bash
#
# mkdir /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 1 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/COP06_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 2 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/GF1_RD-P1-169_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/Final_Ustacks_outputs/
# ustacks -t fastq -M 4 -m 2 -p 8 -d -r -i 3 -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/HOLT6_RD-P1-168_1.fil.fq_1 -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/Thesis_Incremental_runs//CRU_GOLD_TESTDIR_3/Final_Ustacks_outputs/
