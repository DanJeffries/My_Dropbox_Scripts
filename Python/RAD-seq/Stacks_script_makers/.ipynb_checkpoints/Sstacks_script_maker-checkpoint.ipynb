# %%
# Make sstacks scripts

import os
import sys

## Check usage 

if len(sys.argv) < 6:
    print "NOT ENOUGH ARGUMENTS\nUsage<\nUstacks_scriptmaker.py <sctacks_script> <path to input files> <outputdir>  <threads> <sample identifier>"

cstacks_script ='%s/' %(sys.argv[1])
inpath = '%s/' %(sys.argv[2])
outpath='%s/' %(sys.argv[3])
threads = '%s' %(sys.argv[4])
sample_identifier = '%s' %(sys.argv[5])


catalog_samples = []

f = open(cstacks_script, 'r') ## Use catalog making script
for thing in f.readlines()[2].split():
    if sample_identifier in thing:
        catalog_samples.append(thing)
        print thing

#### Make the sstacks scripts ####

nf = open(outpath+"/Sstacks_scripts.sh', 'w')
nf.write('#! /bin/bash\n')
for sample in catalog_samples:
    nf.write('sstacks -b 1 -c /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/batch_1 -s ' +sample+" -p +"threads+" -o /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/; \n")
nf.close()
# Out:
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF04_1.fil-BWA-8M-uniq
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF05_1.fil-BWA-8M-uniq
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF06_1.fil-BWA-8M-uniq
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF08_1.fil-BWA-8M-uniq
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF09_1.fil-BWA-8M-uniq
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/selection_study/BF10_1.fil-BWA-8M-uniq
# ...
