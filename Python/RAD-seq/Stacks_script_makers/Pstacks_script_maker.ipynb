# %%
import os

# %%
def pstacks_script_maker(sam_directory):
    f = open(sam_directory+"pstacks_scripts.sh", 'w')
    f.write('#!bin/bash\n')
    for root, dirs, files in os.walk(sam_directory):
        ID = 1
        for fil in files:
            if 'uniq' in fil and 'fil' in fil and 'bai' not in fil and 'bam' not in fil:
                print 'gzip -d '+sam_directory+fil+' ; pstacks -t sam -f '+sam_directory+fil[:-3]+' -o ./pstacks_all/ -i '+str(ID)+' -m 8 -p 7 \n'
                f.write('gzip -d '+sam_directory+fil+' ; pstacks -t sam -f '+sam_directory+fil[:-3]+' -o ./pstacks_all/ -i '+str(ID)+' -m 8 -p 7 \n')
                ID += 1
        print ID
                
                
            
pstacks_script_maker('/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/')
# Out:
# gzip -d /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/BF04_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/BF04_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 1 -m 8 -p 7
#
# gzip -d /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/BF05_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_analyses_TRIMMED/With_reference/Data_links/BF05_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 2 -m 8 -p 7
#
# ...

# %%
def pstacks_script_maker(bam_directory2):
    f = open('./pstacks_scripts.sh', 'a')
    for root, dirs, files in os.walk(bam_directory2):
        ID = 128
        for fil in files:
            if 'uniq' in fil and 'bai' not in fil and 'bam' not in fil:
                print 'gzip -d '+bam_directory2+fil+' ; pstacks -t sam -f '+bam_directory2+fil[:-3]+' -o ./pstacks_all/ -i '+str(ID)+' -m 10 -p 7 \n'
                f.write('gzip -d '+bam_directory2+fil+' ; pstacks -t sam -f '+bam_directory2+fil[:-3]+' -o ./pstacks_all/ -i '+str(ID)+' -m 10 -p 7 \n')
                ID += 1
                
                
            
pstacks_script_maker('./BWA_mapping_batch2/')
# Out:
# gzip -d ./BWA_mapping_batch2/BF04_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF04_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 128 -m 10 -p 7
#
# gzip -d ./BWA_mapping_batch2/BF05_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF05_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 129 -m 10 -p 7
#
# gzip -d ./BWA_mapping_batch2/BF06_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF06_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 130 -m 10 -p 7
#
# gzip -d ./BWA_mapping_batch2/BF09_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF09_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 131 -m 10 -p 7
#
# gzip -d ./BWA_mapping_batch2/BF10_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF10_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 132 -m 10 -p 7
#
# gzip -d ./BWA_mapping_batch2/BF11_1.fil-BWA-8M-uniq.sam.gz ; pstacks -t sam -f ./BWA_mapping_batch2/BF11_1.fil-BWA-8M-uniq.sam -o ./pstacks_all/ -i 133 -m 10 -p 7
# ...

# %%
# !pwd
# Out:
# /media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Stacks/Stacks_with_ref
