# %% [markdown]
# ## Get the data

# %%
###### Getting gene models from BLAST mapping ######

## First, because in the genome file, each scaff has two names, their index and the ENA ID
## I need to get corresponding ID's. The "Scaffold_names.txt" file below is simlpy the headers 
## for each scaffold grepped from the genome fasta. 

Local_draft_Scaffolds = open("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Common_carp_genome/Xu_et_al_2014_Nature_version/Scaffold_names.txt", 'r').readlines()

## Next load the mapping locations for my mapping of BAYENV winners to the XU et al genome "PRJEB7241_all.fasta"
BAYENV_winners_raw = open("/home/dan/RAD_programs/BAYENV/bayenv_release/bottlenecked/Winning_loci_BLAST_XU/Winning_Vs_XU_BLAST.out", 'r')

## Finally get their gff file, which contains the locations of the transcripts that they have mapped onto the genome.
#Gff_scaffolds = open("./V1_gff_scaffs.txt", 'r').readlines()

gff = open("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Common_carp_genome/Xu_et_al_2014_Nature_version/genemodels/V1.0.gff").readlines()

### Using the above, I can retrieve the ID's of the nearest transcript to the locations that my BAYENV winners mapped to

# %% [markdown]
# ## So first, get the highest quality mappings from the Blast mapping file

# %%
## In blast output - Column 4 contains the length of the alignment
## my sequences are 92 bp, so I want everything that is has an alignment length of above 89 (got this from a quick histogram)

## I want to keep the Stacks locus ID, the scaffold ID and the mapping coordinate

Bayenv_winners_IDs = [] ## contains tuples of locus ID, the scaffold ID and the mapping start coordinate

for line in BAYENV_winners_raw:
    if int(line.split()[3]) >= 85:
        Bayenv_winners_IDs.append((line.split()[0], line.split()[1].split('|')[1], line.split()[8]))

print "Number of High quality alignments = ", len(Bayenv_winners_IDs)

        
print "SNP locus\t", "Scaffold\t", "map_start_coord"
for winner in Bayenv_winners_IDs:
    print winner
    


### Note - all e values are extremely low, so I have only used an alignment length cut off here
# Out:
# Number of High quality alignments =  92
# SNP locus	Scaffold	map_start_coord
# ('Loc_3830', 'LN590690', '9575807')
# ('Loc_10953', 'LN590675', '2752815')
# ('Loc_10953', 'LN591056', '209479')
# ('Loc_10953', 'LN591056', '211693')
# ('Loc_10953', 'LN591056', '206508')
# ('Loc_10953', 'LN590708', '1586214')
# ('Loc_12163', 'LN591245', '2441378')
# ('Loc_12163', 'LN591245', '2575860')
# ('Loc_12163', 'LN591137', '1685916')
# ('Loc_12163', 'LN594326', '13461')
# ('Loc_12163', 'LN593719', '83810')
# ('Loc_12163', 'LN593719', '85199')
# ('Loc_12163', 'LN590700', '13701189')
# ('Loc_12163', 'LN590700', '11380980')
# ('Loc_12163', 'LN591213', '108160')
# ('Loc_12163', 'LN590791', '783144')
# ('Loc_12163', 'LN590715', '280729')
# ('Loc_12163', 'LN590711', '18728635')
# ('Loc_12163', 'LN590698', '5485816')
# ('Loc_12163', 'LN590698', '5485500')
# ('Loc_12163', 'LN590686', '11693770')
# ('Loc_12163', 'LN590673', '14423917')
# ('Loc_12163', 'LN598180', '185066')
# ('Loc_12163', 'LN596352', '562495')
# ('Loc_12163', 'LN590672', '7573809')
# ('Loc_12163', 'LN599544', '39069')
# ('Loc_12163', 'LN599544', '39460')
# ('Loc_12163', 'LN590691', '6417820')
# ('Loc_12163', 'LN590690', '14326697')
# ('Loc_12163', 'LN590690', '14326936')
# ('Loc_12163', 'LN596391', '410047')
# ('Loc_12163', 'LN595066', '105897')
# ('Loc_12163', 'LN592971', '30084')
# ('Loc_12163', 'LN592971', '30675')
# ('Loc_12163', 'LN590675', '14695561')
# ('Loc_12163', 'LN594771', '75940')
# ('Loc_12163', 'LN590713', '8294778')
# ('Loc_12163', 'LN598385', '776105')
# ('Loc_12163', 'LN594965', '676990')
# ('Loc_14537', 'LN590678', '2680699')
# ('Loc_16493', 'LN595627', '82452')
# ('Loc_17869', 'LN595117', '127765')
# ('Loc_19746', 'LN590697', '965583')
# ('Loc_23819', 'LN590677', '5203238')
# ('Loc_23819', 'LN590701', '8709127')
# ('Loc_24793', 'LN595835', '2647')
# ('Loc_24793', 'LN595835', '51681')
# ('Loc_25642', 'LN590711', '2286836')
# ('Loc_25642', 'LN590709', '17829600')
# ('Loc_25642', 'LN590691', '7539873')
# ('Loc_25642', 'LN593280', '1575')
# ('Loc_25642', 'LN599339', '50426')
# ('Loc_25642', 'LN599054', '2257')
# ('Loc_26740', 'LN591071', '495339')
# ('Loc_26740', 'LN591071', '455955')
# ('Loc_27195', 'LN590706', '16784767')
# ('Loc_28256', 'LN590848', '271163')
# ('Loc_28256', 'LN590703', '567270')
# ('Loc_28256', 'LN590969', '353228')
# ('Loc_28256', 'LN591003', '659244')
# ('Loc_28256', 'LN591083', '308901')
# ('Loc_28256', 'LN590692', '21280916')
# ('Loc_28256', 'LN590692', '1515067')
# ('Loc_28256', 'LN598175', '751923')
# ('Loc_28256', 'LN590704', '14188943')
# ('Loc_28256', 'LN598389', '775399')
# ('Loc_28256', 'LN592442', '58104')
# ('Loc_28256', 'LN592946', '108429')
# ('Loc_28256', 'LN590708', '10796572')
# ('Loc_29606', 'LN591186', '372675')
# ('Loc_31772', 'LN590692', '10757674')
# ('Loc_31772', 'LN591568', '20319')
# ('Loc_31772', 'LN590682', '7552333')
# ('Loc_31772', 'LN590688', '875465')
# ('Loc_31772', 'LN596191', '21652')
# ('Loc_31772', 'LN595916', '167682')
# ('Loc_31772', 'LN592896', '1232241')
# ('Loc_31772', 'LN590696', '15574002')
# ('Loc_31772', 'LN590687', '7922948')
# ('Loc_31772', 'LN590686', '2784149')
# ('Loc_31772', 'LN590686', '23395907')
# ('Loc_31772', 'LN590909', '578431')
# ('Loc_31772', 'LN590706', '13149889')
# ('Loc_31772', 'LN590693', '7391346')
# ('Loc_31772', 'LN591285', '411291')
# ('Loc_31772', 'LN596709', '1543258')
# ('Loc_31772', 'LN590712', '11734703')
# ('Loc_31772', 'LN591218', '134692')
# ('Loc_31772', 'LN591230', '723802')
# ('Loc_35158', 'LN590681', '4144036')
# ('Loc_39935', 'LN590716', '5575683')
# ('Loc_39935', 'LN590700', '5412790')

# %% [markdown]
# ## Then get the other ID for each scaffold, ie, the ID Xu et al used in their transcriptome mapping

# %%
Bayenv_winner_scaffs = [("STACKS_ID", "XU_scaff_ID", "Map_start_coord")]

for a,b,c in Bayenv_winners_IDs:
    for scaff in Local_draft_Scaffolds:
        if b == scaff.split("|")[1]:
            Bayenv_winner_scaffs.append((a, scaff.split()[-1], c))
print "Bayenv_winner_scaffs"
for winner in Bayenv_winner_scaffs:
    print winner

## so this tuple contains [0] my RAD locus ID, [1] XU et al scaff names, [0] location that my BAYENV winners map on each scaffold
# Out:
# Bayenv_winner_scaffs
# ('STACKS_ID', 'XU_scaff_ID', 'Map_start_coord')
# ('Loc_3830', 'LG31', '9575807')
# ('Loc_10953', 'LG44', '2752815')
# ('Loc_10953', '000001451', '209479')
# ('Loc_10953', '000001451', '211693')
# ('Loc_10953', '000001451', '206508')
# ('Loc_10953', 'LG39', '1586214')
# ('Loc_12163', '000029034', '2441378')
# ('Loc_12163', '000029034', '2575860')
# ('Loc_12163', '000028849', '1685916')
# ('Loc_12163', '000002192', '13461')
# ('Loc_12163', '000008386', '83810')
# ('Loc_12163', '000008386', '85199')
# ('Loc_12163', 'LG10', '13701189')
# ('Loc_12163', 'LG10', '11380980')
# ('Loc_12163', '000028979', '108160')
# ('Loc_12163', '000000268', '783144')
# ('Loc_12163', 'LG46', '280729')
# ('Loc_12163', 'LG40', '18728635')
# ('Loc_12163', 'LG17', '5485816')
# ('Loc_12163', 'LG17', '5485500')
# ('Loc_12163', 'LG35', '11693770')
# ('Loc_12163', 'LG45', '14423917')
# ('Loc_12163', '000002615', '185066')
# ('Loc_12163', '000000095', '562495')
# ('Loc_12163', 'LG37', '7573809')
# ('Loc_12163', '000008011', '39069')
# ('Loc_12163', '000008011', '39460')
# ('Loc_12163', 'LG8', '6417820')
# ('Loc_12163', 'LG31', '14326697')
# ('Loc_12163', 'LG31', '14326936')
# ('Loc_12163', '000000571', '410047')
# ('Loc_12163', '000002484', '105897')
# ('Loc_12163', '000001951', '30084')
# ('Loc_12163', '000001951', '30675')
# ('Loc_12163', 'LG44', '14695561')
# ('Loc_12163', '000000122', '75940')
# ('Loc_12163', 'LG20', '8294778')
# ('Loc_12163', '000000818', '776105')
# ('Loc_12163', '000001460', '676990')
# ('Loc_14537', 'LG28', '2680699')
# ('Loc_16493', '000002832', '82452')
# ('Loc_17869', '000002563', '127765')
# ('Loc_19746', 'LG15', '965583')
# ('Loc_23819', 'LG7', '5203238')
# ('Loc_23819', 'LG1', '8709127')
# ('Loc_24793', '000002231', '2647')
# ('Loc_24793', '000002231', '51681')
# ('Loc_25642', 'LG40', '2286836')
# ('Loc_25642', 'LG5', '17829600')
# ('Loc_25642', 'LG8', '7539873')
# ('Loc_25642', '000002219', '1575')
# ('Loc_25642', '000004822', '50426')
# ('Loc_25642', '000006179', '2257')
# ('Loc_26740', '000001625', '495339')
# ('Loc_26740', '000001625', '455955')
# ('Loc_27195', 'LG36', '16784767')
# ('Loc_28256', '000000489', '271163')
# ('Loc_28256', 'LG6', '567270')
# ('Loc_28256', '000000980', '353228')
# ('Loc_28256', '000001102', '659244')
# ('Loc_28256', '000001783', '308901')
# ('Loc_28256', 'LG33', '21280916')
# ('Loc_28256', 'LG33', '1515067')
# ('Loc_28256', '000028822', '751923')
# ('Loc_28256', 'LG14', '14188943')
# ('Loc_28256', '000001469', '775399')
# ('Loc_28256', '000011073', '58104')
# ('Loc_28256', '000000934', '108429')
# ('Loc_28256', 'LG39', '10796572')
# ('Loc_29606', '000028926', '372675')
# ('Loc_31772', 'LG33', '10757674')
# ('Loc_31772', '000004498', '20319')
# ('Loc_31772', 'LG21', '7552333')
# ('Loc_31772', 'LG48', '875465')
# ('Loc_31772', '000001852', '21652')
# ('Loc_31772', '000011067', '167682')
# ('Loc_31772', '000028830', '1232241')
# ('Loc_31772', 'LG32', '15574002')
# ('Loc_31772', 'LG13', '7922948')
# ('Loc_31772', 'LG35', '2784149')
# ('Loc_31772', 'LG35', '23395907')
# ('Loc_31772', '000000762', '578431')
# ('Loc_31772', 'LG36', '13149889')
# ('Loc_31772', 'LG3', '7391346')
# ('Loc_31772', '000001455', '411291')
# ('Loc_31772', '000029020', '1543258')
# ('Loc_31772', 'LG2', '11734703')
# ('Loc_31772', '000028985', '134692')
# ('Loc_31772', '000029009', '723802')
# ('Loc_35158', 'LG47', '4144036')
# ('Loc_39935', 'LG41', '5575683')
# ('Loc_39935', 'LG10', '5412790')

# %% [markdown]
# ## Finally:
# - Get the transcripts from each scaffold, within a set distance from where my SNP locus maps
# - Output this, along with all of the information above into a file

# %%
Bayenv_GMs = open("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Common_carp_genome/Xu_et_al_2014_Nature_version/genemodels/Bayenv_BOTTLENECKED_winners_gene_models_1kb_LBs_85bp_alignment_length.txt", 'w')

Bayenv_GMs.write("##STACKS_ID\tSTACKS_loc_mapping_Start\tXU_scaff_ID\tTranscript_name\tTranscript_mapping_start\tSwiss-Prot_function\n")  ## Headers
for a,b,c in Bayenv_winner_scaffs[1:]:
    for line in gff:
        if b == line.split()[0] and (int(c)-1000) <= int(line.split()[3]) <= (int(c)+1000): ## this is where I am controlling the size of my linkage blocks . . .
            ## Get the GO functions from the Swissprot output
            swissprot = open("/media/dan/34D5D1CE642D7E36/2013076_Hanfling_Bernd/Common_carp_genome/Xu_et_al_2014_Nature_version/genemodels/Commoncarp_swissprot.alignment", 'r').readlines()
            for swissline in swissprot:
                if line.split()[8] == swissline.split()[0]:
                    swiss_func = swissline.split()[11:]
            Bayenv_GMs.write(a+"\t"+str(c)+"\t"+line.split()[0]+"\t"+line.split()[8]+"\t"+str(line.split()[3])+"\t"+" ".join(swiss_func)+"\n")
Bayenv_GMs.close()
