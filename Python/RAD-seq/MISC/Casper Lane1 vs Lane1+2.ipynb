# %%
import MISC_RAD_tools as MISC
% matplotlib inline

# %% [markdown]
# ## LANE 1 ONLY

# %%
popmap_N73 = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/popmap_N73.txt"
popmap_N83 = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/popmap_N83.txt"

vcf_N73_no_maf = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/populations_N73_no_minmaf/batch_1.vcf"
vcf_N73_maf = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/populations_N73_with_minmaf/batch_1.vcf"
vcf_N83_no_maf = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/populations_N83_no_minmaf/batch_1.vcf"
vcf_N83_maf = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/populations_N83_with_minmaf/batch_1.vcf"

# %%
## N73 no maf
vcf_file = vcf_N73_no_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  4380
# Average tag coverage 30.0037905798 (+- 23.4041008294 )
# Mean sample coverage = 30.0 (+/21.48)

# %%
## N73 with maf
vcf_file = vcf_N73_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  921
# Average tag coverage 46.6940341796 (+- 34.8670939776 )
# Mean sample coverage = 46.68 (+/30.66)

# %%
## N83 no maf
vcf_file = vcf_N83_no_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  4573
# Average tag coverage 30.576943242 (+- 22.9650339731 )
# Mean sample coverage = 30.57 (+/21.7)

# %%
## N83 with maf
vcf_file = vcf_N83_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  898
# Average tag coverage 47.7876942067 (+- 33.9608058142 )
# Mean sample coverage = 47.77 (+/31.74)

# %% [markdown]
# ## LANE 1 and 2

# %%
popmap_N73 = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/popmap_N73.txt"
popmap_N83 = "/home/djeffrie/Data/Caspers_data/Lane1_vs_Lane1_2/popmap_N83.txt"

vcf_N73_no_maf = "/home/djeffrie/Data/Caspers_data/2lanes/Stacks_outs/Populations_1lane_vs_2lanes_test/N73_no_maf/batch_2.vcf"
vcf_N73_maf = "/home/djeffrie/Data/Caspers_data/2lanes/Stacks_outs/Populations_1lane_vs_2lanes_test/N73_with_maf/batch_2.vcf"
vcf_N83_no_maf = "/home/djeffrie/Data/Caspers_data/2lanes/Stacks_outs/Populations_1lane_vs_2lanes_test/N83_no_maf/batch_2.vcf"
vcf_N83_maf = "/home/djeffrie/Data/Caspers_data/2lanes/Stacks_outs/Populations_1lane_vs_2lanes_test/N83_with_maf/batch_2.vcf"

# %%
## N73 no maf
vcf_file = vcf_N73_no_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  10252
# Average tag coverage 40.9168648683 (+- 26.903198932 )
# Mean sample coverage = 40.9 (+/26.26)

# %%
## N73 with maf
vcf_file = vcf_N73_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  1491
# Average tag coverage 59.7564381724 (+- 44.5510887181 )
# Mean sample coverage = 59.68 (+/36.37)

# %%
## N83 no maf
vcf_file = vcf_N83_no_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  10866
# Average tag coverage 41.6708590297 (+- 27.1615408368 )
# Mean sample coverage = 41.66 (+/26.71)

# %%
## N83 with maf
vcf_file = vcf_N83_maf
outfile = "%s.Av_tag_covs.out" % vcf_file

MISC.av_tag_cov(vcf_file, outfile)
MISC.sample_Avcov_from_vcf(vcf_file)
# Out:
# Number of tags =  1449
# Average tag coverage 61.7365362069 (+- 45.8825842965 )
# Mean sample coverage = 61.65 (+/37.91)
