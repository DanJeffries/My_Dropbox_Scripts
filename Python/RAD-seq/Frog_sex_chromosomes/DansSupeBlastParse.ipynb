# %%
from __future__ import division
import sys
import os
from Bio.Blast import NCBIXML
from Bio import SeqIO

# %%
## Cline args

if len(sys.argv) == 1:
    
    print DansBlastParse.__doc__
    
elif len(sys.argv) < 4: ## If not enough args are supplied print error message
    sys.exit("\n##Error, not enough arguments, run script with no arguments to see help message\n")

elif len(sys.argv) == 4:
    in_path = sys.argv[1]
    muti_hit_criteria = float(sys.argv[2])
    Eval = float(sys.argv[3])


    DansBlastParse(in_path, muti_hit_criteria, Eval) ## RUN!

# %%
def DansSuperBlastParse(blast_xml_output, best_hit_criteria, Eval_thresh):
    """
    
    Usage: BlastParseExtra.py  <blast_xml_output>  <best_hit_criteria>  <Evalue_threshold>
    
    <blast_xml_output>  -  Path should be absolute
    <best_hit_criteria> -  Orders of magnitude higher that best hit has to be in multi
    <Evalue_threshold>  -  (1e-20 is default)
    
    
    This script first filters the mappings in the <blast_xml_output>, for only those where the
    best hit is at least 5 orders of magnitude higher than the second.
    
    It will then retrieve a segment of the <genome_fasta> which is + and - the <window_size> around the 
    mapping coordinates for each query. If the ends of the scaffold are not within this window, then the 
    length of the segment will be (length of mapped query sequence + 2 x <window_size>). However if an end
    of a scaffold is within this window, the segment will be trimmed to this length.
    
    """

    blast = NCBIXML.parse(open(blast_xml_output,"r"))

    good_blast_counts = 0
    uniq_counts = 0
    
    ## From Alan's script: Returns blast hits only when the best e-value is 5 orders of magnitude better than the second best.
    for record in blast :
        #print len(record.alignments)
        if len(record.alignments)==1:  ## Extra else statement - this wasn't in Alan's original script.
            if float(record.alignments[0].hsps[0].expect) < Eval_thresh:
                subject = str(record.alignments[0].hit_def)
                Evalue = float(record.alignments[0].hsps[0].expect)
                Hit_start_coord = int(record.alignments[0].hsps[0].sbjct_start)
                Hit_end_coord = int(record.alignments[0].hsps[0].sbjct_end)
                print "Unique\t%s\t%s\t%s\t%s\t%s" % (record.query, subject, Evalue, Hit_start_coord, Hit_end_coord)
                good_blast_counts += 1
                uniq_counts += 1
        
        
        elif len(record.alignments)>1:
            
            if all([record.alignments[0].hsps[0].expect <= Eval_thresh, record.alignments[0].hsps[0].expect < best_hit_criteria * record.alignments[1].hsps[0].expect]):
                
                subject = str(record.alignments[0].hit_def)
                Evalue = float(record.alignments[0].hsps[0].expect)
                Hit_start_coord = int(record.alignments[0].hsps[0].sbjct_start)
                Hit_end_coord = int(record.alignments[0].hsps[0].sbjct_end)
                print "Multi\t%s\t%s\t%s\t%s\t%s" % (record.query, subject, Evalue, Hit_start_coord, Hit_end_coord)
                good_blast_counts += 1

    print "Number of good blast hits:", good_blast_counts
    print "Number of unique mappings:", uniq_counts

# %%
blast_xml_output = "/home/djeffrie/Data/RADseq/Lib_Rjapor/Rjap/Stacks_outs/Population_t_blast_tests/Rjap_t_blast_hits2.xml"

DansSuperBlastParse(blast_xml_output, 1e-5, 1e-20)
# Out:
# Multi	X_linkedLocusID_168605	scaffold67552.1|size38697	2.42484e-36	24306	24396
# Multi	X_linkedLocusID_211519	scaffold89971.1|size51442	2.33573e-33	25735	25824
# Multi	X_linkedLocusID_20905	scaffold63430.1|size26682	2.01087e-21	11163	11240
# Multi	X_linkedLocusID_182157	scaffold364349.1|size8360	3.38376e-26	801	870
# Multi	X_linkedLocusID_10444	scaffold19050.1|size45385	2.08758e-24	15775	15853
# Multi	X_linkedLocusID_193360	scaffold60533.1|size23339	2.01087e-21	20864	20929
# Multi	X_linkedLocusID_225139	scaffold70802.1|size30292	2.2499e-30	20169	20261
# Multi	X_linkedLocusID_12712	scaffold47957.1|size27226	9.22934e-33	5476	5568
# Multi	X_linkedLocusID_88635	scaffold73489.1|size50662	6.13669e-37	45955	46046
# Multi	X_linkedLocusID_194001	scaffold37751.1|size103457	5.48473e-28	36814	36906
# Multi	X_linkedLocusID_211000	scaffold45260.1|size28207	2.2499e-30	24071	24163
# Multi	X_linkedLocusID_201422	scaffold2058.1|size120265	5.08903e-22	46710	46787
# Multi	X_linkedLocusID_15527	scaffold68939.1|size20979	2.2499e-30	1366	1457
# Multi	X_linkedLocusID_209964	scaffold13411.1|size59948	8.24881e-24	37237	37338
# Multi	X_linkedLocusID_151664	scaffold17094.1|size57481	5.48473e-28	4282	4374
# Multi	X_linkedLocusID_159366	scaffold109052.1|size22722	3.93041e-38	8091	8180
# Multi	X_linkedLocusID_126225	scaffold69731.1|size32183	1.38806e-28	22922	23011
# Multi	X_linkedLocusID_185080	scaffold3436.1|size102107	1.33705e-25	101422	101514
# Multi	X_linkedLocusID_191033	scaffold4678.1|size99130	5.48473e-28	17308	17372
# Multi	X_linkedLocusID_182976	scaffold2116.1|size118135	1.55305e-37	40555	40647
# Multi	X_linkedLocusID_67487	scaffold54161.1|size54816	3.78598e-35	24141	24225
# Multi	X_linkedLocusID_80087	scaffold8866.1|size65089	3.78598e-35	52781	52873
# Multi	X_linkedLocusID_30766	scaffold446152.1|size8126	3.51284e-29	48	126
# Multi	X_linkedLocusID_63472	scaffold104.1|size330442	2.61338e-42	282043	282135
# Multi	X_linkedLocusID_19471	scaffold128765.1|size17471	1.55305e-37	10674	10766
# Multi	X_linkedLocusID_187192	scaffold146750.1|size8545	2.16722e-27	2430	2521
# Multi	X_linkedLocusID_35803	scaffold19902.1|size44394	2.61338e-42	20498	20590
# Multi	X_linkedLocusID_34739	scaffold21363.1|size90070	3.64686e-32	16182	16273
# Multi	X_linkedLocusID_217715	scaffold7706.1|size69394	5.48473e-28	14365	14457
# Multi	X_linkedLocusID_18528	scaffold24480.1|size39949	5.69396e-31	22313	22398
# Multi	X_linkedLocusID_199085	scaffold119896.1|size10775	2.16722e-27	6223	6313
# Multi	X_linkedLocusID_44442	scaffold39835.1|size36197	3.38376e-26	27237	27298
# Multi	X_linkedLocusID_43792	scaffold11959.1|size57247	1.49598e-34	9318	9397
# Multi	X_linkedLocusID_21640	scaffold34924.1|size90056	8.24881e-24	11245	11322
# Multi	X_linkedLocusID_21900	scaffold72920.1|size56778	2.51734e-39	16254	16337
# Multi	X_linkedLocusID_88005	scaffold18985.1|size45465	1.55305e-37	33329	33421
# Multi	X_linkedLocusID_213872	scaffold53819.1|size30960	5.28318e-25	26561	26632
# Multi	X_linkedLocusID_49034	scaffold110506.1|size21312	1.33705e-25	12600	12692
# Multi	X_linkedLocusID_221396	scaffold105538.1|size17034	3.25941e-23	14050	14142
# Multi	X_linkedLocusID_107261	scaffold226213.1|size3667	9.22934e-33	2079	2170
# Multi	X_linkedLocusID_108357	scaffold3259.1|size100479	3.51284e-29	18195	18269
# Multi	X_linkedLocusID_221483	scaffold83072.1|size22736	3.93041e-38	542	631
# Multi	X_linkedLocusID_53629	scaffold10983.1|size82031	1.55305e-37	58975	59067
# Multi	X_linkedLocusID_209217	scaffold1183.1|size148970	5.69396e-31	123409	123498
# Multi	X_linkedLocusID_213229	scaffold15693.1|size50118	7.94568e-21	1735	1817
# Multi	X_linkedLocusID_112404	scaffold120228.1|size18351	1.55305e-37	12000	12092
# Multi	X_linkedLocusID_105627	scaffold10690.1|size62035	3.38376e-26	38170	38260
# Multi	X_linkedLocusID_187420	scaffold53461.1|size33799	5.28318e-25	22829	22920
# Multi	X_linkedLocusID_185157	scaffold39665.1|size30512	5.28318e-25	7371	7463
# Multi	X_linkedLocusID_213950	scaffold86965.1|size30389	3.78598e-35	29913	30005
# Multi	X_linkedLocusID_69906	scaffold53232.1|size53075	1.28792e-22	30411	30499
# Multi	X_linkedLocusID_205099	scaffold150787.1|size25710	7.94568e-21	2375	2442
# Multi	X_linkedLocusID_162973	scaffold46995.1|size32682	1.38806e-28	32015	32110
# Multi	X_linkedLocusID_96625	scaffold5408.1|size80701	1.33705e-25	53443	53535
# Multi	X_linkedLocusID_112495	scaffold872.1|size183544	7.94568e-21	131961	132049
# Multi	X_linkedLocusID_184568	scaffold14619.1|size69974	5.48473e-28	55405	55485
# Multi	X_linkedLocusID_78698	scaffold5025.1|size86228	2.51734e-39	173	264
# Multi	X_linkedLocusID_227077	scaffold3833.1|size93079	3.78598e-35	81157	81249
# Multi	X_linkedLocusID_35882	scaffold114911.1|size11507	1.55305e-37	4883	4975
# Multi	X_linkedLocusID_4449	scaffold72044.1|size20128	2.42484e-36	15712	15802
# Multi	X_linkedLocusID_70005	scaffold189325.1|size4606	1.07204e-44	4252	4344
# Multi	X_linkedLocusID_229958	scaffold82902.1|size22126	2.42484e-36	1302	1392
# Multi	X_linkedLocusID_63549	scaffold45985.1|size27947	9.22934e-33	16347	16439
# Multi	X_linkedLocusID_120966	scaffold41120.1|size73146	2.61338e-42	224	316
# Multi	X_linkedLocusID_149697	scaffold28520.1|size36858	1.28792e-22	23637	23729
# Multi	X_linkedLocusID_60704	scaffold19.1|size536463	1.28792e-22	221162	221233
# Multi	X_linkedLocusID_107332	scaffold1843.1|size125282	2.42484e-36	63529	63615
# Multi	X_linkedLocusID_165306	scaffold51076.1|size56197	2.42484e-36	6254	6344
# Multi	X_linkedLocusID_41447	scaffold121460.1|size25031	9.58143e-36	666	759
# Multi	X_linkedLocusID_230595	scaffold5558.1|size130168	2.08758e-24	47634	47712
# Multi	X_linkedLocusID_200834	scaffold8393.1|size83249	8.89019e-30	44512	44600
# Multi	X_linkedLocusID_221040	scaffold6129.1|size89063	3.38376e-26	16714	16799
# Multi	X_linkedLocusID_169554	scaffold1208.1|size147707	3.78598e-35	28102	28194
# Multi	X_linkedLocusID_24828	scaffold89726.1|size41830	1.49598e-34	32046	32134
# Multi	X_linkedLocusID_197840	scaffold109052.1|size22722	9.22934e-33	8177	8265
# Multi	X_linkedLocusID_15599	scaffold19512.1|size46528	3.78598e-35	46893	46984
# Multi	X_linkedLocusID_117310	scaffold222.1|size268420	2.51734e-39	152878	152961
# Multi	X_linkedLocusID_10603	scaffold51243.1|size33172	6.3708e-40	9024	9116
# Multi	X_linkedLocusID_38178	scaffold11486.1|size57789	1.55305e-37	28762	28854
# Multi	X_linkedLocusID_189167	scaffold1101.1|size161233	3.64686e-32	130915	131013
# Multi	X_linkedLocusID_95712	scaffold874.1|size168738	1.07204e-44	84557	84649
# Multi	X_linkedLocusID_48678	scaffold37400.1|size31567	3.78598e-35	20151	20243
# Multi	X_linkedLocusID_142033	scaffold40529.1|size84130	5.28318e-25	226	301
# Multi	X_linkedLocusID_119152	scaffold120984.1|size17441	5.08903e-22	12533	12614
# Multi	X_linkedLocusID_183673	scaffold84180.1|size77051	3.64686e-32	25906	25985
# Multi	X_linkedLocusID_98902	scaffold120491.1|size44157	2.42484e-36	34045	34131
# Multi	X_linkedLocusID_78354	scaffold522.1|size245039	3.78598e-35	182136	182228
# Multi	X_linkedLocusID_79970	scaffold522.1|size245039	2.61338e-42	119619	119711
# Multi	X_linkedLocusID_129297	scaffold15507.1|size53587	3.78598e-35	30107	30199
# Multi	X_linkedLocusID_200110	scaffold68750.1|size21033	2.08758e-24	20457	20527
# Multi	X_linkedLocusID_80499	scaffold100195.1|size19854	8.89019e-30	4586	4672
# Multi	X_linkedLocusID_13788	scaffold69555.1|size28402	5.91119e-34	20006	20096
# Multi	X_linkedLocusID_225666	scaffold7811.1|size69022	6.3708e-40	34186	34278
# Multi	X_linkedLocusID_12208	scaffold4736.1|size86401	2.2499e-30	2530	2622
# Multi	X_linkedLocusID_217557	scaffold4911.1|size99876	5.08903e-22	64442	64504
# Multi	X_linkedLocusID_85060	scaffold3503.1|size96435	6.3708e-40	85011	85103
# Number of good blast hits: 131
# Number of unique mappings: 0

# %%
blast_xml_output = "/home/djeffrie/Data/RADseq/Lib_Rjapor/Rjap/Stacks_outs/Population_t_blast_tests/Rjap_t_blast_hits2.xml"

blast = NCBIXML.parse(open(blast_xml_output,"r"))
record = blast.next()

# %%
############################################################################################################################################
################### ADD THE FUNCTION TO FIND LOCI WITH 100% ID REGARDLESS OF THE NEXT BEST HIT!! #############################################
#####################################################################################################################################
def find_perfect_hits(record, align_len_thresh, ID_thresh):
    
    
    multiple_good_alignments = {}
    for alignment in record.alignments:
        
        N_aligned_bases = alignment.hsps[0].match.count("|") ## looks at the top HSP which is always the best
        Perc_ID = (alignment.hsps[0].identities/alignment.hsps[0].align_length)*100
        
        #print "Percentage ID=", Perc_ID, "%"
        
        if Perc_ID >= ID_thresh and alignment.hsps[0].align_length >= align_len_thresh:
            print "alignment is perfect", alignment.title, "% Identity =", Perc_ID

# %%
blast = NCBIXML.parse(open(blast_xml_output,"r"))

good_blast_counts = 0
uniq_counts = 0
    
## From Alan's script: Returns blast hits only when the best e-value is 5 orders of magnitude better than the second best.
for record in blast :
    find_perfect_hits(record, 80, 98)
# Out:
# alignment is perfect gnl|BL_ORD_ID|9329 scaffold9330.1|size64118 % Identity = 98.75
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-134-0c0ca55e83fa> in <module>()
#       5
#       6 ## From Alan's script: Returns blast hits only when the best e-value is 5 orders of magnitude better than the second best.
# ----> 7 for record in blast :
#       8     find_perfect_hits(record, 80, 98)
#
# /usr/local/lib/python2.7/dist-packages/Bio/Blast/NCBIXML.pyc in parse(handle, debug)
#     601             if not text:
#     602                 # End of the file!
# --> 603                 expat_parser.Parse("", True)  # End of XML record
#     604                 break
#     605
#
# ExpatError: no element found: line 75711, column 16

# %%
muti_hit_criteria = 1e-5
Eval = 1e-20

parent_dir = "/home/djeffrie/Data/Ribe_LM/"

for root, firs, files in os.walk(parent_dir):
    for fil in files:
        if "Male_L6_Xenchunks_" in fil:
            in_path = "%s%s" % (root,fil)
            print "\nProcessing %s" % (in_path)
            DansBlastParse(in_path, muti_hit_criteria, Eval)
# Out:
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_1000.xml
# Multi	scaffold37.1|size456371	Chr02	3.17932e-59	19134200	19133764
# Unique	scaffold490.1|size258825	Chr03	1.9842e-21	58781379	58781449
# Multi	scaffold5790.1|size82980	Chr03	7.25741e-11	97846769	97846856
# Unique	scaffold11278.1|size59203	Chr04	4.62233e-28	51687691	51687588
# Unique	scaffold79227.1|size18324	Chr03	4.64487e-28	21583106	21582976
# Number of good blast hits: 5
# Number of unique mappings: 3
#
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_500.xml
# Multi	scaffold37.1|size456371	Chr05	4.47788e-15	54673628	54673567
# Multi	scaffold5790.1|size82980	Chr03	3.40915e-11	97846769	97846856
# Number of good blast hits: 2
# Number of unique mappings: 0
#
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_2000.xml
# Unique	scaffold490.1|size258825	Chr03	4.0951e-21	58781379	58781449
# Multi	scaffold5790.1|size82980	Chr03	1.49577e-10	97846769	97846856
# Multi	scaffold29037.1|size50135	Chr10	5.09457e-80	38015018	38015563
# Unique	scaffold79227.1|size18324	Chr03	9.14997e-28	21583106	21582976
# Number of good blast hits: 4
# Number of unique mappings: 2
#
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_100.xml
# Number of good blast hits: 0
# Number of unique mappings: 0
#
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_2500.xml
# Unique	scaffold490.1|size258825	Chr03	5.15108e-21	58781379	58781449
# Multi	scaffold5790.1|size82980	Chr03	1.88099e-10	97846769	97846856
# Multi	scaffold29037.1|size50135	Chr10	6.34939e-80	38015018	38015563
# Unique	scaffold79227.1|size18324	Chr03	1.14037e-27	21583106	21582976
# Number of good blast hits: 4
# Number of unique mappings: 2
#
# Processing /home/djeffrie/Data/Ribe_LM/Male_L6_Xenchunks_1500.xml
# Unique	scaffold490.1|size258825	Chr03	3.03912e-21	58781379	58781449
# Multi	scaffold5790.1|size82980	Chr03	1.11056e-10	97846769	97846856
# Unique	scaffold79227.1|size18324	Chr03	6.89628e-28	21583106	21582976
# Number of good blast hits: 3
# Number of unique mappings: 2

# %%
#### Test args

in_path = "/home/djeffrie/Data/Ribe_LM/Male_LG3_Rtemp_blasthits.xml"
muti_hit_criteria = 1e-5
Eval = 1e-20

DansBlastParse(in_path, muti_hit_criteria, Eval)
# Out:
# Multi	745	scaffold46199.1|size35026	2.99753e-32	34048	34139
# Multi	2711	scaffold93399.1|size15147	8.45302e-23	8301	8233
# Unique	4139	scaffold93399.1|size15147	8.45302e-23	8301	8233
# Unique	5134	scaffold93399.1|size15147	8.45302e-23	8301	8233
# Multi	6126	scaffold311071.1|size1376	6.48852e-29	655	744
# Multi	8038	scaffold3905.1|size92276	1.0705e-36	22990	23080
# Multi	8350	scaffold74752.1|size45057	1.38478e-35	27243	27152
# Multi	8519	scaffold1012.1|size167646	6.44277e-34	51516	51425
# Unique	8771	scaffold1012.1|size167646	6.44277e-34	51516	51425
# Unique	9622	scaffold1012.1|size167646	6.44277e-34	51516	51425
# Multi	12788	scaffold18042.1|size52226	5.05154e-25	44200	44134
# Unique	13609	scaffold18042.1|size52226	5.05154e-25	44200	44134
# Multi	13938	scaffold14468.1|size53227	3.85022e-36	32644	32558
# Multi	14202	scaffold77651.1|size18722	2.9764e-37	8043	8134
# Unique	14313	scaffold77651.1|size18722	2.9764e-37	8043	8134
# Multi	15436	scaffold21629.1|size42593	2.9764e-37	32904	32812
# Multi	15437	scaffold107114.1|size28414	2.9764e-37	19110	19022
# Unique	16365	scaffold107114.1|size28414	2.9764e-37	19110	19022
# Multi	16397	scaffold377419.1|size1115	2.9764e-37	1037	1128
# Unique	16757	scaffold377419.1|size1115	2.9764e-37	1037	1128
# Unique	17271	scaffold377419.1|size1115	2.9764e-37	1037	1128
# Multi	17720	scaffold2664.1|size112525	1.39462e-30	80177	80086
# Unique	19450	scaffold2664.1|size112525	1.39462e-30	80177	80086
# Unique	20197	scaffold2664.1|size112525	1.39462e-30	80177	80086
# Multi	20946	scaffold10444.1|size66534	5.01593e-30	40399	40488
# Multi	21075	scaffold70536.1|size45976	1.82976e-19	44600	44668
# Unique	21121	scaffold70536.1|size45976	1.82976e-19	44600	44668
# Unique	21512	scaffold70536.1|size45976	1.82976e-19	44600	44668
# Multi	21543	scaffold622874.1|size716	1.37502e-40	567	658
# Unique	21559	scaffold622874.1|size716	1.37502e-40	567	658
# Multi	22114	scaffold369864.1|size8290	1.79133e-34	231	320
# Multi	22851	scaffold4647.1|size86116	2.9764e-37	63113	63022
# Unique	24032	scaffold4647.1|size86116	2.9764e-37	63113	63022
# Multi	28102	scaffold418844.1|size1022	1.40452e-25	141	220
# Unique	28449	scaffold418844.1|size1022	1.40452e-25	141	220
# Unique	28563	scaffold418844.1|size1022	1.40452e-25	141	220
# Multi	28710	scaffold2206.1|size119735	1.38478e-35	10788	10879
# Multi	30181	scaffold79227.1|size18324	1.37502e-40	15432	15523
# Unique	31044	scaffold79227.1|size18324	1.37502e-40	15432	15523
# Unique	31207	scaffold79227.1|size18324	1.37502e-40	15432	15523
# Multi	31292	scaffold244449.1|size2179	3.93281e-21	1195	1263
# Multi	31426	scaffold164184.1|size5680	1.41449e-20	4403	4494
# Unique	32029	scaffold164184.1|size5680	1.41449e-20	4403	4494
# Unique	33233	scaffold164184.1|size5680	1.41449e-20	4403	4494
# Multi	33752	scaffold13589.1|size53509	6.44277e-34	28894	28803
# Unique	34352	scaffold13589.1|size53509	6.44277e-34	28894	28803
# Unique	34599	scaffold13589.1|size53509	6.44277e-34	28894	28803
# Multi	35630	scaffold37.1|size456371	5.08741e-20	346983	346917
# Unique	36711	scaffold37.1|size456371	5.08741e-20	346983	346917
# Unique	37116	scaffold37.1|size456371	5.08741e-20	346983	346917
# Unique	37700	scaffold37.1|size456371	5.08741e-20	346983	346917
# Unique	37803	scaffold37.1|size456371	5.08741e-20	346983	346917
# Multi	42431	scaffold17743.1|size102254	6.39736e-39	18631	18722
# Unique	43191	scaffold17743.1|size102254	6.39736e-39	18631	18722
# Unique	43728	scaffold17743.1|size102254	6.39736e-39	18631	18722
# Unique	44004	scaffold17743.1|size102254	6.39736e-39	18631	18722
# Multi	45562	scaffold490.1|size258825	1.37502e-40	147288	147197
# Multi	46046	scaffold25484.1|size39085	1.39462e-30	7193	7102
# Multi	46144	scaffold1584873.1|size216	3.87755e-31	1	87
# Multi	46631	scaffold341905.1|size1235	2.33369e-28	944	1028
# Multi	46721	scaffold3561.1|size95720	1.82976e-19	45259	45352
# Unique	48898	scaffold3561.1|size95720	1.82976e-19	45259	45352
# Multi	50403	scaffold485.1|size209310	6.39736e-39	15151	15242
# Unique	50578	scaffold485.1|size209310	6.39736e-39	15151	15242
# Unique	51169	scaffold485.1|size209310	6.39736e-39	15151	15242
# Multi	51181	scaffold562.1|size199439	2.99753e-32	181996	182087
# Multi	52220	scaffold5208.1|size99709	2.9764e-37	76835	76926
# Multi	52351	scaffold34393.1|size41460	3.85022e-36	920	831
# Multi	52413	scaffold592263.1|size751	1.09347e-21	256	199
# Unique	52644	scaffold592263.1|size751	1.09347e-21	256	199
# Unique	53379	scaffold592263.1|size751	1.09347e-21	256	199
# Multi	53429	scaffold54053.1|size54095	2.99753e-32	8010	7919
# Unique	53988	scaffold54053.1|size54095	2.99753e-32	8010	7919
# Unique	55560	scaffold54053.1|size54095	2.99753e-32	8010	7919
# Unique	55853	scaffold54053.1|size54095	2.99753e-32	8010	7919
# Multi	56243	scaffold1012.1|size167646	1.38478e-35	144691	144782
# Multi	56630	scaffold135184.1|size15778	1.40452e-25	8444	8514
# Multi	56854	scaffold1347143.1|size247	2.99753e-32	227	145
# Unique	56883	scaffold1347143.1|size247	2.99753e-32	227	145
# Multi	58079	scaffold1092077.1|size317	1.38478e-35	317	226
