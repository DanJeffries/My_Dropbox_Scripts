# %% [markdown]
# # This notebook contains the Stacks parameter tests, final scripts used and analyses to identify sex linked markers for the ddRADseq dataset of <i>Hyla orientalis</i>
# ## Sample set:
#
# This sample set is big and consists of 13 populations.
#
#       N Pop
#       5 AB
#       5 DidM
#      27 HLi
#      11 loc01
#      16 loc11
#      18 loc14
#       7 loc21
#      14 loc22
#      17 loc32
#      19 loc34
#      11 MNK
#       8 THM
#       5 Y

# %%
# %matplotlib inline
from __future__ import division
import os
import Incremental_U as IncU 
import Incremental_C as IncC
import Incremental_Pop_mod as IncPop
import MISC_RAD_tools as MISC
import pprint
import subprocess

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# ### First check the quality of the data and remove any bad samples which would bring the total number of loci in the dataset down.

# %%
wd = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all"

blacklist = MISC.missing_data_finder("%s/batch_1.vcf" % wd, wd)
# Out:
# Outputs written to:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all/Tag_dropouts_per_sample.txt
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all/Tag_dropouts_per_tag.txt
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all/Tag_dropouts_per_sample.pdf
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all/Tag_dropouts_per_tag.pdf
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all/blacklist.txt

# %% [markdown]
# Ok nice! So there are only two bad samples really, the rest look really good! This shouldn't have a big effect on the data. There aren't many loci share between all populations but this might be down to biological divergence as opposed to library preparation or data filtering
# ### ASK Chris

# %% [markdown]
# ### Now run a PCA to look at the structure in the data . . .

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/batch_1.vcf > $wd/batch_1_altered_adegenet.vcf
#
# /home/djeffrie/Programs/plink_linux_x86_64/plink --vcf $wd//batch_1_altered_adegenet.vcf --recode A --allow-extra-chr -out $wd//batch_1_altered_adegenet_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink-temporary.fam
# written.
# 3102 variants loaded from .bim file.
# 158 people (0 males, 0 females, 158 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 158 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.953183.
# 3102 variants and 158 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all//batch_1_altered_adegenet_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.txt")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_all")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('batch_1_altered_adegenet_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("popmap_kept.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
#
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "H. orientalis population structure using 3102 SNPs", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(13), ## Colours to use
#            func_cex = 5) ## Size of points and text in plots)

# %% [markdown]
# A few samples that are intermediate of the main clusters were removed as they had low data quality and populations was re-run again using more detailed population information.
#
# Removing low quality samples increased the number of loci kept in the dataset to 9366!

# %%
wd = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept/"

blacklist = MISC.missing_data_finder("%s/batch_1.vcf" % wd, wd)
# Out:
# Outputs written to:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//Tag_dropouts_per_sample.txt
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//Tag_dropouts_per_tag.txt
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//Tag_dropouts_per_sample.pdf
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//Tag_dropouts_per_tag.pdf
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//blacklist.txt

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/batch_1.vcf > $wd/batch_1_altered_adegenet.vcf
#
# /home/djeffrie/Programs/plink_linux_x86_64/plink --vcf $wd//batch_1_altered_adegenet.vcf --recode A --allow-extra-chr -out $wd//batch_1_altered_adegenet_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink-temporary.fam
# written.
# 9366 variants loaded from .bim file.
# 155 people (0 males, 0 females, 155 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 155 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.896151.
# 9366 variants and 155 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept//batch_1_altered_adegenet_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.txt")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_kept")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('batch_1_altered_adegenet_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("popmap_kept.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.
#
#
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
#
# source("/home/djeffrie/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.R")
#
# sexes <- read.delim("popmap_kept.txt", header = F)
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "H. orientalis population structure using 9366 SNPs", ## plot title
#            xtitle = "PC1", ## X axis title:
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(21), ## Colours to use
#            func_cex = 4,
#            leg_title = "Populations") ## Size of points and text in plots)

# %% [markdown]
# ## Finding sex linked markers for Clades 1 and 2 (the cluster at the top of the above PCA)

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clades_C1_C2/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clades_C1_C2/Sex_ID_info_C1_C2.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.6 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
C1_C2_XYset, C1_C2_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 35334
# Number of samples = 44
# Number of loci with too few samples = 25548
# Number of loci with low MAF = 589
# Number of loci with enough data = 9196
# Number of putative X linked snps = 5
# Number of putative X linked tags = 5
# Number of putative Z linked markers = 2
# Number of putative Z linked tags = 2
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 35334
# Number of samples = 44
# Number of loci with too few samples = 26133
# Number of loci with low MAF = 4
# Number of loci with enough data = 9196
# Number of putative X linked snps = 11
# Number of putative X linked tags = 11
# Number of putative Z linked markers = 1
# Number of putative Z linked tags = 1
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of males: 24
# Number of males: 20
# Number of Putative Y linked tags: 4
# Number of Putative W linked tags: 2
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Hori/Stacks_new
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 17
# Final number of ZW tags = 5

# %% [markdown]
# ###So there are very few sex linked markers found here. Now going to try without Clade C1

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/Sex_ID_info_C2.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.6 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
C1_C2_XYset, C1_C2_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 31664
# Number of samples = 33
# Number of loci with too few samples = 21149
# Number of loci with low MAF = 204
# Number of loci with enough data = 10310
# Number of putative X linked snps = 13
# Number of putative X linked tags = 13
# Number of putative Z linked markers = 2
# Number of putative Z linked tags = 2
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 31664
# Number of samples = 33
# Number of loci with too few samples = 21353
# Number of loci with low MAF = 0
# Number of loci with enough data = 10310
# Number of putative X linked snps = 14
# Number of putative X linked tags = 14
# Number of putative Z linked markers = 2
# Number of putative Z linked tags = 2
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of males: 18
# Number of males: 15
# Number of Putative Y linked tags: 4
# Number of Putative W linked tags: 6
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Hori/Stacks_new
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 30
# Final number of ZW tags = 10

# %%
vcf_path = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/batch_1.vcf"

MISC.filter_vcf(vcf_path,C1_C2_XYset, "XY_linked_snps_freq_het.vcf")

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/XY_linked_snps_freq_het.vcf > $wd/XY_linked_snps_freq_het_altered.vcf
#
# ~/Programs/plink_linux_x86_64/plink --vcf $wd/XY_linked_snps_freq_het_altered.vcf --recode A --allow-extra-chr -out $wd/XY_linked_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_snps_freq_het_altered.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink-temporary.fam
# written.
# 15 variants loaded from .bim file.
# 33 people (0 males, 0 females, 33 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 33 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.913131.
# 15 variants and 33 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2//XY_linked_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.R")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('XY_linked_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("Sex_ID_info_C2.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "H. orientalis Clade 2 at putatively sex linked markers", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(12), ## Colours to use
#            func_cex = 5) ## Size of points and text in plots)

# %% [markdown]
# ### Looks like the two different haplotypes could be getting in the way of the sex linked marker test here.
#
# I tried removing the Loc11 males (leaving females in) and then Loc11 alltogether but there was no major improvement. . .

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/
#
# sh /home/djeffrie/Dropbox/My_Dropbox_Scripts/Bash/Make_heatmap_input.sh  $wd/XY_linked_plink.raw  $wd/XY_linked_heatmap_input

# %%
# %%R -w 30 -h 30 -u cm
#
# XY_heatmap_data <- read.delim("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_C2/XY_linked_heatmap_input.raw", row.names = 1)
# XY_heatmap_data_sorted <- XY_heatmap_data[order(row.names(XY_heatmap_data), decreasing = T), ]
# XY_heatmap_data_datmat <- as.matrix(XY_heatmap_data_sorted)
#
# heatmap(XY_heatmap_data_datmat, scale='none', col = c("royalblue", "orange", "darkblue"), cexRow = 1, main = "Northern Spain R. iberica")

# %% [markdown]
# ### Next Clade B

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/Sex_ID_info_Clade_B.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 1 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 1 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.6 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
cladeB_XYset, cladeB_ZWset = MISC.Super_SLM_finder(Parameter_dict, "110")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 15940
# Number of samples = 20
# Number of loci with too few samples = 5522
# Number of loci with low MAF = 0
# Number of loci with enough data = 10417
# Number of putative X linked snps = 20
# Number of putative X linked tags = 20
# Number of putative Z linked markers = 7
# Number of putative Z linked tags = 7
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 15940
# Number of samples = 20
# Number of loci with too few samples = 5521
# Number of loci with low MAF = 0
# Number of loci with enough data = 10417
# Number of putative X linked snps = 29
# Number of putative X linked tags = 29
# Number of putative Z linked markers = 11
# Number of putative Z linked tags = 11
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Hori/Stacks_new
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 33
# Final number of ZW tags = 17

# %%
vcf_path = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/batch_1.vcf"

MISC.filter_vcf(vcf_path,cladeB_XYset, "XY_linked_snps_freq_het.vcf")

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/XY_linked_snps_freq_het.vcf > $wd/XY_linked_snps_freq_het_altered.vcf
#
# ~/Programs/plink_linux_x86_64/plink --vcf $wd/XY_linked_snps_freq_het_altered.vcf --recode A --allow-extra-chr -out $wd/XY_linked_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_snps_freq_het_altered.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink-temporary.fam
# written.
# 36 variants loaded from .bim file.
# 20 people (0 males, 0 females, 20 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 20 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.931944.
# 36 variants and 20 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.R")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('XY_linked_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("Sex_ID_info_Clade_B.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "H. orientalis Clade B at putatively sex linked markers", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(12), ## Colours to use
#            func_cex = 5) ## Size of points and text in plots)

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B/
#
# sh /home/djeffrie/Dropbox/My_Dropbox_Scripts/Bash/Make_heatmap_input.sh  $wd/XY_linked_plink.raw  $wd/XY_linked_heatmap_input

# %%
# %%R -w 30 -h 30 -u cm
#
# XY_heatmap_data <- read.delim("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_B//XY_linked_heatmap_input.raw", row.names = 1)
# XY_heatmap_data_sorted <- XY_heatmap_data[order(row.names(XY_heatmap_data), decreasing = T), ]
# XY_heatmap_data_datmat <- as.matrix(XY_heatmap_data_sorted)
#
# heatmap(XY_heatmap_data_datmat, scale='none', col = c("royalblue", "orange", "darkblue"), cexRow = 1, main = "Northern Spain R. iberica")

# %% [markdown]
# ### Now Clade A2

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2//batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2/Sex_ID_info_Clade_A2.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 1 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 1 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.6 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
cladeA2_XYset, cladeA2_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 31426
# Number of samples = 36
# Number of loci with too few samples = 3693
# Number of loci with low MAF = 0
# Number of loci with enough data = 27732
# Number of putative X linked snps = 8
# Number of putative X linked tags = 8
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 31426
# Number of samples = 36
# Number of loci with too few samples = 3693
# Number of loci with low MAF = 0
# Number of loci with enough data = 27732
# Number of putative X linked snps = 74
# Number of putative X linked tags = 74
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 19
# Number of males: 17
# Number of Putative Y linked tags: 86
# Number of Putative W linked tags: 0
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Hori/Stacks_new
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 167
# Final number of ZW tags = 0
# /home/djeffrie/anaconda/lib/python2.7/site-packages/matplotlib_venn/_venn3.py:46: UserWarning: All circles have zero area
#   warnings.warn("All circles have zero area")

# %% [markdown]
# Going to output all tags as a fasta file to map to the genome.

# %%
import vcf
vcf_handle = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2/batch_1.vcf.altered", 'r')

myvcf = vcf.Reader(vcf_handle)

tag_IDs_only = []
tag_IDs = []
for i in myvcf:
    if i.ID not in tag_IDs_only:
        tag_IDs.append("%s_%s" % (i.ID, i.POS))
        tag_IDs_only.append(i.ID)

# %%
print len(tag_IDs), "tags in VCF"
# Out:
# 21490 tags in VCF

# %%
catalog_path = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/batch_1.catalog.tags.tsv.gz"

MISC.fasta_maka(tag_IDs, catalog_path)
# Out:
# Number of tags in whitelist: 21490
# 21490 sequences written to /home/djeffrie/Data/RADseq/Hori/Stacks_new/Whitelist_tags.fa

# %% [markdown]
# ## Mapped these all to the Hyla arborea draft genome (about 10 million years away)

# %%
Mapped_hyla_tags = "/home/djeffrie/Data/RADseq/Hori/Stacks_new/Hori_all_VCF_tags_blastn.xml"
Hyla_fasta = "/home/djeffrie/Data/Genomes/Hyla/HarbK44final.fa"

best_hit_crit = 1e5
Eval_threshold = 1e-20
Window = 100000000

Hyla_records = MISC.BlastParseExtra(Mapped_hyla_tags, Hyla_fasta , best_hit_crit, Eval_threshold,Window)

Hyla_mapped_scaffs = "%s/%s" % ("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2/", "Hyla_mapped_scaffs.fa")
# Out:
# Number of multi-alingments kept: 7760
# Number of unique alingments kept: 5823
# Getting subject scaffold segments from /home/djeffrie/Data/Genomes/Hyla/HarbK44final.fa . . .
# 13583 sequence scaffold segments are in /home/djeffrie/Data/RADseq/Hori/Stacks_new/blast_100000000_chunks.fa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f5156a3b152d> in <module>()
#      10 Hyla_mapped_scaffs = "%s/%s" % ("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2/", "Hyla_mapped_scaffs.fa")
#      11
# ---> 12 shutil.move("%s/%s" % (wd,"blast_100000000_chunks.fa"), Hyla_mapped_scaffs)
#      13
#
# NameError: name 'shutil' is not defined

# %% [markdown]
# A really nice number of loci mapped!! So how many of these scaffolds are in the map?
#
# What I did was take the Male and Female maps that alan previously made, and combined them. I lose order information in this, but retain the identity of the chromosome that each one maps to. So I will now group RAD loci according to their sex chromosome allocation.

# %%
Hyla_scaffold_locations = {}
hyla_mapped_scaffolds = open("/home/djeffrie/Data/RADseq/Hori/Combined_harb_scaff_LG_IDs.txt", 'r').readlines()

for scaffold in hyla_mapped_scaffolds:
    Hyla_scaffold_locations[scaffold.split()[1]] = scaffold.split()[0]

Hori_RADtag_locations = {}
for RADtag in Hyla_records:
    subject = Hyla_records[RADtag]["Ref_hit_id"].split(".")[0]
    
    if subject in Hyla_scaffold_locations:
        Hori_RADtag_locations[RADtag] = Hyla_scaffold_locations[subject]

# %%
from collections import Counter
    
Chromosome_counts = Counter(Hori_RADtag_locations.values())

for chromosome in Chromosome_counts:
    print chromosome, Chromosome_counts[chromosome]
# Out:
# 10 43
# 4A7A 61
# 8B 35
# 8A 58
# 1 199
# 3 149
# 2 140
# 5 154
# 6 114
# 9 56
# 4B 79
# 7B 36

# %% [markdown]
# So this went really well - There are definitely enough loci on each chromosome to compare pop statistics between them. Annoyingly I didn't do this populations run with male and female data, but with population data. So now I will use the mapped tag IDs as a whitelist and re-run populations giving it male and female information. This way it will calculate Fstats for me.

# %%
whitelist = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex/whitelist.txt", 'w')

for i in Hori_RADtag_locations:
    whitelist.write("%s\n" % i)
whitelist.close()

# %% [markdown]
# First I did this for males and females together for both populations in this clade.

# %%
## FSTs first

Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex/batch_1.fst_F-M.tsv", 'r').readlines()

per_chromosome_Fst = {}

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    Fst = line.split()[8]
    
    if Loc_ID in Hori_RADtag_locations:
        if Hori_RADtag_locations[Loc_ID] not in per_chromosome_Fst:
            per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]] = []
        per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]].append(float(Fst))

# %%
linkage_groups_ordered = ["1", "2", "3", "4A7A", "4B", "5", "6","7B", "8A", "8B","9", "10"]

# %%
all_fsts = []
for i in per_chromosome_Fst:
    all_data.append(i)

# %%
from matplotlib import pyplot as plt

all_data = []
for i in per_chromosome_Fst:
    all_data.append(per_chromosome_Fst[i])

fig = plt.figure(figsize=(20,10))
fig.add_subplot(111)

plt.boxplot(all_data, labels=linkage_groups_ordered)
#plt.set_xticks(range(len(linkage_groups_ordered), linkage_groups_ordered))

plt.show()

# %% [markdown]
# Ok, so no obvious difference here. . . Will now look between males and females in the same populations.

# %% [markdown]
# ### Loc 32

# %%
## FSTs first

Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex_and_pop/batch_1.fst_F32-M32.tsv", 'r').readlines()

per_chromosome_Fst = {}

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    Fst = line.split()[8]
    
    if Loc_ID in Hori_RADtag_locations:
        if Hori_RADtag_locations[Loc_ID] not in per_chromosome_Fst:
            per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]] = []
        per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]].append(float(Fst))

        
all_fsts = []
for i in per_chromosome_Fst:
    all_data.append(i)
    
    
from matplotlib import pyplot as plt

all_data = []
for i in per_chromosome_Fst:
    all_data.append(per_chromosome_Fst[i])

fig = plt.figure(figsize=(20,10))
fig.add_subplot(111)

plt.boxplot(all_data, labels=linkage_groups_ordered)
#plt.set_xticks(range(len(linkage_groups_ordered), linkage_groups_ordered))

plt.show()

# %% [markdown]
# ### Loc 34

# %%
## FSTs first

Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex_and_pop/batch_1.fst_F34-M34.tsv", 'r').readlines()

per_chromosome_Fst = {}

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    Fst = line.split()[8]
    
    if Loc_ID in Hori_RADtag_locations:
        if Hori_RADtag_locations[Loc_ID] not in per_chromosome_Fst:
            per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]] = []
        per_chromosome_Fst[Hori_RADtag_locations[Loc_ID]].append(float(Fst))

        
all_fsts = []
for i in per_chromosome_Fst:
    all_data.append(i)
    
    
from matplotlib import pyplot as plt

all_data = []
for i in per_chromosome_Fst:
    all_data.append(per_chromosome_Fst[i])

fig = plt.figure(figsize=(20,10))
fig.add_subplot(111)

plt.boxplot(all_data, labels=linkage_groups_ordered)
#plt.set_xticks(range(len(linkage_groups_ordered), linkage_groups_ordered))

plt.show()

# %% [markdown]
# ## So no noticable difference in Fst at these loci . . .
#
# What about the number of SNPs on there? Can look at N_SNPs/N_tags to see if diversity is higher on the sex chromosome? And then heterozygosity too perhaps?

# %%
Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex_and_pop/batch_1.fst_F34-M34.tsv", 'r').readlines()


All_loci_occurences = []

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    All_loci_occurences.append(Loc_ID)
    
SNPs_per_chrom = {}

for tag in All_loci_occurences:
    if tag in Hori_RADtag_locations:
        if Hori_RADtag_locations[tag] not in SNPs_per_chrom:
            SNPs_per_chrom[Hori_RADtag_locations[tag]] = []
        SNPs_per_chrom[Hori_RADtag_locations[tag]].append(tag)
        
tags_to_SNPs_per_chrom = {}

for chrom in linkage_groups_ordered:
    
    N_tags = len(Counter(SNPs_per_chrom[chrom]))
    N_SNps = len(SNPs_per_chrom[chrom])
    
    N_SNPs_to_tags = N_SNps / N_tags
    
    print chrom, " ", N_SNPs_to_tags
# Out:
# 1   1.52150537634
# 2   1.72131147541
# 3   1.64583333333
# 4A7A   1.59322033898
# 4B   1.68055555556
# 5   1.70503597122
# 6   1.76576576577
# 7B   1.57142857143
# 8A   1.63157894737
# 8B   1.5625
# 9   1.67924528302
# 10   1.61904761905

# %%
Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex_and_pop/batch_1.fst_F32-M32.tsv", 'r').readlines()


All_loci_occurences = []

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    All_loci_occurences.append(Loc_ID)
    
SNPs_per_chrom = {}

for tag in All_loci_occurences:
    if tag in Hori_RADtag_locations:
        if Hori_RADtag_locations[tag] not in SNPs_per_chrom:
            SNPs_per_chrom[Hori_RADtag_locations[tag]] = []
        SNPs_per_chrom[Hori_RADtag_locations[tag]].append(tag)
        
tags_to_SNPs_per_chrom = {}

for chrom in linkage_groups_ordered:
    
    N_tags = len(Counter(SNPs_per_chrom[chrom]))
    N_SNps = len(SNPs_per_chrom[chrom])
    
    N_SNPs_to_tags = N_SNps / N_tags
    
    print chrom, " ", N_SNPs_to_tags
# Out:
# 1   1.77435897436
# 2   1.89051094891
# 3   1.8275862069
# 4A7A   1.75
# 4B   1.85897435897
# 5   1.91503267974
# 6   1.94642857143
# 7B   1.8
# 8A   1.79310344828
# 8B   1.82857142857
# 9   1.83636363636
# 10   1.90476190476

# %%
Fst_stats = open("/home/djeffrie/Data/RADseq/Hori/Stacks_new/Populations_Clade_A2_by_sex/batch_1.fst_F-M.tsv", 'r').readlines()


All_loci_occurences = []

for line in Fst_stats[1:]:
    Loc_ID = line.split()[1]
    All_loci_occurences.append(Loc_ID)
    
SNPs_per_chrom = {}

for tag in All_loci_occurences:
    if tag in Hori_RADtag_locations:
        if Hori_RADtag_locations[tag] not in SNPs_per_chrom:
            SNPs_per_chrom[Hori_RADtag_locations[tag]] = []
        SNPs_per_chrom[Hori_RADtag_locations[tag]].append(tag)
        
tags_to_SNPs_per_chrom = {}

for chrom in linkage_groups_ordered:
    
    N_tags = len(Counter(SNPs_per_chrom[chrom]))
    N_SNps = len(SNPs_per_chrom[chrom])
    
    N_SNPs_to_tags = N_SNps / N_tags
    
    print chrom, " ", N_SNPs_to_tags
# Out:
# 1   1.88944723618
# 2   2.07142857143
# 3   2.07382550336
# 4A7A   1.95081967213
# 4B   1.9746835443
# 5   2.09090909091
# 6   2.13157894737
# 7B   1.83333333333
# 8A   2.01724137931
# 8B   1.97142857143
# 9   2.0
# 10   1.95348837209

# %% [markdown]
# ### Sooo, there is no pattern on chromosome 1 that looks any different from the others.
