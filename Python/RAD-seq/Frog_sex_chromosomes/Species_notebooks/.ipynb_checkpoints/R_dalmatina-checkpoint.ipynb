# %% [markdown]
# # This notebook contains the Stacks parameter tests, final parameters used and analyses to identify sex linked markers for the RADseq dataset of <i> Rana dalmatina </i>
# ## Sample set:
# 11 Females, 19 Males, 2 unknown.
#
# All analyses includeing the outputs below are in "/archive/dee/perrin/djeffrie/turnover_project/RAD_seq_datasets/Completed/Rdalmatina.tgz"

# %% [markdown]
# Contents:
#
# 1. Ustacks parameter tests & final parameters used
# 2. Cstacks parameter tests & final parameters used
# 3. Populations parameter tests & final parameters used
# 4. Identification of sex-linked markers
#
#
# **Scripts for Incremental can be found in the Incremental module,
#
# **custom scripts for analyses of sex-linked markers can be found in the package "some_sexy_tools".

# %%
# %matplotlib inline
import os
import wget ## used "sudo pip install wget" in command line to get package.
import Incremental_U as IncU ## Get this sorted
import Incremental_C as IncC
import Incremental_Pop_mod as IncPop
import MISC_RAD_tools as MISC
import pprint
import subprocess

# %%
# %load_ext rpy2.ipython

# %%
working_directory = "/home/djeffrie/Data/RADseq/Rdalmatina/" ## Wherever you like

# %% [markdown]
# ##Stacks parameter tests --------------------------------------------------------
# ###Ustacks
# Files for the analyses below were transfered from the demultiplexed fastq.gz files on the archive.

# %%
### Fastq files are here:
Incrememntal_test_directory = "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/"

# %%
## INPUT INCREMENTAL PARAMETERS HERE -----------------------------------------

parameters = ["M", "m", "MS"]                                             ## List, eg ["M", "m", "MS"]. If only testing 1 param, this must still be a list e.g. ["M"]
M_vals =   [2,3,4,5,6]                                              ## List, eg range(1,5,1) this would give [1,2,3,4]
m_vals =   [2,3,4,5,6]                                              ## List, eg range(1,5,1) this would give [1,2,3,4]
MS_vals =  [2,3,4]                                                 ## List, eg range(1,5,1) this would give [1,2,3,4]
threads =  7                                                        ## Int. eg 7
parent_dir = Incrememntal_test_directory    ## Absolute Dir containing the demultiplexed raw read fasta/fastq files
run_cline_switch =  1                            ## to switch on (1) to run stacks cline or off (0) to run pipeline on existing outputs

print parent_dir

## Making input dictionary --------------------------------------

Setup_dict = {}
Setup_dict["parameters"] = {}
Setup_dict["threads"] = threads
Setup_dict["parent_directory"] = parent_dir
Setup_dict["run_cline_switch"] = run_cline_switch
Setup_dict["verbose"] = True

for param in parameters:
    if "M" in param:
        Setup_dict["parameters"][param] = M_vals
    if "m" in param:
        Setup_dict["parameters"][param] = m_vals
    if "MS" in param:
        Setup_dict["parameters"][param] = MS_vals

#pp = pprint.PrettyPrinter(indent=2)
#pp.pprint(Setup_dict)
# Out:
# /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/

# %%
Incremental_U_outputs = IncU.IncreMental_U(Setup_dict)
# Out:
# ##### ------- Test samples, parameters and values ------ #####
#
# { 'RdalM10.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM11.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM12.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM13.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM14.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM18.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'RdalM19.fq': { 'M': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }},
#                   'MS': { 2: { }, 3: { }, 4: { }},
#                   'm': { 2: { }, 3: { }, 4: { }, 5: { }, 6: { }}},
#   'parent_directory': '/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/'}
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/M_tests/M_2 -i 1 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 251
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7558
# 	Number of deleveraged but still blacklisted multistack loci = 959
# RdalM10.tags.tsv at M = 2 Total_tags = 108508, Good tags = 106971, N blacklisted = 1537
# Mean and SD of coverage for RdalM10, M=2:  20.86 (+/- 18.6)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/M_tests/M_3 -i 1 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 141
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 13025
# 	Number of deleveraged but still blacklisted multistack loci = 1055
# RdalM10.tags.tsv at M = 3 Total_tags = 108050, Good tags = 106527, N blacklisted = 1523
# Mean and SD of coverage for RdalM10, M=3:  21.08 (+/- 18.92)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/M_tests/M_4 -i 1 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 110
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 16623
# 	Number of deleveraged but still blacklisted multistack loci = 1093
# RdalM10.tags.tsv at M = 4 Total_tags = 107612, Good tags = 106082, N blacklisted = 1530
# Mean and SD of coverage for RdalM10, M=4:  21.22 (+/- 19.07)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/M_tests/M_5 -i 1 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 99
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 19332
# 	Number of deleveraged but still blacklisted multistack loci = 1097
# RdalM10.tags.tsv at M = 5 Total_tags = 107305, Good tags = 105782, N blacklisted = 1523
# Mean and SD of coverage for RdalM10, M=5:  21.32 (+/- 19.15)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/M_tests/M_6 -i 1 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 89
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 21475
# 	Number of deleveraged but still blacklisted multistack loci = 1085
# RdalM10.tags.tsv at M = 6 Total_tags = 107006, Good tags = 105505, N blacklisted = 1501
# Mean and SD of coverage for RdalM10, M=6:  21.43 (+/- 19.29)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/m_tests/m_2 -i 1 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 349
# 	Number of un-deleveraged multistack loci blacklisted = 306
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8474
# 	Number of deleveraged but still blacklisted multistack loci = 1169
# RdalM10.tags.tsv at m = 2 Total_tags = 116454, Good tags = 114630, N blacklisted = 1824
# Mean and SD of coverage for RdalM10, m=2:  19.4 (+/- 17.73)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/m_tests/m_3 -i 1 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 251
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7561
# 	Number of deleveraged but still blacklisted multistack loci = 956
# RdalM10.tags.tsv at m = 3 Total_tags = 108508, Good tags = 106974, N blacklisted = 1534
# Mean and SD of coverage for RdalM10, m=3:  20.87 (+/- 18.68)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/m_tests/m_4 -i 1 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 324
# 	Number of un-deleveraged multistack loci blacklisted = 238
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7197
# 	Number of deleveraged but still blacklisted multistack loci = 898
# RdalM10.tags.tsv at m = 4 Total_tags = 104696, Good tags = 103236, N blacklisted = 1460
# Mean and SD of coverage for RdalM10, m=4:  21.56 (+/- 18.87)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/m_tests/m_5 -i 1 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 316
# 	Number of un-deleveraged multistack loci blacklisted = 234
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6906
# 	Number of deleveraged but still blacklisted multistack loci = 864
# RdalM10.tags.tsv at m = 5 Total_tags = 101102, Good tags = 99688, N blacklisted = 1414
# Mean and SD of coverage for RdalM10, m=5:  22.19 (+/- 19.11)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/m_tests/m_6 -i 1 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 311
# 	Number of un-deleveraged multistack loci blacklisted = 225
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6673
# 	Number of deleveraged but still blacklisted multistack loci = 820
# RdalM10.tags.tsv at m = 6 Total_tags = 97524, Good tags = 96168, N blacklisted = 1356
# Mean and SD of coverage for RdalM10, m=6:  22.84 (+/- 19.36)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/MS_tests/MS_2 -i 1 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 549
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6994
# 	Number of deleveraged but still blacklisted multistack loci = 1523
# RdalM10.tags.tsv at MS = 2 Total_tags = 108508, Good tags = 106109, N blacklisted = 2399
# Mean and SD of coverage for RdalM10, MS=2:  20.44 (+/- 17.27)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/MS_tests/MS_3 -i 1 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 251
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7552
# 	Number of deleveraged but still blacklisted multistack loci = 965
# RdalM10.tags.tsv at MS = 3 Total_tags = 108508, Good tags = 106965, N blacklisted = 1543
# Mean and SD of coverage for RdalM10, MS=3:  20.86 (+/- 18.61)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM10/MS_tests/MS_4 -i 1 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 121
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7856
# 	Number of deleveraged but still blacklisted multistack loci = 661
# RdalM10.tags.tsv at MS = 4 Total_tags = 108508, Good tags = 107399, N blacklisted = 1109
# Mean and SD of coverage for RdalM10, MS=4:  21.15 (+/- 19.56)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/M_tests/M_2 -i 2 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7038
# 	Number of deleveraged but still blacklisted multistack loci = 956
# RdalM14.tags.tsv at M = 2 Total_tags = 102303, Good tags = 100806, N blacklisted = 1497
# Mean and SD of coverage for RdalM14, M=2:  25.09 (+/- 22.21)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/M_tests/M_3 -i 2 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 140
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 12141
# 	Number of deleveraged but still blacklisted multistack loci = 1023
# RdalM14.tags.tsv at M = 3 Total_tags = 101863, Good tags = 100391, N blacklisted = 1472
# Mean and SD of coverage for RdalM14, M=3:  25.35 (+/- 22.72)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/M_tests/M_4 -i 2 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 112
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 15549
# 	Number of deleveraged but still blacklisted multistack loci = 1049
# RdalM14.tags.tsv at M = 4 Total_tags = 101489, Good tags = 100019, N blacklisted = 1470
# Mean and SD of coverage for RdalM14, M=4:  25.54 (+/- 22.89)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/M_tests/M_5 -i 2 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 100
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 18100
# 	Number of deleveraged but still blacklisted multistack loci = 1064
# RdalM14.tags.tsv at M = 5 Total_tags = 101203, Good tags = 99730, N blacklisted = 1473
# Mean and SD of coverage for RdalM14, M=5:  25.64 (+/- 23.0)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/M_tests/M_6 -i 2 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 85
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 20164
# 	Number of deleveraged but still blacklisted multistack loci = 1061
# RdalM14.tags.tsv at M = 6 Total_tags = 100937, Good tags = 99482, N blacklisted = 1455
# Mean and SD of coverage for RdalM14, M=6:  25.76 (+/- 23.11)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/m_tests/m_2 -i 2 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 339
# 	Number of un-deleveraged multistack loci blacklisted = 291
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8071
# 	Number of deleveraged but still blacklisted multistack loci = 1161
# RdalM14.tags.tsv at m = 2 Total_tags = 111688, Good tags = 109897, N blacklisted = 1791
# Mean and SD of coverage for RdalM14, m=2:  22.94 (+/- 21.32)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/m_tests/m_3 -i 2 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7036
# 	Number of deleveraged but still blacklisted multistack loci = 958
# RdalM14.tags.tsv at m = 3 Total_tags = 102303, Good tags = 100804, N blacklisted = 1499
# Mean and SD of coverage for RdalM14, m=3:  25.1 (+/- 22.24)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/m_tests/m_4 -i 2 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 297
# 	Number of un-deleveraged multistack loci blacklisted = 218
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6604
# 	Number of deleveraged but still blacklisted multistack loci = 890
# RdalM14.tags.tsv at m = 4 Total_tags = 97191, Good tags = 95786, N blacklisted = 1405
# Mean and SD of coverage for RdalM14, m=4:  26.27 (+/- 22.44)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/m_tests/m_5 -i 2 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 291
# 	Number of un-deleveraged multistack loci blacklisted = 202
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6269
# 	Number of deleveraged but still blacklisted multistack loci = 821
# RdalM14.tags.tsv at m = 5 Total_tags = 93076, Good tags = 91762, N blacklisted = 1314
# Mean and SD of coverage for RdalM14, m=5:  27.28 (+/- 22.59)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/m_tests/m_6 -i 2 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 288
# 	Number of un-deleveraged multistack loci blacklisted = 195
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 5960
# 	Number of deleveraged but still blacklisted multistack loci = 780
# RdalM14.tags.tsv at m = 6 Total_tags = 89268, Good tags = 88005, N blacklisted = 1263
# Mean and SD of coverage for RdalM14, m=6:  28.26 (+/- 22.78)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/MS_tests/MS_2 -i 2 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 517
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6540
# 	Number of deleveraged but still blacklisted multistack loci = 1454
# RdalM14.tags.tsv at MS = 2 Total_tags = 102303, Good tags = 100023, N blacklisted = 2280
# Mean and SD of coverage for RdalM14, MS=2:  24.62 (+/- 20.72)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/MS_tests/MS_3 -i 2 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7033
# 	Number of deleveraged but still blacklisted multistack loci = 961
# RdalM14.tags.tsv at MS = 3 Total_tags = 102303, Good tags = 100801, N blacklisted = 1502
# Mean and SD of coverage for RdalM14, MS=3:  25.08 (+/- 22.14)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM14/MS_tests/MS_4 -i 2 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 110
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7347
# 	Number of deleveraged but still blacklisted multistack loci = 647
# RdalM14.tags.tsv at MS = 4 Total_tags = 102303, Good tags = 101237, N blacklisted = 1066
# Mean and SD of coverage for RdalM14, MS=4:  25.46 (+/- 23.51)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/M_tests/M_2 -i 3 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 250
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7800
# 	Number of deleveraged but still blacklisted multistack loci = 937
# RdalM11.tags.tsv at M = 2 Total_tags = 108425, Good tags = 106925, N blacklisted = 1500
# Mean and SD of coverage for RdalM11, M=2:  24.63 (+/- 18.63)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/M_tests/M_3 -i 3 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 149
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 13308
# 	Number of deleveraged but still blacklisted multistack loci = 997
# RdalM11.tags.tsv at M = 3 Total_tags = 107954, Good tags = 106495, N blacklisted = 1459
# Mean and SD of coverage for RdalM11, M=3:  24.9 (+/- 18.98)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/M_tests/M_4 -i 3 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 117
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 16939
# 	Number of deleveraged but still blacklisted multistack loci = 1041
# RdalM11.tags.tsv at M = 4 Total_tags = 107549, Good tags = 106078, N blacklisted = 1471
# Mean and SD of coverage for RdalM11, M=4:  25.08 (+/- 19.22)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/M_tests/M_5 -i 3 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 108
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 19640
# 	Number of deleveraged but still blacklisted multistack loci = 1033
# RdalM11.tags.tsv at M = 5 Total_tags = 107244, Good tags = 105790, N blacklisted = 1454
# Mean and SD of coverage for RdalM11, M=5:  25.21 (+/- 19.45)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/M_tests/M_6 -i 3 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 89
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 21800
# 	Number of deleveraged but still blacklisted multistack loci = 1058
# RdalM11.tags.tsv at M = 6 Total_tags = 106965, Good tags = 105505, N blacklisted = 1460
# Mean and SD of coverage for RdalM11, M=6:  25.31 (+/- 19.47)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/m_tests/m_2 -i 3 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 324
# 	Number of un-deleveraged multistack loci blacklisted = 297
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8855
# 	Number of deleveraged but still blacklisted multistack loci = 1215
# RdalM11.tags.tsv at m = 2 Total_tags = 116018, Good tags = 114182, N blacklisted = 1836
# Mean and SD of coverage for RdalM11, m=2:  22.94 (+/- 17.88)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/m_tests/m_3 -i 3 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 250
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7779
# 	Number of deleveraged but still blacklisted multistack loci = 958
# RdalM11.tags.tsv at m = 3 Total_tags = 108425, Good tags = 106904, N blacklisted = 1521
# Mean and SD of coverage for RdalM11, m=3:  24.62 (+/- 18.58)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/m_tests/m_4 -i 3 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 309
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7395
# 	Number of deleveraged but still blacklisted multistack loci = 875
# RdalM11.tags.tsv at m = 4 Total_tags = 105055, Good tags = 103639, N blacklisted = 1416
# Mean and SD of coverage for RdalM11, m=4:  25.39 (+/- 19.05)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/m_tests/m_5 -i 3 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 304
# 	Number of un-deleveraged multistack loci blacklisted = 231
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7171
# 	Number of deleveraged but still blacklisted multistack loci = 800
# RdalM11.tags.tsv at m = 5 Total_tags = 102009, Good tags = 100674, N blacklisted = 1335
# Mean and SD of coverage for RdalM11, m=5:  26.06 (+/- 19.03)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/m_tests/m_6 -i 3 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 302
# 	Number of un-deleveraged multistack loci blacklisted = 220
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6919
# 	Number of deleveraged but still blacklisted multistack loci = 800
# RdalM11.tags.tsv at m = 6 Total_tags = 98980, Good tags = 97658, N blacklisted = 1322
# Mean and SD of coverage for RdalM11, m=6:  26.7 (+/- 19.16)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/MS_tests/MS_2 -i 3 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 568
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7237
# 	Number of deleveraged but still blacklisted multistack loci = 1500
# RdalM11.tags.tsv at MS = 2 Total_tags = 108425, Good tags = 106044, N blacklisted = 2381
# Mean and SD of coverage for RdalM11, MS=2:  24.14 (+/- 16.96)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/MS_tests/MS_3 -i 3 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 250
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7784
# 	Number of deleveraged but still blacklisted multistack loci = 953
# RdalM11.tags.tsv at MS = 3 Total_tags = 108425, Good tags = 106909, N blacklisted = 1516
# Mean and SD of coverage for RdalM11, MS=3:  24.63 (+/- 18.64)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM11/MS_tests/MS_4 -i 3 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 313
# 	Number of un-deleveraged multistack loci blacklisted = 125
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8119
# 	Number of deleveraged but still blacklisted multistack loci = 618
# RdalM11.tags.tsv at MS = 4 Total_tags = 108425, Good tags = 107369, N blacklisted = 1056
# Mean and SD of coverage for RdalM11, MS=4:  24.99 (+/- 20.1)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/M_tests/M_2 -i 4 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 247
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7369
# 	Number of deleveraged but still blacklisted multistack loci = 1038
# RdalM18.tags.tsv at M = 2 Total_tags = 106956, Good tags = 105351, N blacklisted = 1605
# Mean and SD of coverage for RdalM18, M=2:  23.3 (+/- 17.46)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/M_tests/M_3 -i 4 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 145
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 12681
# 	Number of deleveraged but still blacklisted multistack loci = 1109
# RdalM18.tags.tsv at M = 3 Total_tags = 106453, Good tags = 104879, N blacklisted = 1574
# Mean and SD of coverage for RdalM18, M=3:  23.63 (+/- 18.3)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/M_tests/M_4 -i 4 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 112
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 16249
# 	Number of deleveraged but still blacklisted multistack loci = 1125
# RdalM18.tags.tsv at M = 4 Total_tags = 106061, Good tags = 104504, N blacklisted = 1557
# Mean and SD of coverage for RdalM18, M=4:  23.77 (+/- 18.25)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/M_tests/M_5 -i 4 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 95
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 18942
# 	Number of deleveraged but still blacklisted multistack loci = 1111
# RdalM18.tags.tsv at M = 5 Total_tags = 105784, Good tags = 104258, N blacklisted = 1526
# Mean and SD of coverage for RdalM18, M=5:  23.91 (+/- 18.58)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/M_tests/M_6 -i 4 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 80
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 21004
# 	Number of deleveraged but still blacklisted multistack loci = 1131
# RdalM18.tags.tsv at M = 6 Total_tags = 105483, Good tags = 103952, N blacklisted = 1531
# Mean and SD of coverage for RdalM18, M=6:  24.01 (+/- 18.62)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/m_tests/m_2 -i 4 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 340
# 	Number of un-deleveraged multistack loci blacklisted = 303
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8304
# 	Number of deleveraged but still blacklisted multistack loci = 1215
# RdalM18.tags.tsv at m = 2 Total_tags = 114442, Good tags = 112584, N blacklisted = 1858
# Mean and SD of coverage for RdalM18, m=2:  21.76 (+/- 17.03)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/m_tests/m_3 -i 4 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 247
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7394
# 	Number of deleveraged but still blacklisted multistack loci = 1013
# RdalM18.tags.tsv at m = 3 Total_tags = 106956, Good tags = 105376, N blacklisted = 1580
# Mean and SD of coverage for RdalM18, m=3:  23.32 (+/- 17.55)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/m_tests/m_4 -i 4 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 315
# 	Number of un-deleveraged multistack loci blacklisted = 239
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6974
# 	Number of deleveraged but still blacklisted multistack loci = 960
# RdalM18.tags.tsv at m = 4 Total_tags = 103494, Good tags = 101980, N blacklisted = 1514
# Mean and SD of coverage for RdalM18, m=4:  24.04 (+/- 17.74)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/m_tests/m_5 -i 4 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 308
# 	Number of un-deleveraged multistack loci blacklisted = 225
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6712
# 	Number of deleveraged but still blacklisted multistack loci = 912
# RdalM18.tags.tsv at m = 5 Total_tags = 100242, Good tags = 98797, N blacklisted = 1445
# Mean and SD of coverage for RdalM18, m=5:  24.72 (+/- 18.05)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/m_tests/m_6 -i 4 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 304
# 	Number of un-deleveraged multistack loci blacklisted = 219
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6506
# 	Number of deleveraged but still blacklisted multistack loci = 875
# RdalM18.tags.tsv at m = 6 Total_tags = 96912, Good tags = 95514, N blacklisted = 1398
# Mean and SD of coverage for RdalM18, m=6:  25.42 (+/- 18.1)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/MS_tests/MS_2 -i 4 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 558
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6835
# 	Number of deleveraged but still blacklisted multistack loci = 1572
# RdalM18.tags.tsv at MS = 2 Total_tags = 106956, Good tags = 104506, N blacklisted = 2450
# Mean and SD of coverage for RdalM18, MS=2:  22.87 (+/- 16.02)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/MS_tests/MS_3 -i 4 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 247
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7378
# 	Number of deleveraged but still blacklisted multistack loci = 1029
# RdalM18.tags.tsv at MS = 3 Total_tags = 106956, Good tags = 105360, N blacklisted = 1596
# Mean and SD of coverage for RdalM18, MS=3:  23.32 (+/- 17.54)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM18/MS_tests/MS_4 -i 4 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 320
# 	Number of un-deleveraged multistack loci blacklisted = 119
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7712
# 	Number of deleveraged but still blacklisted multistack loci = 695
# RdalM18.tags.tsv at MS = 4 Total_tags = 106956, Good tags = 105822, N blacklisted = 1134
# Mean and SD of coverage for RdalM18, MS=4:  23.68 (+/- 19.0)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/M_tests/M_2 -i 5 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6961
# 	Number of deleveraged but still blacklisted multistack loci = 952
# RdalM13.tags.tsv at M = 2 Total_tags = 100628, Good tags = 99141, N blacklisted = 1487
# Mean and SD of coverage for RdalM13, M=2:  25.19 (+/- 22.33)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/M_tests/M_3 -i 5 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 142
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 12014
# 	Number of deleveraged but still blacklisted multistack loci = 1014
# RdalM13.tags.tsv at M = 3 Total_tags = 100178, Good tags = 98719, N blacklisted = 1459
# Mean and SD of coverage for RdalM13, M=3:  25.47 (+/- 22.61)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/M_tests/M_4 -i 5 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 117
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 15409
# 	Number of deleveraged but still blacklisted multistack loci = 1025
# RdalM13.tags.tsv at M = 4 Total_tags = 99804, Good tags = 98359, N blacklisted = 1445
# Mean and SD of coverage for RdalM13, M=4:  25.65 (+/- 22.93)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/M_tests/M_5 -i 5 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 105
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 17957
# 	Number of deleveraged but still blacklisted multistack loci = 1042
# RdalM13.tags.tsv at M = 5 Total_tags = 99537, Good tags = 98087, N blacklisted = 1450
# Mean and SD of coverage for RdalM13, M=5:  25.76 (+/- 23.05)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/M_tests/M_6 -i 5 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 85
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 19991
# 	Number of deleveraged but still blacklisted multistack loci = 1037
# RdalM13.tags.tsv at M = 6 Total_tags = 99299, Good tags = 97874, N blacklisted = 1425
# Mean and SD of coverage for RdalM13, M=6:  25.88 (+/- 23.12)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/m_tests/m_2 -i 5 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 327
# 	Number of un-deleveraged multistack loci blacklisted = 288
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8168
# 	Number of deleveraged but still blacklisted multistack loci = 1176
# RdalM13.tags.tsv at m = 2 Total_tags = 110879, Good tags = 109088, N blacklisted = 1791
# Mean and SD of coverage for RdalM13, m=2:  22.83 (+/- 21.34)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/m_tests/m_3 -i 5 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6972
# 	Number of deleveraged but still blacklisted multistack loci = 941
# RdalM13.tags.tsv at m = 3 Total_tags = 100628, Good tags = 99152, N blacklisted = 1476
# Mean and SD of coverage for RdalM13, m=3:  25.18 (+/- 22.24)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/m_tests/m_4 -i 5 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 293
# 	Number of un-deleveraged multistack loci blacklisted = 213
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6490
# 	Number of deleveraged but still blacklisted multistack loci = 863
# RdalM13.tags.tsv at m = 4 Total_tags = 95151, Good tags = 93782, N blacklisted = 1369
# Mean and SD of coverage for RdalM13, m=4:  26.53 (+/- 22.53)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/m_tests/m_5 -i 5 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 285
# 	Number of un-deleveraged multistack loci blacklisted = 200
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6161
# 	Number of deleveraged but still blacklisted multistack loci = 794
# RdalM13.tags.tsv at m = 5 Total_tags = 90882, Good tags = 89603, N blacklisted = 1279
# Mean and SD of coverage for RdalM13, m=5:  27.62 (+/- 22.83)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/m_tests/m_6 -i 5 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 280
# 	Number of un-deleveraged multistack loci blacklisted = 191
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 5905
# 	Number of deleveraged but still blacklisted multistack loci = 742
# RdalM13.tags.tsv at m = 6 Total_tags = 86933, Good tags = 85720, N blacklisted = 1213
# Mean and SD of coverage for RdalM13, m=6:  28.67 (+/- 22.95)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/MS_tests/MS_2 -i 5 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 531
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6462
# 	Number of deleveraged but still blacklisted multistack loci = 1451
# RdalM13.tags.tsv at MS = 2 Total_tags = 100628, Good tags = 98343, N blacklisted = 2285
# Mean and SD of coverage for RdalM13, MS=2:  24.71 (+/- 20.7)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/MS_tests/MS_3 -i 5 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 232
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6964
# 	Number of deleveraged but still blacklisted multistack loci = 949
# RdalM13.tags.tsv at MS = 3 Total_tags = 100628, Good tags = 99144, N blacklisted = 1484
# Mean and SD of coverage for RdalM13, MS=3:  25.18 (+/- 22.14)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM13/MS_tests/MS_4 -i 5 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 303
# 	Number of un-deleveraged multistack loci blacklisted = 109
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7276
# 	Number of deleveraged but still blacklisted multistack loci = 637
# RdalM13.tags.tsv at MS = 4 Total_tags = 100628, Good tags = 99579, N blacklisted = 1049
# Mean and SD of coverage for RdalM13, MS=4:  25.53 (+/- 23.34)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/M_tests/M_2 -i 6 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 145
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 4430
# 	Number of deleveraged but still blacklisted multistack loci = 641
# RdalM12.tags.tsv at M = 2 Total_tags = 69286, Good tags = 68298, N blacklisted = 988
# Mean and SD of coverage for RdalM12, M=2:  15.9 (+/- 21.18)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/M_tests/M_3 -i 6 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 93
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7872
# 	Number of deleveraged but still blacklisted multistack loci = 694
# RdalM12.tags.tsv at M = 3 Total_tags = 68974, Good tags = 67985, N blacklisted = 989
# Mean and SD of coverage for RdalM12, M=3:  16.07 (+/- 21.47)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/M_tests/M_4 -i 6 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 71
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 10161
# 	Number of deleveraged but still blacklisted multistack loci = 717
# RdalM12.tags.tsv at M = 4 Total_tags = 68678, Good tags = 67688, N blacklisted = 990
# Mean and SD of coverage for RdalM12, M=4:  16.19 (+/- 21.61)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/M_tests/M_5 -i 6 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 65
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 12015
# 	Number of deleveraged but still blacklisted multistack loci = 701
# RdalM12.tags.tsv at M = 5 Total_tags = 68483, Good tags = 67515, N blacklisted = 968
# Mean and SD of coverage for RdalM12, M=5:  16.27 (+/- 21.65)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/M_tests/M_6 -i 6 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 54
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 13442
# 	Number of deleveraged but still blacklisted multistack loci = 711
# RdalM12.tags.tsv at M = 6 Total_tags = 68298, Good tags = 67331, N blacklisted = 967
# Mean and SD of coverage for RdalM12, M=6:  16.37 (+/- 21.78)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/m_tests/m_2 -i 6 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 234
# 	Number of un-deleveraged multistack loci blacklisted = 206
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 5625
# 	Number of deleveraged but still blacklisted multistack loci = 884
# RdalM12.tags.tsv at m = 2 Total_tags = 88813, Good tags = 87489, N blacklisted = 1324
# Mean and SD of coverage for RdalM12, m=2:  12.71 (+/- 18.98)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/m_tests/m_3 -i 6 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 145
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 4423
# 	Number of deleveraged but still blacklisted multistack loci = 648
# RdalM12.tags.tsv at m = 3 Total_tags = 69286, Good tags = 68291, N blacklisted = 995
# Mean and SD of coverage for RdalM12, m=3:  15.9 (+/- 21.24)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/m_tests/m_4 -i 6 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 173
# 	Number of un-deleveraged multistack loci blacklisted = 118
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 3377
# 	Number of deleveraged but still blacklisted multistack loci = 499
# RdalM12.tags.tsv at m = 4 Total_tags = 53668, Good tags = 52878, N blacklisted = 790
# Mean and SD of coverage for RdalM12, m=4:  19.82 (+/- 23.55)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/m_tests/m_5 -i 6 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 150
# 	Number of un-deleveraged multistack loci blacklisted = 99
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 2736
# 	Number of deleveraged but still blacklisted multistack loci = 388
# RdalM12.tags.tsv at m = 5 Total_tags = 42413, Good tags = 41776, N blacklisted = 637
# Mean and SD of coverage for RdalM12, m=5:  24.21 (+/- 25.85)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/m_tests/m_6 -i 6 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 141
# 	Number of un-deleveraged multistack loci blacklisted = 83
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 2268
# 	Number of deleveraged but still blacklisted multistack loci = 306
# RdalM12.tags.tsv at m = 6 Total_tags = 34784, Good tags = 34254, N blacklisted = 530
# Mean and SD of coverage for RdalM12, m=6:  28.55 (+/- 27.86)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/MS_tests/MS_2 -i 6 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 352
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 4104
# 	Number of deleveraged but still blacklisted multistack loci = 967
# RdalM12.tags.tsv at MS = 2 Total_tags = 69286, Good tags = 67765, N blacklisted = 1521
# Mean and SD of coverage for RdalM12, MS=2:  15.61 (+/- 20.34)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/MS_tests/MS_3 -i 6 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 145
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 4416
# 	Number of deleveraged but still blacklisted multistack loci = 655
# RdalM12.tags.tsv at MS = 3 Total_tags = 69286, Good tags = 68284, N blacklisted = 1002
# Mean and SD of coverage for RdalM12, MS=3:  15.89 (+/- 21.18)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM12/MS_tests/MS_4 -i 6 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 202
# 	Number of un-deleveraged multistack loci blacklisted = 73
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 4622
# 	Number of deleveraged but still blacklisted multistack loci = 449
# RdalM12.tags.tsv at MS = 4 Total_tags = 69286, Good tags = 68562, N blacklisted = 724
# Mean and SD of coverage for RdalM12, MS=4:  16.13 (+/- 21.88)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/M_tests/M_2 -i 7 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 238
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7153
# 	Number of deleveraged but still blacklisted multistack loci = 984
# RdalM19.tags.tsv at M = 2 Total_tags = 104438, Good tags = 102921, N blacklisted = 1517
# Mean and SD of coverage for RdalM19, M=2:  25.11 (+/- 20.38)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/M_tests/M_3 -i 7 -m 3 -M 3 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 134
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 12422
# 	Number of deleveraged but still blacklisted multistack loci = 1076
# RdalM19.tags.tsv at M = 3 Total_tags = 103984, Good tags = 102479, N blacklisted = 1505
# Mean and SD of coverage for RdalM19, M=3:  25.41 (+/- 20.95)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/M_tests/M_4 -i 7 -m 3 -M 4 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 110
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 15985
# 	Number of deleveraged but still blacklisted multistack loci = 1067
# RdalM19.tags.tsv at M = 4 Total_tags = 103615, Good tags = 102143, N blacklisted = 1472
# Mean and SD of coverage for RdalM19, M=4:  25.59 (+/- 21.05)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/M_tests/M_5 -i 7 -m 3 -M 5 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 100
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 18563
# 	Number of deleveraged but still blacklisted multistack loci = 1090
# RdalM19.tags.tsv at M = 5 Total_tags = 103313, Good tags = 101828, N blacklisted = 1485
# Mean and SD of coverage for RdalM19, M=5:  25.72 (+/- 21.28)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/M_tests/M_6 -i 7 -m 3 -M 6 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 84
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 20655
# 	Number of deleveraged but still blacklisted multistack loci = 1096
# RdalM19.tags.tsv at M = 6 Total_tags = 103042, Good tags = 101567, N blacklisted = 1475
# Mean and SD of coverage for RdalM19, M=6:  25.83 (+/- 21.31)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/m_tests/m_2 -i 7 -m 2 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 321
# 	Number of un-deleveraged multistack loci blacklisted = 296
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 8337
# 	Number of deleveraged but still blacklisted multistack loci = 1275
# RdalM19.tags.tsv at m = 2 Total_tags = 113324, Good tags = 111432, N blacklisted = 1892
# Mean and SD of coverage for RdalM19, m=2:  23.09 (+/- 19.59)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/m_tests/m_3 -i 7 -m 3 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 238
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7127
# 	Number of deleveraged but still blacklisted multistack loci = 1010
# RdalM19.tags.tsv at m = 3 Total_tags = 104438, Good tags = 102895, N blacklisted = 1543
# Mean and SD of coverage for RdalM19, m=3:  25.09 (+/- 20.4)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/m_tests/m_4 -i 7 -m 4 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 291
# 	Number of un-deleveraged multistack loci blacklisted = 224
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6774
# 	Number of deleveraged but still blacklisted multistack loci = 901
# RdalM19.tags.tsv at m = 4 Total_tags = 100031, Good tags = 98615, N blacklisted = 1416
# Mean and SD of coverage for RdalM19, m=4:  26.12 (+/- 20.58)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/m_tests/m_5 -i 7 -m 5 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 278
# 	Number of un-deleveraged multistack loci blacklisted = 213
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6509
# 	Number of deleveraged but still blacklisted multistack loci = 836
# RdalM19.tags.tsv at m = 5 Total_tags = 96142, Good tags = 94815, N blacklisted = 1327
# Mean and SD of coverage for RdalM19, m=5:  27.08 (+/- 21.06)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/m_tests/m_6 -i 7 -m 6 -M 2 -p 7 -r -d
# 	Number of un-deleveraged lumberjacks blacklisted = 272
# 	Number of un-deleveraged multistack loci blacklisted = 212
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6271
# 	Number of deleveraged but still blacklisted multistack loci = 801
# RdalM19.tags.tsv at m = 6 Total_tags = 92606, Good tags = 91321, N blacklisted = 1285
# Mean and SD of coverage for RdalM19, m=6:  27.95 (+/- 21.28)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/MS_tests/MS_2 -i 7 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 2
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 555
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 6612
# 	Number of deleveraged but still blacklisted multistack loci = 1525
# RdalM19.tags.tsv at MS = 2 Total_tags = 104438, Good tags = 102063, N blacklisted = 2375
# Mean and SD of coverage for RdalM19, MS=2:  24.61 (+/- 18.67)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/MS_tests/MS_3 -i 7 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 3
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 238
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7143
# 	Number of deleveraged but still blacklisted multistack loci = 994
# RdalM19.tags.tsv at MS = 3 Total_tags = 104438, Good tags = 102911, N blacklisted = 1527
# Mean and SD of coverage for RdalM19, MS=3:  25.12 (+/- 20.43)
#
# Running Stacks command: ustacks -t fastq -f /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19.fq -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Ustacks/RdalM19/MS_tests/MS_4 -i 7 -m 3 -M 2 -p 7 -r -d --max_locus_stacks 4
# 	Number of un-deleveraged lumberjacks blacklisted = 295
# 	Number of un-deleveraged multistack loci blacklisted = 123
# 	Number of deleveraged lumberjacks = 0
# 	Number of deleveraged multistack loci = 7465
# 	Number of deleveraged but still blacklisted multistack loci = 672
# RdalM19.tags.tsv at MS = 4 Total_tags = 104438, Good tags = 103348, N blacklisted = 1090
# Mean and SD of coverage for RdalM19, MS=4:  25.49 (+/- 21.86)
#
#
#                ##### PLOTTING #####
# /home/djeffrie/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# This is a nice dataset! One or two bad samples but no problem. . .

# %% [markdown]
# #### Final Ustacks commands ----------------------------------------------
#
# Used M = 2, m = 3 and other defaults in final Ustacks

# %% [markdown]
# ###Cstacks

# %%
## INPUT INCREMENTAL_C PARAMETERS HERE -----------------------------------------

## Get IDs for the test samples

Parameter_dict = {}
Parameter_dict["Get_IDs"] = True
Parameter_dict["Ustacks_outs_dir"] = "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks"

IncC.Incremental_C(Parameter_dict)
# Out:
#  ## Sample IDs:
#
# RdalM10, ID = 8
# RdalM11, ID = 9
# RdalM12, ID = 10
# RdalM13, ID = 11
# RdalM14, ID = 12
# RdalM18, ID = 13
# RdalM19, ID = 14

# %%
## INPUT INCREMENTAL_C PARAMETERS HERE -----------------------------------------

Parameter_dict = {}
Parameter_dict["Get_IDs"] = False
Parameter_dict["batch_ID"] = 1
Parameter_dict["n_vals"] = [1,2,3,4]
Parameter_dict["threads"] = 7
Parameter_dict["Ustacks_outs_dir"] = "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks"
Parameter_dict["sample_ids"] = [10,11,12]   ## add specific sample ID's of samples you want to look at, if this is not all samples in the directory given above. Leave as empty list if not.
Parameter_dict["run_cline_switch"] = 1     ## to switch on (1) to run stacks cline or off (0) to run pipeline on existing outputs

pp = pprint.PrettyPrinter(indent=2)
pp.pprint(Parameter_dict)
# Out:
# { 'Get_IDs': False,
#   'Ustacks_outs_dir': '/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks',
#   'batch_ID': 1,
#   'n_vals': [1, 2, 3, 4],
#   'run_cline_switch': 1,
#   'sample_ids': [10, 11, 12],
#   'threads': 7}

# %%
IncC.Incremental_C(Parameter_dict)
# Out:
# ### ----- Making and running command lines ----- ###
#
# n value = 1
# cstacks -b 1 -n 1 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM12 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM13 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM14 7 -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/n_1
# Running Command line
#
# n value = 2
# cstacks -b 1 -n 2 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM12 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM13 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM14 7 -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/n_2
# Running Command line
#
# n value = 3
# cstacks -b 1 -n 3 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM12 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM13 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM14 7 -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/n_3
# Running Command line
#
# n value = 4
# cstacks -b 1 -n 4 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM12 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM13 -s /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/RdalM14 7 -o /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Cstacks/n_4
# Running Command line
#
#
# #### ---- Plotting the tag sharing patterns between individuals ---- ####
#
# Number of samples specified: 3

# %% [markdown]
# Tag sharing looks good here.

# %% [markdown]
# ####Final Cstacks command ---------------------------------------------------------------------
#
# n = 2
#
# All other parameters default

# %% [markdown]
# ### Populations
#
#          - First ran populations with relaxed filtering parameters (r = 0.5 and p = 1) to allow me to look at
#          the amount of missing data per individual. Then remove these samples before doing other parameter tests . .
#          (Plot not shown)

# %% [markdown]
# ####Removed RdalM12 due to high locus dropout rate

# %% [markdown]
# #### Final Populations sample set:

# %%
wd = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/"

blacklist = MISC.missing_data_finder("%s/batch_1.vcf" % wd, wd)
# Out:
# Outputs written to:
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final//Tag_dropouts_per_sample.txt
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final//Tag_dropouts_per_tag.txt
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final//Tag_dropouts_per_sample.pdf
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final//Tag_dropouts_per_tag.pdf
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final//blacklist.txt

# %% [markdown]
# ####Now testing populations parameters -r and -m (p tests not useful here as always want both sexes included)

# %%
## parameters for the Incremental populations analyses

Analysis_parameters1 = {}

## Test parameters
Analysis_parameters1["parameters"] = ["r","m"]
Analysis_parameters1["p_vals"] = []
Analysis_parameters1["p_default"] = 2 ## The value of p when other params are being tested. Set as 2 for males and females!
Analysis_parameters1["r_vals"] = [0.75, 0.85, 0.9, 0.95]
Analysis_parameters1["r_default"] = 0.75 ## The value of r when other params are being tested. 
Analysis_parameters1["m_vals"] = [2,3,4,5,6]
Analysis_parameters1["m_default"] = 3 ## The value of m when other params are being tested. 
Analysis_parameters1["Populations_test_dir_path"] = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/"
Analysis_parameters1["run_cline_switch"] = 1 ## run command line or not. 

## Mandatory Populations options
Analysis_parameters1["b"] = 1 ## batch ID
Analysis_parameters1["P"] = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/"## Path to stacks outputs
Analysis_parameters1["M"] = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt" ## All samples

## Outputs parameters
Analysis_parameters1["vcf"] = True
Analysis_parameters1["vcf_haplotypes"] = True

## Optional parameters
Analysis_parameters1["t"] = 7 ## number of threads
Analysis_parameters1["min_maf"] = 0.05 ## number of threads

#Analysis_parameters1["B"] = None ## Locus blacklist
Analysis_parameters1["write_single_snp"] = True ## switch to write first snp of locus or not.
Analysis_parameters1["fstats"] = False

# %%
Sample_data, Locus_data, group_info = IncPop.Incremental_Pop(Analysis_parameters1)
# Out:
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 3 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_075
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.85 -p 2 -m 3 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_085
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.9 -p 2 -m 3 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_09
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.95 -p 2 -m 3 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 2 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_2
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 3 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_3
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 4 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_4
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 5 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_5
# ## Running command lines ##
# populations -b 1 -P /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/ -M /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests/sex_info_kept.txt -t 7 -r 0.75 -p 2 -m 6 --min_maf 0.05 --write_single_snp --vcf --vcf_haplotypes    ## FINISHED
# Files moved to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_6
# ##### Getting and plotting the data ######
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_075/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_075/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_075/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_085/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_085/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_085/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_09/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_09/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_09/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//r_tests/r_095/batch_1.vcf.altered.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_2/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_2/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_2/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_3/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_3/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_3/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_4/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_4/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_4/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_5/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_5/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_5/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_6/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_6/batch_1.vcf.altered
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_tests//m_tests/m_6/batch_1.vcf.altered

# %% [markdown]
# So the amount of missing data is very negligable, its a nice dataset, very consistent across these samples

# %% [markdown]
# #### Final Populations command
#
# -p 2
#
# -r 0.75
#
# -M sex_info.txt
#
# all other parameters defaults

# %% [markdown]
# #### Check the final snp dataset, e.g. amount of locus/ sample dropout, coverage etc

# %%
final_vcf = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1.vcf"
final_popmap = "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Populations/sex_info_kept.txt"

# %%
MISC.av_tag_cov(final_vcf, "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Av_tag_cov.out")
MISC.sample_Avcov_from_vcf(final_vcf)
# Out:
# Number of tags =  12198
# Average tag coverage 33.3192918693 (+- 31.6378661027 )
# Mean sample coverage = 33.32 (+/3.12)

# %% [markdown]
# ### Now find sex linked markers using the 3 approaches in Brelsford & Lavanchy et al (2016)

# %%
# %matplotlib inline
import MISC_RAD_tools as MISC
wd = "//home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/"
final_vcf = "%s/batch_1.vcf" % wd
MISC.av_tag_cov(final_vcf, "%s/Av_tag_cov.out" % wd)
#MISC.sample_Avcov_from_vcf(final_vcf)
# Out:
# Number of tags =  12198
# Average tag coverage 33.3192918693 (+- 31.6378661027 )

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Populations_tests/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Populations_tests/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Populations_tests/Sex_ID_info.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
XYset, ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 12198
# Number of samples = 18
# Number of loci with too few samples = 2903
# Number of loci with low MAF = 3061
# Number of loci with enough data = 6233
# Number of putative X linked snps = 198
# Number of putative X linked tags = 171
# Number of putative Z linked markers = 25
# Number of putative Z linked tags = 24
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 12198
# Number of samples = 18
# Number of loci with too few samples = 3975
# Number of loci with low MAF = 1989
# Number of loci with enough data = 0
# Number of putative X linked snps = 225
# Number of putative X linked tags = 184
# Number of putative Z linked markers = 41
# Number of putative Z linked tags = 37
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of males: 7
# Number of males: 12
# Number of Putative Y linked tags: 31
# Number of Putative W linked tags: 1
#
#  ### DONE! ###
#
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 217
# Final number of ZW tags = 42
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Rdalmatina/Incremental/Populations_tests

# %% [markdown]
# ### Guillaume found a couple of mis-assigned samples in his analyses, so I will check for the same

# %%
import vcf
from Bio import SeqIO


vcfpath = "/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1.vcf.altered"
XY_tags_file = open("/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/Putative_XYlinked_makers.fa", 'r').readlines()

XY_tags = []

for line in XY_tags_file:
    if "Xlinked_het" in line or  "Xlinked_freq" in line:
        XY_tags.append(line.split("_")[2])

XY_set = set(XY_tags)

SL_vcf = open("/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps.vcf", 'w')

XYtags_parsed = SeqIO.parse(XY_tags, "fasta")
vcf_parsed = vcf.Reader(open(vcfpath, 'r'))

XY_ids = []
    
for line in open(vcfpath,'r').readlines():
    if line.startswith("#"):
        SL_vcf.write(line)
    else:
        if line.split()[2] in XY_set:
            SL_vcf.write(line)
SL_vcf.close()

# %%
# %%bash
#
# ## All data
# sed 's/_/-/g' /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1.vcf > /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_adegenet.vcf
#
# ~/Programs/plink_linux_x86_64/plink --vcf /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_adegenet.vcf --recode A --allow-extra-chr -out /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink
#
#
# ## XY linked data only
# sed 's/_/-/g' /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps.vcf > /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered.vcf
#
# ~/Programs/plink_linux_x86_64/plink --vcf /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered.vcf  --recode A --allow-extra-chr -out /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_adegenet.vcf
#
# 32084 MB RAM detected; reserving 16042 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink-temporary.fam
# written.
# 12198 variants loaded from .bim file.
# 18 people (0 males, 0 females, 18 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 18 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.830086.
# 12198 variants and 18 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/batch_1_altered_plink.raw
# done.
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered.vcf
#
# 32084 MB RAM detected; reserving 16042 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink-temporary.fam
# written.
# 243 variants loaded from .bim file.
# 18 people (0 males, 0 females, 18 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 18 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.937586.
# 243 variants and 18 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/Sex_linked_markers/XY_linked_snps_altered_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.txt")

# %%
# %%R
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Rdalmatina/Populations_final/")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('./batch_1_altered_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T) ## If you are on linus you can change n.cores. But >1 core is not supported on windows.
#
# ## Sex linked SNPs only (about 150)
# XY_linked_data <- read.PLINK('../Sex_linked_markers/XY_linked_snps_altered_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("./Sex_ID_info.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 2, nf = 5)
# ## again if on linux, you can set "parallel" to TRUE to use multi cores
# ## Also, here I have specified nf = 3 to retain 3 PCs. If I don't do this it will plot the eigenvalues and interactively ask you
# ## how many PCs to retain. This even works in Jupyter! Cos Jupyter and rpy2 are bloody cool! Thats Why!
#
# pca2 <- glPca(XY_linked_data, parallel = TRUE, n.cores = 2, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.
#
#
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 40 -h 40 -u cm
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "R. dalmatina All data", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = c("violet", "black"),
#            func_cex = 4) ## Size of points and text in plots) ## Colours to use
# Out:
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Saving 15.7 x 15.7 in image
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R -w 40 -h 40 -u cm
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca2,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "R. dalmatina Pop all SNPs", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = c("violet", "black"),
#            func_cex = 4) ## Size of points and text in plots) ## Colours to use

# %% [markdown]
# ### This is interesting ...
#
# There are a couple of interesting samples here, one "female" - RdalM21 and one "male" - RdalM03. Perhaps this is also a misassignment and it is just another male haplotype
#
# If needed I could take these samples out and re-run this, but 217 markers is a good number and it is clear there are a couple of haplotypes here too.

# %% [markdown]
# ## Summary:
# ###217 XY linked tags, suggests an XY system (after accounting for overlap between methods)
# ###42 tags pointing to ZW are likely to be false positives

# %% [markdown]
# ## Manual mapping

# %%
from Bio.Blast.Applications import NcbiblastnCommandline
import MISC_RAD_tools as MISC
import shutil

Rtemp_fasta = "/home/djeffrie/Data/Genomes/Rtemp/V2/Rtemp_gapfilled_iter2_flted2.fa"
Rtemp_db = "/home/djeffrie/Data/Genomes/Rtemp/V2/Rtemp_gapfilled_iter2_flted2-blastn-db"

Nano_fasta = "/home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Nanorana_blast_db/Nanorana_parkeri.genome.v2.fasta"
Nanorana_db = "/home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Nanorana_blast_db/Nanorana_blast_db"

Xen_db = "/home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Xenopus_genome/Xenoupus_blastdb"
Xen_fasta = "/home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Xenopus_genome/Xtropicalis.v9.repeatMasked.fa"


best_hit_crit = 1e-5
Eval_threshold = 1e-20
Window = 8000

wd = "/home/djeffrie/Data/Mapping_SL_tags_to_genomes/Sex_linked_tags/Manual_mapping/R_dalmatina/"
prefix = "R_dal"

### Tags to Rtemp

print "\n##  Mapping tags to R. temporaria  ##\n"

tags ="%s/%s" % (wd, "R_dalmatina.fa")
tags_to_Rtemp_blastnouts = "%s/%s" % (wd, "%s_%s" % (prefix, "tags_Rtemp_blastnouts.xml"))

blastn_cline = NcbiblastnCommandline(query=tags, db=Rtemp_db, outfmt=5, out=tags_to_Rtemp_blastnouts)
stdout, stderr = blastn_cline()

Rtemp_records = MISC.BlastParseExtra(tags_to_Rtemp_blastnouts, Rtemp_fasta , best_hit_crit, Eval_threshold,Window)

Rtemp_blast_chunks = "%s/%s" % (wd,  "%s_%s" % (prefix, "Rtemp_8k_chunks.fa"))

shutil.move("%s/%s" % (wd,"blast_8000_chunks.fa"), Rtemp_blast_chunks)


### Rtemp chunks to Nanorana

print "\n##  Mapping Rtemp chunks Nanorana  ##\n"

tags_Rtemp_Nano_blastnouts = "%s/%s" % (wd, "%s_%s" % (prefix, "Rtemp_Nano_blastnouts.xml"))

blastn_cline = NcbiblastnCommandline(query=Rtemp_blast_chunks, db=Nanorana_db, outfmt=5, out=tags_Rtemp_Nano_blastnouts)
stdout, stderr = blastn_cline()

Nano_records = MISC.BlastParseExtra(tags_Rtemp_Nano_blastnouts, Nano_fasta , best_hit_crit, Eval_threshold,Window)

Rtemp_Nano_blast_chunks = "%s/%s" % (wd,"%s_%s" % (prefix, "Rtemp_Nano_8k_chunks.fa"))

shutil.move("%s/%s" % (wd,"blast_8000_chunks.fa"), Rtemp_Nano_blast_chunks)



### Nanorana chunks to Xenopus

print "\n##  Mapping Nanorana chunks Xenopus  ##\n"

tags_Rtemp_Nano_Xen_blastnouts = "%s/%s" % (wd, "%s_%s" % (prefix, "Rtemp_Nano_Xen_blastnouts.xml"))

blastn_cline = NcbiblastnCommandline(query=Rtemp_Nano_blast_chunks, db=Xen_db, outfmt=5, out=tags_Rtemp_Nano_Xen_blastnouts)
stdout, stderr = blastn_cline()

Xen_records = MISC.BlastParseExtra(tags_Rtemp_Nano_Xen_blastnouts, Xen_fasta , best_hit_crit, Eval_threshold,Window)

Xen_chunks = "%s/%s" % (wd,"%s_%s" % (prefix, "Rtemp_Nano_Xen_8kb_chunks.fa"))
                                      
shutil.move("%s/%s" % (wd,"blast_8000_chunks.fa"), Xen_chunks)



### Get the Xenopus summary

print "\n##  Final Xenopus hits  ##\n"

from collections import Counter 
Xen_hits = []
for i in Xen_records:
    Xen_hits.append(Xen_records[i]["Ref_hit_id"])
    print i, Xen_records[i]["Ref_hit_id"]
# Out:
# ##  Mapping tags to R. temporaria  ##
#
# Number of multi-alingments kept: 32
# Number of unique alingments kept: 31
# Getting subject scaffold segments from /home/djeffrie/Data/Genomes/Rtemp/V2/Rtemp_gapfilled_iter2_flted2.fa . . .
# 63 sequence scaffold segments are in /home/djeffrie/Data/Mapping_SL_tags_to_genomes/Sex_linked_tags/Manual_mapping/R_dalmatina//blast_8000_chunks.fa
#
# ##  Mapping Rtemp chunks Nanorana  ##
#
# Number of multi-alingments kept: 39
# Number of unique alingments kept: 1
# Getting subject scaffold segments from /home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Nanorana_blast_db/Nanorana_parkeri.genome.v2.fasta . . .
# 39 sequence scaffold segments are in /home/djeffrie/Data/Mapping_SL_tags_to_genomes/Sex_linked_tags/Manual_mapping/R_dalmatina//blast_8000_chunks.fa
#
# ##  Mapping Nanorana chunks Xenopus  ##
#
# Number of multi-alingments kept: 6
# Number of unique alingments kept: 4
# Getting subject scaffold segments from /home/djeffrie/Data/RADseq/STOECK/Bviridis/Genome_mapping/Xenopus_genome/Xtropicalis.v9.repeatMasked.fa . . .
# 9 sequence scaffold segments are in /home/djeffrie/Data/Mapping_SL_tags_to_genomes/Sex_linked_tags/Manual_mapping/R_dalmatina//blast_8000_chunks.fa
#
# ##  Final Xenopus hits  ##
#
# scaffold1498 Chr05
# scaffold66 Chr05
# scaffold145 Chr05
# scaffold1068 Chr05
# scaffold1228 Chr09
# scaffold2477 Chr02
# scaffold123 Chr05
# scaffold568 Chr01
# scaffold1042 Chr05
