# %% [markdown]
# # Looking for sex linked tags in <i>Bufo spinosus</i>

# %%
# %matplotlib inline
import MISC_RAD_tools as MISC

myvcf = "/home/djeffrie/Data/RADseq/Bbufo/batch_1.vcf"
mycat = "/home/djeffrie/Data/RADseq/Bbufo/batch_1.catalog.tags.tsv.gz"
mypopmap = "/home/djeffrie/Data/RADseq/Bbufo/Sex_ID_Info.txt"

# %% [markdown]
# (Using Dans super sexy sex-linked marker finding scripts)

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  mycat ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =   myvcf ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = mypopmap ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.5  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

XYset, ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 33591
# Number of samples = 40
# Number of loci with too few samples = 0
# Number of loci with low MAF = 8586
# Number of loci with enough data = 25004
# Number of putative X linked snps = 34
# Number of putative X linked tags = 34
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 33591
# Number of samples = 40
# Number of loci with too few samples = 0
# Number of loci with low MAF = 8586
# Number of loci with enough data = 25004
# Number of putative X linked snps = 277
# Number of putative X linked tags = 277
# Number of putative Z linked markers = 20
# Number of putative Z linked tags = 20
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 20
# Number of males: 20
# Number of Putative Y linked tags: 72
# Number of Putative W linked tags: 3
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Bbufo
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 353
# Final number of ZW tags = 23

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  mycat ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =   myvcf ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = mypopmap ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.7  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.7 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 3 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

XYset_07, ZWset_07 = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 33591
# Number of samples = 40
# Number of loci with too few samples = 0
# Number of loci with low MAF = 8586
# Number of loci with enough data = 25004
# Number of putative X linked snps = 0
# Number of putative X linked tags = 0
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 33591
# Number of samples = 40
# Number of loci with too few samples = 0
# Number of loci with low MAF = 8586
# Number of loci with enough data = 25004
# Number of putative X linked snps = 59
# Number of putative X linked tags = 59
# Number of putative Z linked markers = 1
# Number of putative Z linked tags = 1
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 20
# Number of males: 20
# Number of Putative Y linked tags: 72
# Number of Putative W linked tags: 3
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Bbufo
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 131
# Final number of ZW tags = 4

# %% [markdown]
# ### Now map them to <i>R. temporaria </i> genome

# %% [markdown]
# Note - I filter the blast hits with the function below, see help for details on how it works

# %%
help(MISC.BlastParseExtra)
# Out:
# Help on function BlastParseExtra in module MISC_RAD_tools:
#
# BlastParseExtra(infile, genome_fa, best_hit_criteria, Eval_thresh, get_frags_switch=1, window_size=2000, verb=0)
#     Usage: BlastParseExtra.py  <blast_xml_output> <genome_fasta> <best_hit_criteria> <Eval_thresh> <get_frags_switch> <window_size> <verb>
#
#     <blast_xml_output>  -  absolute path to blast xml output
#     <genome_fasta>      -  absolute path to genome fasta file
#     <best_hit_criteria> -  factor by which the best e-value must be lower than the second best (recommended: 1e-5)
#     <Eval_thresh>       -  e-value threshold for unique alignments
#     <window_size>       -  size of the window (in bp) around the mapping coordinates used to extract the subject scaffold segment
#     <get_frags_switch>  -  switch (1 = on, 0 = off) for getting fragments around the mapping
#     <verb>              -  become verbose
#
#     This script first filters the mappings in the <blast_xml_output> for uniq hits with evalues better than
#     <Eval_thresh> or for multi hits where the best hit is <best_hit_criteria> orders of magnitude better than
#     the second.
#
#     It will then retrieve a segment of the scaffold from <genome_fasta> which is + and - the <window_size> around
#     the mapping coordinates for each query. If the ends of the scaffold are not within this window, then the
#     length of the segment will be (length of mapped query sequence + 2 x <window_size>). However if an end of a
#     scaffold is within this window, the segment will be trimmed to this length.

# %%
from Bio.Blast.Applications import NcbiblastnCommandline
import MISC_RAD_tools as MISC
import shutil

Bbufo_SLM_fasta = "/home/djeffrie/Data/RADseq/Bbufo/Putative_XYlinked_makers.fa"
Rtemp_genome_db = "/home/djeffrie/Data/Genomes/Rtemp_hybrid/Genome/Rtemp_anchored_all_scaffolds.fasta"
Rtemp_genome_fasta = "/home/djeffrie/Data/Genomes/Rtemp_hybrid/Genome/Rtemp_anchored_all_scaffolds.fasta"

best_hit_crit = 1e-5
Eval_threshold = 1e-20
Window = 2000

### Tags to R. temporaria

print "\n##  Aligning tags to R. temporaria with Blastn ##"

tags = Bbufo_SLM_fasta
tags_to_Rtemp_blastnouts = "/home/djeffrie/Data/RADseq/Bbufo/Bufo_SLM_tags_Rtemp_blastnouts.xml"

blastn_cline = NcbiblastnCommandline(query=tags, db=Rtemp_genome_db, outfmt=5, out=tags_to_Rtemp_blastnouts, max_target_seqs=20)
stdout, stderr = blastn_cline()

print "\n## Alignment done, filtering blast hits ##"

Bbufo_filtered_alignments = MISC.BlastParseExtra(tags_to_Rtemp_blastnouts, Rtemp_genome_fasta , best_hit_crit, Eval_threshold, 0 , Window, 1)
# Out:
# ##  Aligning tags to R. temporaria with Blastn ##
#
# ## Alignment done, filtering blast hits ##
# Number of multi-alingments kept: 0
# Number of unique alingments kept: 1

# %%
Bbufo_filtered_alignments
# Out:
# {u'X_linkedLocusID_104990_91_9764070_Xlinked_het_Xlinked_freq': {'Evalue': 5.06853e-25,
#   'Hit_end_coord': 404053441,
#   'Hit_start_coord': 404053523,
#   'Ref_hit_id': 'chr1'}}

# %% [markdown]
# So - a lot of sex linked markers pointing to XY, but can't map them, I guess the genomes are just too far away. . . . can think about going through a different species, or mapping to the linkage map and inferring the chromosome from that.
