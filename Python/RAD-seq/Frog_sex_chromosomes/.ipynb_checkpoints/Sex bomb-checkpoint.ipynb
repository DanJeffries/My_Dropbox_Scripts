# %% [markdown]
# ### RADseq analyses for adults and families of Bombina bombina and Bombina variagata

# %% [markdown]
# ### Bbomb

# %%
# %matplotlib inline
from operator import itemgetter
from __future__ import division
import os
import Incremental_U as IncU 
import Incremental_C as IncC
import Incremental_Pop_mod as IncPop
import MISC_RAD_tools as MISC
import pprint
import subprocess

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# ###I will first run the adults through populations separately according to their population, and run sex linkage analyses to look for sex linked markers

# %% [markdown]
# ### Population PL

# %%
working_dir = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL"
myvcf_PL = "%s/batch_1.vcf" % working_dir

MISC.Summary_plotter(myvcf_PL, "1111", False)
# Out:
# #### DONE ####
#
# Number of Loci = 11658
# Average coverage = 24.5932871562 reads

# %% [markdown]
# Data looks great, apart from one sample that didn't work.

# %% [markdown]
# ### Do a quick PCA to check for any cryptic population structure

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/batch_1.vcf > $wd/batch_1_altered_adegenet.vcf
#
# /home/djeffrie/Programs/plink_linux_x86_64/plink --vcf $wd/batch_1_altered_adegenet.vcf --recode A --allow-extra-chr -out $wd/batch_1_altered_adegenet_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink-temporary.fam
# written.
# 11658 variants loaded from .bim file.
# 48 people (0 males, 0 females, 48 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 48 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.941991.
# 11658 variants and 48 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1_altered_adegenet_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.R")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('batch_1_altered_adegenet_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("./Bbomb_ADs_PL_popmap.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
#
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "BBomb_ADs_PL", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(2), ## Colours to use
#            func_cex = 5) ## Size of points and text in plots)
# Out:
# /home/djeffrie/anaconda3/envs/py27/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Saving 19.7 x 19.7 in image
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ### Ok, doesn't look to be much structure in there, good news.
#
# ### Lets look for some sex linked markers

# %%
working_dir = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/"

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_PL/Sex_ID_info_Bbomb_ADs_PL.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.8 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
Bbomb_ADs_PL_XYset, Bbomb_ADs_PL_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 11658
# Number of samples = 48
# Number of loci with too few samples = 152
# Number of loci with low MAF = 0
# Number of loci with enough data = 11505
# Number of putative X linked snps = 2
# Number of putative X linked tags = 2
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 11658
# Number of samples = 48
# Number of loci with too few samples = 152
# Number of loci with low MAF = 0
# Number of loci with enough data = 11505
# Number of putative X linked snps = 38
# Number of putative X linked tags = 38
# Number of putative Z linked markers = 17
# Number of putative Z linked tags = 17
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 24
# Number of males: 24
# Number of Putative Y linked tags: 1
# Number of Putative W linked tags: 0
#
#  ### DONE! ###
# /home/djeffrie/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib_venn/_venn3.py:53: UserWarning: Circle A has zero area
#   warnings.warn("Circle A has zero area")
# /home/djeffrie/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib_venn/_venn3.py:61: UserWarning: Circle C has zero area
#   warnings.warn("Circle C has zero area")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-976e4801b105> in <module>()
# ----> 1 Bbomb_ADs_PL_XYset, Bbomb_ADs_PL_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
#
# /home/djeffrie/Dropbox/My_Dropbox_Scripts/Python/My_Modules/MISC_RAD_tools.pyc in Super_SLM_finder(Parameter_dict, execute_seq, write_files)
#    2385
#    2386                     for tag in catalog:
# -> 2387                         if locus.split("_")[0] == tag.split()[2]:
#    2388                             Putative_XYlinked_makers_file.write(">X_linkedLocusID_%s_%s\n" % (locus, method))
#    2389                             Putative_XYlinked_makers_file.write("%s\n" % (tag.split()[8]))
#
# KeyboardInterrupt:

# %% [markdown]
# No sex linked loci - whats going on!

# %% [markdown]
# ### Population SRB

# %%
working_dir = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB"
myvcf_SRB = "%s/batch_1.vcf" % working_dir

MISC.Summary_plotter(myvcf_SRB, "1111", False)
# Out:
# #### DONE ####
#
# Number of Loci = 18365
# Average coverage = 25.1270407932 reads

# %% [markdown]
# ### Check with PCA

# %%
# %%bash
#
# wd=/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB  ## just change this line
#
# ## All data
# sed 's/_/-/g' $wd/batch_1.vcf > $wd/batch_1_altered_adegenet.vcf
#
# /home/djeffrie/Programs/plink_linux_x86_64/plink --vcf $wd/batch_1_altered_adegenet.vcf --recode A --allow-extra-chr -out $wd/batch_1_altered_adegenet_plink
# Out:
# PLINK v1.90b3.39 64-bit (4 Aug 2016)       https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --out /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink
#   --recode A
#   --vcf /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet.vcf
#
# 32083 MB RAM detected; reserving 16041 MB for main workspace.
# --vcf:
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink-temporary.bed
# +
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink-temporary.bim
# +
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink-temporary.fam
# written.
# 18365 variants loaded from .bim file.
# 48 people (0 males, 0 females, 48 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 48 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.964744.
# 18365 variants and 48 people pass filters and QC.
# Note: No phenotypes present.
# --recode A to
# /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1_altered_adegenet_plink.raw
# done.

# %%
# %%R
#
# ## Load packages and functions needed
#
# library(adegenet)
# library(ggplot2)
# source("~/Dropbox/My_Dropbox_Scripts/R/My_functions/Sex_sorter_PCA_plotting_function.R")
#
# ## Reading in the data -------------------------------------------------------------------------------
#
# setwd("/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB")
#
# ## All SNPs (about 80,000)
# alldata <- read.PLINK('batch_1_altered_adegenet_plink.raw', chunkSize=1000, parallel = TRUE, n.cores=1, saveNbAlleles=T)
#
# ## Sex information:
# sexes <- read.delim("./Bbomb_ADs_SRB_popmap.txt", header = F)
#
# ## Running PCA ---------------------------------------------------------------------------------------
#
# pca1 <- glPca(alldata, parallel = TRUE, n.cores = 6, nf = 5)
# Out:
#  Reading PLINK raw format into a genlight object...
#
#
#  Reading loci information...
#
#  Reading and converting genotypes...
# .
#  Building final object...
#
# ...done.

# %%
# %%R -w 50 -h 50 -u cm
#
# ## Plotting the PCAs using the Sex_sorter function.
#
# Sex_sorter(pca1,   ## PCA object
#            sexes,  ## sex_info file
#            c(1,2), ## which components to plot
#            Title = "BBomb_ADs_SRB", ## plot title
#            xtitle = "PC1", ## X axis title
#            ytitle = "PC2", ## Y axis title
#            Palette = rainbow(2), ## Colours to use
#            func_cex = 5) ## Size of points and text in plots)

# %% [markdown]
# Again, no population structure that I can see.

# %% [markdown]
# ### Look for sex linked markers

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/Populations_Bbomb_ADs_SRB/Sex_ID_info_Bbom_ADs_SRB.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.8 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
Bbomb_ADs_PL_XYset, Bbomb_ADs_PL_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 18365
# Number of samples = 48
# Number of loci with too few samples = 272
# Number of loci with low MAF = 0
# Number of loci with enough data = 18092
# Number of putative X linked snps = 0
# Number of putative X linked tags = 0
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 18365
# Number of samples = 48
# Number of loci with too few samples = 272
# Number of loci with low MAF = 0
# Number of loci with enough data = 18092
# Number of putative X linked snps = 4
# Number of putative X linked tags = 4
# Number of putative Z linked markers = 9
# Number of putative Z linked tags = 9
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 24
# Number of males: 24
# Number of Putative Y linked tags: 10
# Number of Putative W linked tags: 0
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 14
# Final number of ZW tags = 9

# %% [markdown]
# ### Bvar

# %% [markdown]
# ### Population CH

# %%
working_dir = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_CH/"
myvcf_CH = "%s/batch_1.vcf" % working_dir

MISC.Summary_plotter(myvcf_CH, "1111", False)
# Out:
# #### DONE ####
#
# Number of Loci = 9375
# Average coverage = 24.8937777778 reads

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_CH/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_CH/Bvar_ADs_CH_Sex_info_IDs.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
Bvar_ADs_CH_XYset, Bvar_ADs_CH_ZWset = MISC.Super_SLM_finder(Parameter_dict, "111")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 9375
# Number of samples = 48
# Number of loci with too few samples = 332
# Number of loci with low MAF = 0
# Number of loci with enough data = 9042
# Number of putative X linked snps = 1
# Number of putative X linked tags = 1
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 9375
# Number of samples = 48
# Number of loci with too few samples = 332
# Number of loci with low MAF = 0
# Number of loci with enough data = 9042
# Number of putative X linked snps = 2
# Number of putative X linked tags = 2
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
#
#  ### DONE! ###
#
#
# ##### Using Sex specific tag approach #####
#
#
# SUMMARY:
# Number of females: 24
# Number of males: 24
# Number of Putative Y linked tags: 14
# Number of Putative W linked tags: 12
#
#  ### DONE! ###
# /home/djeffrie/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib_venn/_venn3.py:57: UserWarning: Circle B has zero area
#   warnings.warn("Circle B has zero area")
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 16
# Final number of ZW tags = 12

# %% [markdown]
# ### UA population

# %%
working_dir = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_UA/"
myvcf_CH = "%s/batch_1.vcf" % working_dir

MISC.Summary_plotter(myvcf_CH, "1111", False)
# Out:
# #### DONE ####
#
# Number of Loci = 41986
# Average coverage = 23.0282820221 reads

# %%
Parameter_dict = {}

##### Data ########################

Parameter_dict['Catalog'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb/batch_1.catalog.tags.tsv.gz" ## Path to the catalog file - used by all approaches.
Parameter_dict['VCF'] =  "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_UA/batch_1.vcf" ## path to vcf file (note this will be altered to make header compatible with Pyvcf. New vcf will have same name with ".altered" appended to the end). Used by Approach i) and ii)
Parameter_dict['Pop_map'] = "/home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bvar/Populations_Bvar_ADs_UA/Bvar_ADs_UA_Sex_ID_info.txt" ## path to population map file containing sex information. Same format as Stacks pop map file. Used by all approaches.

###### threshold parameters #######

# 1. Frequency approach
Parameter_dict['X_or_Z_freq_threshold'] = 0.4  ## (Default = 0.4) The lower threshold for the freq caluclation to find sex linked snps, e.g. for an XY system, a threshold of 0.4 means that f(F) - f(M) can be >= 0.4 and <= 0.6 (the upper threshold is automatically calculated to be the same distance above 0.5 as the lower threshold is below 0.5) 
Parameter_dict['sample_presence_cutoff1'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold1'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci below this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold1'] =  0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 
Parameter_dict['homogametic_REF_allele_freq'] = 0.9 ## (Default = 0.95) The sex linked SNP will be the minor allele, so a check is done to make sure that the homogametic sex is above the threshold specified for the major allele. In theory this should be 1. But allowing for some error 0.95 is used as a default. 

# 2. Heterozygosity approach
Parameter_dict['homogamtic_homozygosity_threshold'] = 0.9 ## (Default = 0.9) The minimum number of the homogametic sex which must not have the tag for that tag to be considered linked to the sex-limited chromosome
Parameter_dict['heterogamtic_heterozygosity_threshold'] = 0.5 ## (Default = 0.5) The lower threshold for the proportion of heterozygotes in the heterogametic sex at a locus 
Parameter_dict['sample_presence_cutoff2'] = 0.75 ## (Default = 0.75) a locus must be called in at least this proportion of all samples (not within populations) to be considered
Parameter_dict['coverage_threshold2'] = 7 ## (Default = 3) a locus must have at least this threshold in a sample to be considered for that sample. Note that loci bels this threshold will be removed from a sample, and this can push the locus below the sample presence cut-off, which will then remove the locus.
Parameter_dict['maf_threshold2'] = 0.05 ## (Default = 0.05) minor allele frequency cutoff for a locus across all samples. 

# 3. Sex specific presence or absence approach
Parameter_dict['sex_presence_threshold'] =  0.5 ## (Default = 0.5) The minimum percenatage of the heterogametic sex that a tag must be present in.

# %%
Bvar_ADs_UA_XYset, Bvar_ADs_UA_ZWset = MISC.Super_SLM_finder(Parameter_dict, "110")
# Out:
# ##### Using SNP frequency approach ####
#
# Number of loci = 41986
# Number of samples = 49
# Number of loci with too few samples = 1272
# Number of loci with low MAF = 0
# Number of loci with enough data = 40713
# Number of putative X linked snps = 0
# Number of putative X linked tags = 0
# Number of putative Z linked markers = 0
# Number of putative Z linked tags = 0
# ***DONE!***
#
#
# ##### Using SNP heterozygosity approach #####
#
# Number of loci = 41986
# Number of samples = 49
# Number of loci with too few samples = 1272
# Number of loci with low MAF = 0
# Number of loci with enough data = 40713
# Number of putative X linked snps = 7
# Number of putative X linked tags = 7
# Number of putative Z linked markers = 9
# Number of putative Z linked tags = 9
#
#  ### DONE! ###
#
# Sex linked tags outputted to fastas 'Putative_XYlinked_makers.fa' and Putative_ZWlinked_makers.fa
# in the directory /home/djeffrie/Data/RADseq/Dufresnes/Bbom/Populations_Bbomb
#
#  ## After merging tags accross methods ##
#
# Final number of XY tags = 7
# Final number of ZW tags = 9

# %% [markdown]
# ### Summary
#
#
# Unfortunately, no sexs linked markers, despite having an awesome dataset!
#
# I can't think of anything that would get in the way of this, the demultiplexing looks fine, based on the summary stats across all samples, data seem to be partitioned into separate popualtions / families etc accurately, so it would follow that males and females are also demultiplexed properly.
#
# And the sexing, according to Christophe. That leaves two options, either sex reversals occur, meaning that phenotype and genotype don't match up, or the sex chromosomes really are just super undifferentiated!
#
# ### NEXT STEPS
#
# The next thing to do is to look at the linkage maps. I can make linkage maps with the families, and compare the number of markers in male and female maps. As in Alan's papers, we can then look for chromosomes with a higher number of SNPs in one sex than the other sex. . . So have to come back to this soon!
