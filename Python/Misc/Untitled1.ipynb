# %%
names = open("/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Cru_Cyp_names.txt", 'r').readlines()
print "original file length", len(names)-6
# Out:
# original file length 1110

# %%
names = open("/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Cru_Cyp_names.txt", 'r').readlines()
print "original file length", len(names)-6
names = [i.strip() for i in set(names)]

data_named = open("/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Car_refined_named.dat", 'r').readlines()

Cru_Cyp_Newhybs = open("/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Cru_cyp_NEWHYBS.dat", 'w')

for line in data_named[0:6]:
    Cru_Cyp_Newhybs.write(line)
counter = 0
for line in data_named:
    for name in names:
        if line.split()[0] == name:
            print name
            counter += 1
            Cru_Cyp_Newhybs.write(line)

Cru_Cyp_Newhybs.close()
print counter
# Out:
# original file length 1110
# BOK1
# BOK2
# BOK3
# BOK4
# BOK5
# BOK6
# BOK7
# BOK8
# BOK9
# BOK10
# BOK11
# BOK12
# BOK13
# BOK14
# MVW1
# MVW2
# MVW3
# MVW4
# MVW5
# MVW6
# MVW7
# MVW8
# MVW9
# MVW10
# MVW11
# MVW12
# MVWZ1
# MVWZ2
# MVWZ3
# MVWZ4
# MVWZ5
# MVWZ6
# MVWZ7
# MVWZ8
# MVWZ9
# OKB1
# OKB2
# OKB3
# OKB4
# C2016C1
# C2016C2
# C2016C3
# C2016C4
# C2016C5
# CCS1
# CCS2
# CCS3
# CCS4
# CCS5
# CCS6
# CCS7
# CCS8
# CCS9
# CCS10
# CCS11
# CCS12
# CCS13
# CCS14
# CCS15
# CCS16
# CCS17
# CCS18
# CCS19
# CCS20
# CCS21
# CCS22
# CCS23
# CCS24
# CCS25
# CCS26
# CCS27
# CCS28
# CCS29
# CCS30
# FFF1
# FFF2
# FFF3
# FFF4
# TL1
# TL2
# TL3
# TL4
# TL5
# TL6
# TL7
# TL8
# TL9
# TL10
# TL11
# TL12
# TL13
# TL14
# TL15
# TL16
# TL17
# TL18
# TL19
# TL20
# NLP1
# NLP2
# NLP3
# NLP4
# NLP5
# NLP6
# NLP7
# NLP8
# NLP9
# NLP10
# NLP11
# NLP12
# NLP13
# NLP14
# NLP15
# NLP16
# NLP17
# NLP18
# NLP19
# NLP20
# NLP21
# NLP22
# NLP23
# NLP24
# NLP25
# NLP26
# NLP27
# NLP28
# NLP29
# NLP30
# NLP31
# ...
