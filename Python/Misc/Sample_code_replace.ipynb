# %%
test = open("/home/djeffrie/Dropbox/PhD/Dans_PhD_Shared/Thesis/Misc/Labels_key_file", 'r').readlines()

for line in test:
    print line.split()[0]
# Out:
# AL01
# AL08
# AL09
# AL10
# AL11
# AL12
# AL13
# AL14
# BF1
# BF01
# BF10
# BF11
# BF12
# BF13
# BF14
# BF16
# BF17
# BF18
# BF19
# BF2
# BF02
# BF20
# BF21
# BF22
# BF23
# BF24
# BF25
# BF26
# BF27
# BF28
# BF29
# BF3
# BF03
# BF30
# BF31
# BF32
# BF33
# BF34
# BF35
# BF36
# BF37
# BF38
# BF39
# BF4
# BF04
# BF40
# BF5
# BF05
# BF6
# BF06
# BF7
# BF07
# BF8
# BF08
# BF9
# BF09
# BOK1
# BOK10
# BOK11
# BOK12
# BOK13
# BOK14
# BOK2
# BOK3
# BOK4
# BOK5
# BOK6
# BOK7
# BOK8
# BOK9
# BOR01
# BOR02
# BOR03
# BOR04
# BOR06
# C2016C1
# C2016C2
# C2016C3
# C2016C4
# C2016C5
# CACR01
# CACR02
# CACR03
# CACR04
# CACR05
# CACR06
# CACR07
# CACR08
# CACR09
# CAKE01
# CAKE02
# CAKE03
# CAKE04
# CAKE05
# CAKE06
# CAKE07
# CAKE08
# CAKE09
# CAKE1
# CAKE2
# CAKE3
# CAKE4
# CAKE5
# CAKE6
# CAKE7
# CAKE8
# CAKE9
# CAKE10
# CAKE11
# CAKE12
# CAKE13
# CAKE14
# CAKE15
# CAKE16
# CAKE17
# CAKE18
# CAKE19
# CAKE20
# CAKE21
# CAKE22
# CAKE23
# CAKE24
# CAKE25
# CAKE26
# CAKE27
# CAKE28
# CAKE29
# CALK01
# ...

# %%
## label changer
import sys

#data_file = open(sys.argv[1], 'r').readlines()
#outfile = open(sys.argv[2], 'w')
#label_keys = open(sys.argv[3], 'r').readlines()

data_file = open("/home/djeffrie/Dropbox/PhD/Dans_PhD_Shared/Papers/Phylogeography_paper/Final_data_files/indiv_sample_coverages.txt", 'r').readlines()
label_keys = open("/home/djeffrie/Dropbox/PhD/Dans_PhD_Shared/Thesis/Misc/Labels_key_file2.txt", 'r').readlines()
outfile = open("/home/djeffrie/Dropbox/PhD/Dans_PhD_Shared/Papers/Phylogeography_paper/Final_data_files/indiv_sample_coverages_newcodes.txt", 'w')

for datline in data_file:

    for line in label_keys:
        #print line.split()[0]
        old = line.split()[0]
        new = line.strip().split()[1]
        for field in datline.split():
            if old == field:
                datline = datline.replace(old, new)
            else:
                pass
    outfile.write(datline)
    print datline.strip()
outfile.close()
# Out:
# GBR8_33	19.15
# GBR8_35	20.98
# GBR8_36	34.26
# GBR8_38	16.17
# GBR8_39	28.82
# GBR8_2	22.99
# GBR8_3	15.2
# GBR8_4	15.71
# GBR8_5	24.4
# BEL1_15	26.45
# BEL1_16	34.17
# BEL1_17	27.93
# BEL1_18	28.3
# BEL1_19	22.03
# GBR4_10	33.92
# GBR4_2	20.12
# GBR4_3	30.47
# GBR4_4	22.51
# GBR4_5	34.12
# GBR4_6	29.89
# GBR4_7	31.02
# GBR4_8	35.54
# GBR4_9	38.79
# FIN3_1	34.31
# FIN3_2	24.95
# FIN3_3	28.35
# FIN3_4	33.67
# FIN3_5	27.46
# FIN3_6	40.56
# FIN3_7	37.14
# FIN3_8	35.05
# FIN3_9	36.92
# FIN3_10	31.15
# DEN1_3	25.11
# DEN1_4	20.62
# DEN1_5	54.2
# DEN1_6	31.5
# DEN1_7	57.48
# DEN1_8	19.62
# DEN1_9	23.27
# DEN1_10	17.51
# DEN1_11	28.27
# DEN1_12	17.93
# HUN4_2	73.59
# HUN4_8	50.1
# HUN4_10	36.81
# HUN3_1	30.72
# HUN3_3	26.71
# HUN3_2	34.2
# MOAT1	22.05
# GBR7_2	30.1
# GBR7_7	49.53
# GBR7_11	40.42
# GBR7_19	29.38
# GBR7_21	29.66
# GBR7_22	35.85
# GBR7_23	38.42
# GBR7_24	27.95
# GBR7_25	34.46
# SWE12_1	18.78
# SWE12_2	25.73
# SWE12_7	25.92
# SWE12_10	26.81
# SWE12_11	18.19
# SWE12_12	17.67
# ...
