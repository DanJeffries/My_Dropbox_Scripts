# %%
cru_comm = open("C:/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Cru_Cyp_names.txt", 'r').readlines()
car_named = open("C:/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Car_refined_named.dat", 'r').readlines()

print len(cru_comm)

new_fstat = open("C:/Users/Dan/Documents/Dropbox/PhD/Dans_PhD_Shared/Thesis/Chapter_4_Hybridisation_and_introgression/data/Microsats/Cru_cyp_fstat.dat ", 'w')

for header in car_named[:6]:
    new_fstat.write(header)

numblines = 0
for line in car_named[7:]:
    for name in cru_comm:
        if line.split()[0] == name.strip():
            numblines += 1
            new_fstat.write(line)
            print line.strip()
print numblines

new_fstat.close()
# Out:
# 1029
# BOK1	299299	182182	221221	161161	220220	136136
# BOK2	299299	182182	221221	161161	220220	136136
# BOK3	299299	182182	221223	161161	220220	136136
# BOK4	299299	182182	221221	161161	220220	136136
# BOK5	299299	182182	223223	161161	220220	136136
# BOK6	299299	182182	221221	161161	220220	136136
# BOK7	299299	182182	221223	161161	220220	136136
# BOK8	299299	182182	221221	161161	220220	136136
# BOK9	299299	182182	221221	161161	220220	136136
# BOK10	299299	182182	221221	161161	220220	136136
# BOK11	299299	182182	221221	161161	220220	136136
# BOK12	299299	182182	221223	161161	220220	136136
# BOK13	299299	182182	221223	161161	220220	136136
# BOK14	299299	182182	221221	161161	220220	136136
# MVW1	299299	182182	221221	161161	220220	136136
# MVW2	299299	182182	221221	161161	220220	136136
# MVW3	299299	182182	221223	161161	220220	136136
# MVW4	299299	182182	221223	161161	220220	136136
# MVW5	299299	182182	221221	161161	220220	136136
# MVW6	299299	182182	221221	161161	220220	136136
# ...
